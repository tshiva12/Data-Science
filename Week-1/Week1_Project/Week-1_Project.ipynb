# %% [markdown]
# Walter Thornton working with Dwayne Kennemore

# %% [markdown]
# Dwayne. Solved our issue. Completely.
#     Things to do:
#         1.6 Alternate metric code
#         1.7 Answer question
#
#         Delete this cell. Send me a copy.
#
#         IMPORTANT Certain cells cannot be run over and over without clearing some previous output.

# %% [markdown]
# # CS 109A/STAT 121A/AC 209A/CSCI E-109A: Homework 1
#
#
#
# **Harvard University**<br/>
# **Fall 2017**<br/>
# **Instructors**: Pavlos Protopapas, Kevin Rader, Rahul Dave, Margo Levine
#
# ---
#
# ### INSTRUCTIONS
#
# **WARNING**: There is web page scraping in this homework. It takes about 40 minutes. **Do not wait till the last minute** to do this homework.
#
# - To submit your assignment follow the instructions given in canvas.
# - Restart the kernel and run the whole notebook again before you submit. There is an important CAVEAT to this. DO NOT run the web-page fetching cells again. (We have provided hints like `# DO NOT RERUN THIS CELL WHEN SUBMITTING` on some of the cells where we provide the code). Instead load your data structures from the JSON files we will ask you to save below. Otherwise you will be waiting for a long time. (Another reason to not wait until the last moment to submit.)
#
# - Do not include your name in the notebook.
#
# ---

# %% [markdown]
# # Homework 1: Rihanna or Mariah?

# %% [markdown]
# Billboard Magazine puts out a top 100 list of "singles" every week. Information from this list, as well as that from music sales, radio, and other sources is used to determine a top-100 "singles" of the year list. A **single** is typically one song, but sometimes can be two songs which are on one "single" record.
#
# In this homework you will:
#
# 1. Scrape Wikipedia to obtain infprmation about the best singers and groups from each year (distinguishing between the two groups) as determined by the Billboard top 100 charts. You will have to clean this data. Along the way you will learn how to save data in json files to avoid repeated scraping.
# 2. Scrape Wikipedia to obtain information on these singers. You will have to scrape the web pages, this time using a cache to guard against network timeouts (or your laptop going to sleep). You will again clean the data, and save it to a json file.
# 3. Use pandas to represent these two datasets and merge them.
# 4. Use the individual and merged datasets to visualize the performance of the artists and their songs. We have kept the amount of analysis limited here for reasons of time; but you might enjoy exploring music genres and other aspects of the music business you can find on these wikipedia pages at your own leisure.

# %% [markdown]
# You should have worked through Lab0 and Lab 1, and Lecture 2.  Lab 2 will help as well.

# %% [markdown]
# As usual, first we import the necessary libraries.  In particular, we use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as pl
import pandas as pd
import time
import requests
import urllib.request
from bs4 import BeautifulSoup
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape Wikipedia for the Billboard's top 100 singles.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using  [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/), and suggest that you use Python's built in `requests` library to fetch the web page.

# %% [markdown]
# #### 1.1 Parsing the Billboard Wikipedia page for 1970

# %% [markdown]
# Obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970 using a HTTP GET request. From this web page we'll extract the top 100 singles and their rankings. Create a list of dictionaries, 100 of them to be precise, with entries like
#
# `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# If you look at that web page, you'll see a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# *HINT: look for a table with class `wikitable`.*

# %%
req = requests.get("https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970")

# %%
page = req.text
soup = BeautifulSoup(page, 'html.parser')
soup.table["class"]

table_html = soup.find('table', attrs={'class':'wikitable sortable'})

# %%
songs_list = []

table_row_list = table_html.find_all('tr')
table_rows = table_row_list[1:] 
table_rows

for row in table_rows:
#     print(row)
    table_row_values = row.find_all('td')
    
#     print(table_cols)
    
    ranking = table_row_values[0].get_text()
    title = table_row_values[1].get_text()
    band_singer = table_row_values[2].get_text().replace("\n","")
    
    url = table_row_values[1].a["href"]
    
    dic = {'band_singer': band_singer,
           'ranking': ranking,
           'title': title,
           'url': url}
    songs_list.append(dic)
print(songs_list[2:4])
# Out:
# [{'band_singer': 'The Guess Who', 'ranking': '3', 'title': '"American Woman"', 'url': '/wiki/American_Woman'}, {'band_singer': 'B.J. Thomas', 'ranking': '4', 'title': '"Raindrops Keep Fallin\' on My Head"', 'url': '/wiki/Raindrops_Keep_Fallin%27_on_My_Head'}]

# %% [markdown]
# sanity check
# song_list[2:4]

# %% [markdown]
# You should get something similar to this (where songs is the aforementioned list):
#
# ```
# songs[2:4]
# ```
#
# ```
# [{'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'title': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'}]
# ```

# %% [markdown]
# #### 1.2 Generalize the previous: scrape Wikipedia from 1992 to 2014

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. (We choose these later years rather than 1970 as you might find music from this era more interesting.) Download these using Python's `requests` module and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second (look up `time.sleep` in Python) at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %%
#retrieves full webpages from wikipedia saving each to a dictionary keyed by year
yearstext = {}
for year in range(1992, 2015):
    with urllib.request.urlopen(f'https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_%s' % year) as response:
        year_text = {year : response.read()}
        yearstext.update(year_text)
        time.sleep(1)

# %% [markdown]
# *HINT: you might find `range` and string-interpolation useful to construct the URLs *.

# %% [markdown]
# #### 1.3 Parse and Clean data

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single.  Now write a function `parse_year(the_year, yeartext_dict)` which takes the year, prints it out, gets the text for the year from the just created `yearstext` dictionary, and return a list of dictionaries for that year, with one dictionary for each single. Store this list in the variable `yearinfo`.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %% [markdown]
# The spec of this function is provided below:

# %%
"""
Function
--------
parse_year

Inputs
------
the_year: the year you want the singles for
yeartext_dict: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:


Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    

Notes
-----
See description and example above.
"""




def parse_year(the_year, yeartext_dict):
    year = the_year
    yearinfo = []
    song = []
    songurl = []
    band_singer = []
    title = []
    url = []
    title_text = ''
    i = 0
    title_string = ''
    band_singer = ''
    soup = BeautifulSoup(yearstext[year], "lxml")
    tables = soup.find('table', attrs={'class':'wikitable sortable'})        
    #iterates through tree structure, scraping our data
    tr_list = tables.find_all('tr')    
    for tr in tr_list:
        td_list = tr.find_all('td')
        if td_list == [] :
            td_list = []
        else : 
            ranking = tr.th.string
            links = tr.td.findAll('a')
            number_of_links = len(links)   
            if number_of_links == 0:
                songurl = [None]
                title_text = [a['title']]
                song.append(a['title'] )
            else :
                i = 0
                for a in tr.td.findAll('a') : 
                    song.append(a['title'] )
                    title_string = '\"' + a['title'] + '\"'    
                    if i == 0 :
                        title_text = title_string
                        i = i + 1
                    else :
                        title_text = title_text + ' / ' + title_string
                        i = i + 1    
                    songurl.append(a['href'])
            title = song
            #finds next td tag
            tr.td.findNext('td') 
            temp = len(tr.td.findNext('td').findAll('a'))
            if temp == 0:
                singer_url = [None]
                band_singer = tr.td.findNext('td').string
                band_singer = [band_singer]
            elif temp == 1:
                singer_url = tr.td.findNext('td').a['href']
                singer_url = [singer_url]
                band_singer = tr.td.findNext('td').a.string
                band_singer = [band_singer]
            else:
                singer_url = []
                band_singer = []
                for a in tr.td.findNext('td').findAll('a'):
                    webpage = a['href']
                    singer_url.append(webpage)
                    band_singer.append(a.string)            
            #creates dictionary entry                   
            dict_entry = {'band_singer' : band_singer,
            'ranking' : ranking,
            'song' : title, 'songurl': songurl, 'titletext' : title_text,
            'url' : singer_url}
            #appends new dictionary to our list
            yearinfo.append(dict_entry)      
            songurl = []
            song = []
            title_string = ''
            title_text = ''    
    return(yearinfo)

# %%
#parse each year
years_dict = {}
for year in range(1992, 2015):
    years_dict.update({year : parse_year(year, yearstext)})

# %%
#assign the complete dictionary back to yearinfo
yearinfo = years_dict

# %% [markdown]
# #### Helpful notes
#
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some singles don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# Thus there are some issues this function must handle:
#
# 1. There can be more than one  `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be two songs in a single, because of the way the industry works: there are two-sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for an example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that Wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %% [markdown]
# As a check, we can do this for 1997. We'll print the first 5 outputs: `parse_year(1997, yearstext)[:5]`

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %% [markdown]
# sanity check
# parse_year(1997, yearstext)[:5]

# %% [markdown]
# ```
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]
# ```

# %% [markdown]
# #### Save a json file of information from the scraped files

# %% [markdown]
# We do not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run from here, you don't need to redo all these requests and parsing.
#
# DO NOT RERUN THE HTTP REQUESTS TO WIKIPEDIA WHEN SUBMITTING.
#
# *We **DO NOT** need to see these JSON files in your submission!*

# %%
import json

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
fd = open("yearinfo.json","w+")
json.dump(yearinfo, fd)
fd.close()
del yearinfo

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %%
# RERUN WHEN SUBMITTING
# Another way to deal with files. Has the advantage of closing the file for you.
with open("yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %% [markdown]
# #### 1.4 Construct a year-song-singer dataframe from the yearly information

# %% [markdown]
# Let's construct a dataframe `flatframe` from the `yearinfo`. The frame should be similar to the frame below.  Each row of the frame represents a song, and carries with it the chief properties of year, song, singer, and ranking.
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC1.png)

# %%
# turns our list into a list of dictionaries where each entry contains a year key  
rows = []
for year in yearinfo.keys():
    for song in yearinfo[year]:
        song['year'] = year
        rows.append(song)

# %%
# sanity check
rows
# Out:
# [{'band_singer': ['Boyz II Men'],
#   'ranking': '1\n',
#   'song': ['End of the Road'],
#   'songurl': ['/wiki/End_of_the_Road'],
#   'titletext': '"End of the Road"',
#   'url': ['/wiki/Boyz_II_Men'],
#   'year': '1992'},
#  {'band_singer': ['Sir Mix-a-Lot'],
#   'ranking': '2\n',
#   'song': ['Baby Got Back'],
#   'songurl': ['/wiki/Baby_Got_Back'],
#   'titletext': '"Baby Got Back"',
#   'url': ['/wiki/Sir_Mix-a-Lot'],
#   'year': '1992'},
#  {'band_singer': ['Kris Kross'],
#   'ranking': '3\n',
#   'song': ['Jump (Kris Kross song)'],
#   'songurl': ['/wiki/Jump_(Kris_Kross_song)'],
#   'titletext': '"Jump (Kris Kross song)"',
#   'url': ['/wiki/Kris_Kross'],
#   'year': '1992'},
#  {'band_singer': ['Vanessa Williams'],
#   'ranking': '4\n',
#   'song': ['Save the Best for Last'],
#   'songurl': ['/wiki/Save_the_Best_for_Last'],
#   'titletext': '"Save the Best for Last"',
#   'url': ['/wiki/Vanessa_L._Williams'],
#   'year': '1992'},
#  {'band_singer': ['TLC'],
#   'ranking': '5\n',
#   'song': ['Baby-Baby-Baby'],
#   'songurl': ['/wiki/Baby-Baby-Baby'],
#   'titletext': '"Baby-Baby-Baby"',
#   'url': ['/wiki/TLC_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Eric Clapton'],
#   'ranking': '6\n',
#   'song': ['Tears in Heaven'],
#   'songurl': ['/wiki/Tears_in_Heaven'],
#   'titletext': '"Tears in Heaven"',
#   'url': ['/wiki/Eric_Clapton'],
#   'year': '1992'},
#  {'band_singer': ['En Vogue'],
#   'ranking': '7\n',
#   'song': ["My Lovin' (You're Never Gonna Get It)"],
#   'songurl': ['/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)'],
#   'titletext': '"My Lovin\' (You\'re Never Gonna Get It)"',
#   'url': ['/wiki/En_Vogue'],
#   'year': '1992'},
#  {'band_singer': ['Red Hot Chili Peppers'],
#   'ranking': '8\n',
#   'song': ['Under the Bridge'],
#   'songurl': ['/wiki/Under_the_Bridge'],
#   'titletext': '"Under the Bridge"',
#   'url': ['/wiki/Red_Hot_Chili_Peppers'],
#   'year': '1992'},
#  {'band_singer': ['Color Me Badd'],
#   'ranking': '9\n',
#   'song': ['All 4 Love'],
#   'songurl': ['/wiki/All_4_Love'],
#   'titletext': '"All 4 Love"',
#   'url': ['/wiki/Color_Me_Badd'],
#   'year': '1992'},
#  {'band_singer': ['Jon Secada'],
#   'ranking': '10\n',
#   'song': ['Just Another Day (Jon Secada song)'],
#   'songurl': ['/wiki/Just_Another_Day_(Jon_Secada_song)'],
#   'titletext': '"Just Another Day (Jon Secada song)"',
#   'url': ['/wiki/Jon_Secada'],
#   'year': '1992'},
#  {'band_singer': ['Shanice'],
#   'ranking': '11\n',
#   'song': ['I Love Your Smile'],
#   'songurl': ['/wiki/I_Love_Your_Smile'],
#   'titletext': '"I Love Your Smile"',
#   'url': ['/wiki/Shanice'],
#   'year': '1992'},
#  {'band_singer': ['Mr. Big'],
#   'ranking': '12\n',
#   'song': ['To Be with You'],
#   'songurl': ['/wiki/To_Be_with_You'],
#   'titletext': '"To Be with You"',
#   'url': ['/wiki/Mr._Big_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Right Said Fred'],
#   'ranking': '13\n',
#   'song': ["I'm Too Sexy"],
#   'songurl': ['/wiki/I%27m_Too_Sexy'],
#   'titletext': '"I\'m Too Sexy"',
#   'url': ['/wiki/Right_Said_Fred'],
#   'year': '1992'},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '14\n',
#   'song': ['Black or White'],
#   'songurl': ['/wiki/Black_or_White'],
#   'titletext': '"Black or White"',
#   'url': ['/wiki/Michael_Jackson'],
#   'year': '1992'},
#  {'band_singer': ['Billy Ray Cyrus'],
#   'ranking': '15\n',
#   'song': ['Achy Breaky Heart'],
#   'songurl': ['/wiki/Achy_Breaky_Heart'],
#   'titletext': '"Achy Breaky Heart"',
#   'url': ['/wiki/Billy_Ray_Cyrus'],
#   'year': '1992'},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '16\n',
#   'song': ["I'll Be There (The Jackson 5 song)"],
#   'songurl': ['/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mariah_Carey_version'],
#   'titletext': '"I\'ll Be There (The Jackson 5 song)"',
#   'url': ['/wiki/Mariah_Carey'],
#   'year': '1992'},
#  {'band_singer': ["Guns N' Roses"],
#   'ranking': '17\n',
#   'song': ['November Rain'],
#   'songurl': ['/wiki/November_Rain'],
#   'titletext': '"November Rain"',
#   'url': ['/wiki/Guns_N%27_Roses'],
#   'year': '1992'},
#  {'band_singer': ['Tom Cochrane'],
#   'ranking': '18\n',
#   'song': ['Life Is a Highway'],
#   'songurl': ['/wiki/Life_Is_a_Highway'],
#   'titletext': '"Life Is a Highway"',
#   'url': ['/wiki/Tom_Cochrane'],
#   'year': '1992'},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '19\n',
#   'song': ['Remember the Time'],
#   'songurl': ['/wiki/Remember_the_Time'],
#   'titletext': '"Remember the Time"',
#   'url': ['/wiki/Michael_Jackson'],
#   'year': '1992'},
#  {'band_singer': ['CeCe Peniston'],
#   'ranking': '20\n',
#   'song': ['Finally (CeCe Peniston song)'],
#   'songurl': ['/wiki/Finally_(CeCe_Peniston_song)'],
#   'titletext': '"Finally (CeCe Peniston song)"',
#   'url': ['/wiki/CeCe_Peniston'],
#   'year': '1992'},
#  {'band_singer': ['Madonna'],
#   'ranking': '21\n',
#   'song': ['This Used to Be My Playground'],
#   'songurl': ['/wiki/This_Used_to_Be_My_Playground'],
#   'titletext': '"This Used to Be My Playground"',
#   'url': ['/wiki/Madonna_(entertainer)'],
#   'year': '1992'},
#  {'band_singer': ['Patty Smyth', 'Don Henley'],
#   'ranking': '22\n',
#   'song': ["Sometimes Love Just Ain't Enough"],
#   'songurl': ['/wiki/Sometimes_Love_Just_Ain%27t_Enough'],
#   'titletext': '"Sometimes Love Just Ain\'t Enough"',
#   'url': ['/wiki/Patty_Smyth', '/wiki/Don_Henley'],
#   'year': '1992'},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '23\n',
#   'song': ["Can't Let Go (Mariah Carey song)"],
#   'songurl': ['/wiki/Can%27t_Let_Go_(Mariah_Carey_song)'],
#   'titletext': '"Can\'t Let Go (Mariah Carey song)"',
#   'url': ['/wiki/Mariah_Carey'],
#   'year': '1992'},
#  {'band_singer': ['House of Pain'],
#   'ranking': '24\n',
#   'song': ['Jump Around'],
#   'songurl': ['/wiki/Jump_Around'],
#   'titletext': '"Jump Around"',
#   'url': ['/wiki/House_of_Pain'],
#   'year': '1992'},
#  {'band_singer': ['Prince', 'The New Power Generation'],
#   'ranking': '25\n',
#   'song': ['Diamonds and Pearls (song)'],
#   'songurl': ['/wiki/Diamonds_and_Pearls_(song)'],
#   'titletext': '"Diamonds and Pearls (song)"',
#   'url': ['/wiki/Prince_(entertainer)', '/wiki/The_New_Power_Generation'],
#   'year': '1992'},
#  {'band_singer': ['George Michael', 'Elton John'],
#   'ranking': '26\n',
#   'song': ["Don't Let the Sun Go Down on Me"],
#   'songurl': ['/wiki/Don%27t_Let_the_Sun_Go_Down_on_Me'],
#   'titletext': '"Don\'t Let the Sun Go Down on Me"',
#   'url': ['/wiki/George_Michael', '/wiki/Elton_John'],
#   'year': '1992'},
#  {'band_singer': ['Atlantic Starr'],
#   'ranking': '27\n',
#   'song': ['Masterpiece (Atlantic Starr song)'],
#   'songurl': ['/wiki/Masterpiece_(Atlantic_Starr_song)'],
#   'titletext': '"Masterpiece (Atlantic Starr song)"',
#   'url': ['/wiki/Atlantic_Starr'],
#   'year': '1992'},
#  {'band_singer': ['Celine Dion'],
#   'ranking': '28\n',
#   'song': ['If You Asked Me To'],
#   'songurl': ['/wiki/If_You_Asked_Me_To'],
#   'titletext': '"If You Asked Me To"',
#   'url': ['/wiki/Celine_Dion'],
#   'year': '1992'},
#  {'band_singer': ['En Vogue'],
#   'ranking': '29\n',
#   'song': ['Something He Can Feel'],
#   'songurl': ['/wiki/Something_He_Can_Feel'],
#   'titletext': '"Something He Can Feel"',
#   'url': ['/wiki/En_Vogue'],
#   'year': '1992'},
#  {'band_singer': ['Joe Public'],
#   'ranking': '30\n',
#   'song': ['Live and Learn (Joe Public song)'],
#   'songurl': ['/wiki/Live_and_Learn_(Joe_Public_song)'],
#   'titletext': '"Live and Learn (Joe Public song)"',
#   'url': ['/wiki/Joe_Public_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Jodeci'],
#   'ranking': '31\n',
#   'song': ['Come and Talk to Me'],
#   'songurl': ['/wiki/Come_and_Talk_to_Me'],
#   'titletext': '"Come and Talk to Me"',
#   'url': ['/wiki/Jodeci'],
#   'year': '1992'},
#  {'band_singer': ['Nirvana'],
#   'ranking': '32\n',
#   'song': ['Smells Like Teen Spirit'],
#   'songurl': ['/wiki/Smells_Like_Teen_Spirit'],
#   'titletext': '"Smells Like Teen Spirit"',
#   'url': ['/wiki/Nirvana_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Bobby Brown'],
#   'ranking': '33\n',
#   'song': ["Humpin' Around"],
#   'songurl': ['/wiki/Humpin%27_Around'],
#   'titletext': '"Humpin\' Around"',
#   'url': ['/wiki/Bobby_Brown'],
#   'year': '1992'},
#  {'band_singer': ['Sophie B. Hawkins'],
#   'ranking': '34\n',
#   'song': ['Damn I Wish I Was Your Lover'],
#   'songurl': ['/wiki/Damn_I_Wish_I_Was_Your_Lover'],
#   'titletext': '"Damn I Wish I Was Your Lover"',
#   'url': ['/wiki/Sophie_B._Hawkins'],
#   'year': '1992'},
#  {'band_singer': ['Tevin Campbell'],
#   'ranking': '35\n',
#   'song': ['Tell Me What You Want Me to Do'],
#   'songurl': ['/wiki/Tell_Me_What_You_Want_Me_to_Do'],
#   'titletext': '"Tell Me What You Want Me to Do"',
#   'url': ['/wiki/Tevin_Campbell'],
#   'year': '1992'},
#  {'band_singer': ['TLC'],
#   'ranking': '36\n',
#   'song': ["Ain't 2 Proud 2 Beg"],
#   'songurl': ['/wiki/Ain%27t_2_Proud_2_Beg'],
#   'titletext': '"Ain\'t 2 Proud 2 Beg"',
#   'url': ['/wiki/TLC_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': '37\n',
#   'song': ["It's So Hard to Say Goodbye to Yesterday"],
#   'songurl': ['/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday'],
#   'titletext': '"It\'s So Hard to Say Goodbye to Yesterday"',
#   'url': ['/wiki/Boyz_II_Men'],
#   'year': '1992'},
#  {'band_singer': ['Technotronic', 'Ya Kid K'],
#   'ranking': '38\n',
#   'song': ['Move This'],
#   'songurl': ['/wiki/Move_This'],
#   'titletext': '"Move This"',
#   'url': ['/wiki/Technotronic', '/wiki/Ya_Kid_K'],
#   'year': '1992'},
#  {'band_singer': ['Queen'],
#   'ranking': '39\n',
#   'song': ['Bohemian Rhapsody'],
#   'songurl': ['/wiki/Bohemian_Rhapsody'],
#   'titletext': '"Bohemian Rhapsody"',
#   'url': ['/wiki/Queen_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Arrested Development'],
#   'ranking': '40\n',
#   'song': ['Tennessee (Arrested Development song)'],
#   'songurl': ['/wiki/Tennessee_(Arrested_Development_song)'],
#   'titletext': '"Tennessee (Arrested Development song)"',
#   'url': ['/wiki/Arrested_Development_(group)'],
#   'year': '1992'},
#  {'band_singer': ['Luther Vandross', 'Janet Jackson'],
#   'ranking': '41\n',
#   'song': ['The Best Things in Life Are Free'],
#   'songurl': ['/wiki/The_Best_Things_in_Life_Are_Free'],
#   'titletext': '"The Best Things in Life Are Free"',
#   'url': ['/wiki/Luther_Vandross', '/wiki/Janet_Jackson'],
#   'year': '1992'},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '42\n',
#   'song': ['Make It Happen (Mariah Carey song)'],
#   'songurl': ['/wiki/Make_It_Happen_(Mariah_Carey_song)'],
#   'titletext': '"Make It Happen (Mariah Carey song)"',
#   'url': ['/wiki/Mariah_Carey'],
#   'year': '1992'},
#  {'band_singer': ['Elton John'],
#   'ranking': '43\n',
#   'song': ['The One (Elton John song)'],
#   'songurl': ['/wiki/The_One_(Elton_John_song)'],
#   'titletext': '"The One (Elton John song)"',
#   'url': ['/wiki/Elton_John'],
#   'year': '1992'},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '44\n',
#   'song': ['Set Adrift on Memory Bliss'],
#   'songurl': ['/wiki/Set_Adrift_on_Memory_Bliss'],
#   'titletext': '"Set Adrift on Memory Bliss"',
#   'url': ['/wiki/P.M._Dawn'],
#   'year': '1992'},
#  {'band_singer': ['Shakespears Sister'],
#   'ranking': '45\n',
#   'song': ['Stay (Shakespears Sister song)'],
#   'songurl': ['/wiki/Stay_(Shakespears_Sister_song)'],
#   'titletext': '"Stay (Shakespears Sister song)"',
#   'url': ['/wiki/Shakespears_Sister'],
#   'year': '1992'},
#  {'band_singer': ['Hammer'],
#   'ranking': '46\n',
#   'song': ['Too Legit to Quit (song)'],
#   'songurl': ['/wiki/Too_Legit_to_Quit_(song)'],
#   'titletext': '"Too Legit to Quit (song)"',
#   'url': ['/wiki/MC_Hammer'],
#   'year': '1992'},
#  {'band_singer': ['KWS'],
#   'ranking': '47\n',
#   'song': ["Please Don't Go (KC and the Sunshine Band song)"],
#   'songurl': ['/wiki/Please_Don%27t_Go_(KC_and_the_Sunshine_Band_song)#KWS_version'],
#   'titletext': '"Please Don\'t Go (KC and the Sunshine Band song)"',
#   'url': ['/wiki/KWS_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Mint Condition'],
#   'ranking': '48\n',
#   'song': ["Breakin' My Heart (Pretty Brown Eyes)"],
#   'songurl': ['/wiki/Breakin%27_My_Heart_(Pretty_Brown_Eyes)'],
#   'titletext': '"Breakin\' My Heart (Pretty Brown Eyes)"',
#   'url': ['/wiki/Mint_Condition'],
#   'year': '1992'},
#  {'band_singer': ['The Cover Girls'],
#   'ranking': '49\n',
#   'song': ['Wishing on a Star'],
#   'songurl': ['/wiki/Wishing_on_a_Star'],
#   'titletext': '"Wishing on a Star"',
#   'url': ['/wiki/The_Cover_Girls'],
#   'year': '1992'},
#  {'band_singer': ['Hi-Five'],
#   'ranking': '50\n',
#   'song': ['Wishing on a Star'],
#   'songurl': [None],
#   'titletext': ['Wishing on a Star'],
#   'url': ['/wiki/Hi-Five'],
#   'year': '1992'},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '51\n',
#   'song': ["I'd Die Without You"],
#   'songurl': ['/wiki/I%27d_Die_Without_You'],
#   'titletext': '"I\'d Die Without You"',
#   'url': ['/wiki/P.M._Dawn'],
#   'year': '1992'},
#  {'band_singer': ['Amy Grant'],
#   'ranking': '52\n',
#   'song': ['Good for Me (song)'],
#   'songurl': ['/wiki/Good_for_Me_(song)'],
#   'titletext': '"Good for Me (song)"',
#   'url': ['/wiki/Amy_Grant'],
#   'year': '1992'},
#  {'band_singer': ['Toad the Wet Sprocket'],
#   'ranking': '53\n',
#   'song': ['All I Want (Toad the Wet Sprocket song)'],
#   'songurl': ['/wiki/All_I_Want_(Toad_the_Wet_Sprocket_song)'],
#   'titletext': '"All I Want (Toad the Wet Sprocket song)"',
#   'url': ['/wiki/Toad_the_Wet_Sprocket'],
#   'year': '1992'},
#  {'band_singer': ['Michael Bolton'],
#   'ranking': '54\n',
#   'song': ['When a Man Loves a Woman (song)'],
#   'songurl': ['/wiki/When_a_Man_Loves_a_Woman_(song)'],
#   'titletext': '"When a Man Loves a Woman (song)"',
#   'url': ['/wiki/Michael_Bolton'],
#   'year': '1992'},
#  {'band_singer': ['Genesis'],
#   'ranking': '55\n',
#   'song': ["I Can't Dance"],
#   'songurl': ['/wiki/I_Can%27t_Dance'],
#   'titletext': '"I Can\'t Dance"',
#   'url': ['/wiki/Genesis_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Richard Marx'],
#   'ranking': '56\n',
#   'song': ['Hazard (song)'],
#   'songurl': ['/wiki/Hazard_(song)'],
#   'titletext': '"Hazard (song)"',
#   'url': ['/wiki/Richard_Marx'],
#   'year': '1992'},
#  {'band_singer': ['U2'],
#   'ranking': '57\n',
#   'song': ['Mysterious Ways (song)'],
#   'songurl': ['/wiki/Mysterious_Ways_(song)'],
#   'titletext': '"Mysterious Ways (song)"',
#   'url': ['/wiki/U2'],
#   'year': '1992'},
#  {'band_singer': ['George Michael'],
#   'ranking': '58\n',
#   'song': ['Too Funky'],
#   'songurl': ['/wiki/Too_Funky'],
#   'titletext': '"Too Funky"',
#   'url': ['/wiki/George_Michael'],
#   'year': '1992'},
#  {'band_singer': ['The Heights'],
#   'ranking': '59\n',
#   'song': ['How Do You Talk to an Angel'],
#   'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#   'titletext': '"How Do You Talk to an Angel"',
#   'url': ['/wiki/The_Heights_(American_TV_series)'],
#   'year': '1992'},
#  {'band_singer': ['U2'],
#   'ranking': '60\n',
#   'song': ['One (U2 song)'],
#   'songurl': ['/wiki/One_(U2_song)'],
#   'titletext': '"One (U2 song)"',
#   'url': ['/wiki/U2'],
#   'year': '1992'},
#  {'band_singer': ['CeCe Peniston'],
#   'ranking': '61\n',
#   'song': ["Keep on Walkin' (song)"],
#   'songurl': ['/wiki/Keep_on_Walkin%27_(song)'],
#   'titletext': '"Keep on Walkin\' (song)"',
#   'url': ['/wiki/CeCe_Peniston'],
#   'year': '1992'},
#  {'band_singer': ['Genesis'],
#   'ranking': '62\n',
#   'song': ['Hold on My Heart'],
#   'songurl': ['/wiki/Hold_on_My_Heart'],
#   'titletext': '"Hold on My Heart"',
#   'url': ['/wiki/Genesis_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Karyn White'],
#   'ranking': '63\n',
#   'song': ['Hold on My Heart'],
#   'songurl': [None],
#   'titletext': ['Hold on My Heart'],
#   'url': ['/wiki/Karyn_White'],
#   'year': '1992'},
#  {'band_singer': ['Celine Dion', 'Peabo Bryson'],
#   'ranking': '64\n',
#   'song': ['Beauty and the Beast (Disney song)'],
#   'songurl': ['/wiki/Beauty_and_the_Beast_(Disney_song)'],
#   'titletext': '"Beauty and the Beast (Disney song)"',
#   'url': ['/wiki/Celine_Dion', '/wiki/Peabo_Bryson'],
#   'year': '1992'},
#  {'band_singer': ['Kris Kross'],
#   'ranking': '65\n',
#   'song': ['Warm It Up'],
#   'songurl': ['/wiki/Warm_It_Up'],
#   'titletext': '"Warm It Up"',
#   'url': ['/wiki/Kris_Kross'],
#   'year': '1992'},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '66\n',
#   'song': ['In the Closet'],
#   'songurl': ['/wiki/In_the_Closet'],
#   'titletext': '"In the Closet"',
#   'url': ['/wiki/Michael_Jackson'],
#   'year': '1992'},
#  {'band_singer': ['Arrested Development'],
#   'ranking': '67\n',
#   'song': ['People Everyday'],
#   'songurl': ['/wiki/People_Everyday'],
#   'titletext': '"People Everyday"',
#   'url': ['/wiki/Arrested_Development_(group)'],
#   'year': '1992'},
#  {'band_singer': ['Genesis'],
#   'ranking': '68\n',
#   'song': ['No Son of Mine'],
#   'songurl': ['/wiki/No_Son_of_Mine'],
#   'titletext': '"No Son of Mine"',
#   'url': ['/wiki/Genesis_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Marky Mark and the Funky Bunch'],
#   'ranking': '69\n',
#   'song': ['Wildside (Marky Mark and the Funky Bunch song)'],
#   'songurl': ['/wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch_song)'],
#   'titletext': '"Wildside (Marky Mark and the Funky Bunch song)"',
#   'url': ['/wiki/Marky_Mark_and_the_Funky_Bunch'],
#   'year': '1992'},
#  {'band_singer': ['Bryan Adams'],
#   'ranking': '70\n',
#   'song': ['Do I Have to Say the Words?'],
#   'songurl': ['/wiki/Do_I_Have_to_Say_the_Words%3F'],
#   'titletext': '"Do I Have to Say the Words?"',
#   'url': ['/wiki/Bryan_Adams'],
#   'year': '1992'},
#  {'band_singer': ['The Cure'],
#   'ranking': '71\n',
#   'song': ["Friday I'm in Love"],
#   'songurl': ['/wiki/Friday_I%27m_in_Love'],
#   'titletext': '"Friday I\'m in Love"',
#   'url': ['/wiki/The_Cure'],
#   'year': '1992'},
#  {'band_singer': ['Ugly Kid Joe'],
#   'ranking': '72\n',
#   'song': ['Everything About You (Ugly Kid Joe song)'],
#   'songurl': ['/wiki/Everything_About_You_(Ugly_Kid_Joe_song)'],
#   'titletext': '"Everything About You (Ugly Kid Joe song)"',
#   'url': ['/wiki/Ugly_Kid_Joe'],
#   'year': '1992'},
#  {'band_singer': ['Paula Abdul'],
#   'ranking': '73\n',
#   'song': ['Blowing Kisses in the Wind'],
#   'songurl': ['/wiki/Blowing_Kisses_in_the_Wind'],
#   'titletext': '"Blowing Kisses in the Wind"',
#   'url': ['/wiki/Paula_Abdul'],
#   'year': '1992'},
#  {'band_singer': ['Bryan Adams'],
#   'ranking': '74\n',
#   'song': ["Thought I'd Died and Gone to Heaven"],
#   'songurl': ['/wiki/Thought_I%27d_Died_and_Gone_to_Heaven'],
#   'titletext': '"Thought I\'d Died and Gone to Heaven"',
#   'url': ['/wiki/Bryan_Adams'],
#   'year': '1992'},
#  {'band_singer': ['Snap!'],
#   'ranking': '75\n',
#   'song': ['Rhythm Is a Dancer'],
#   'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#   'titletext': '"Rhythm Is a Dancer"',
#   'url': ['/wiki/Snap!'],
#   'year': '1992'},
#  {'band_singer': ['Hammer'],
#   'ranking': '76\n',
#   'song': ['Addams Groove'],
#   'songurl': ['/wiki/Addams_Groove'],
#   'titletext': '"Addams Groove"',
#   'url': ['/wiki/MC_Hammer'],
#   'year': '1992'},
#  {'band_singer': ['Michael Bolton'],
#   'ranking': '77\n',
#   'song': ['Missing You Now'],
#   'songurl': ['/wiki/Missing_You_Now'],
#   'titletext': '"Missing You Now"',
#   'url': ['/wiki/Michael_Bolton'],
#   'year': '1992'},
#  {'band_singer': ['N2Deep'],
#   'ranking': '78\n',
#   'song': ['Missing You Now'],
#   'songurl': [None],
#   'titletext': ['Missing You Now'],
#   'url': ['/wiki/N2Deep'],
#   'year': '1992'},
#  {'band_singer': ['Kathy Troccoli'],
#   'ranking': '79\n',
#   'song': ['Missing You Now'],
#   'songurl': [None],
#   'titletext': ['Missing You Now'],
#   'url': ['/wiki/Kathy_Troccoli'],
#   'year': '1992'},
#  {'band_singer': ['Def Leppard'],
#   'ranking': '80\n',
#   'song': ['Have You Ever Needed Someone So Bad'],
#   'songurl': ['/wiki/Have_You_Ever_Needed_Someone_So_Bad'],
#   'titletext': '"Have You Ever Needed Someone So Bad"',
#   'url': ['/wiki/Def_Leppard'],
#   'year': '1992'},
#  {'band_singer': ['Richard Marx'],
#   'ranking': '81\n',
#   'song': ['Take This Heart'],
#   'songurl': ['/wiki/Take_This_Heart'],
#   'titletext': '"Take This Heart"',
#   'url': ['/wiki/Richard_Marx'],
#   'year': '1992'},
#  {'band_singer': ['FireHouse'],
#   'ranking': '82\n',
#   'song': ['When I Look Into Your Eyes'],
#   'songurl': ['/wiki/When_I_Look_Into_Your_Eyes'],
#   'titletext': '"When I Look Into Your Eyes"',
#   'url': ['/wiki/FireHouse_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Jade'],
#   'ranking': '83\n',
#   'song': ['I Wanna Love You (Jade song)'],
#   'songurl': ['/wiki/I_Wanna_Love_You_(Jade_song)'],
#   'titletext': '"I Wanna Love You (Jade song)"',
#   'url': ['/wiki/Jade_(American_band)'],
#   'year': '1992'},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': '84\n',
#   'song': ['Uhh Ahh'],
#   'songurl': ['/wiki/Uhh_Ahh'],
#   'titletext': '"Uhh Ahh"',
#   'url': ['/wiki/Boyz_II_Men'],
#   'year': '1992'},
#  {'band_singer': ['Mary J. Blige'],
#   'ranking': '85\n',
#   'song': ['Real Love (Mary J. Blige song)'],
#   'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#   'titletext': '"Real Love (Mary J. Blige song)"',
#   'url': ['/wiki/Mary_J._Blige'],
#   'year': '1992'},
#  {'band_singer': ['The KLF'],
#   'ranking': '86\n',
#   'song': ['Justified and Ancient'],
#   'songurl': ['/wiki/Justified_and_Ancient'],
#   'titletext': '"Justified and Ancient"',
#   'url': ['/wiki/The_KLF'],
#   'year': '1992'},
#  {'band_singer': ['Color Me Badd'],
#   'ranking': '87\n',
#   'song': ['Justified and Ancient'],
#   'songurl': [None],
#   'titletext': ['Justified and Ancient'],
#   'url': ['/wiki/Color_Me_Badd'],
#   'year': '1992'},
#  {'band_singer': ['TLC'],
#   'ranking': '88\n',
#   'song': ['What About Your Friends'],
#   'songurl': ['/wiki/What_About_Your_Friends'],
#   'titletext': '"What About Your Friends"',
#   'url': ['/wiki/TLC_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Color Me Badd'],
#   'ranking': '89\n',
#   'song': ['What About Your Friends'],
#   'songurl': [None],
#   'titletext': ['What About Your Friends'],
#   'url': ['/wiki/Color_Me_Badd'],
#   'year': '1992'},
#  {'band_singer': ['Charles & Eddie'],
#   'ranking': '90\n',
#   'song': ['Would I Lie to You? (Charles & Eddie song)'],
#   'songurl': ['/wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie_song)'],
#   'titletext': '"Would I Lie to You? (Charles & Eddie song)"',
#   'url': ['/wiki/Charles_%26_Eddie'],
#   'year': '1992'},
#  {'band_singer': ['Amy Grant'],
#   'ranking': '91\n',
#   'song': ["That's What Love Is For"],
#   'songurl': ['/wiki/That%27s_What_Love_Is_For'],
#   'titletext': '"That\'s What Love Is For"',
#   'url': ['/wiki/Amy_Grant'],
#   'year': '1992'},
#  {'band_singer': ['Richard Marx'],
#   'ranking': '92\n',
#   'song': ['Keep Coming Back (song)'],
#   'songurl': ['/wiki/Keep_Coming_Back_(song)'],
#   'titletext': '"Keep Coming Back (song)"',
#   'url': ['/wiki/Richard_Marx'],
#   'year': '1992'},
#  {'band_singer': ['En Vogue'],
#   'ranking': '93\n',
#   'song': ['Free Your Mind (song)'],
#   'songurl': ['/wiki/Free_Your_Mind_(song)'],
#   'titletext': '"Free Your Mind (song)"',
#   'url': ['/wiki/En_Vogue'],
#   'year': '1992'},
#  {'band_singer': ['Keith Sweat'],
#   'ranking': '94\n',
#   'song': ["Keep It Comin' (song)"],
#   'songurl': ['/wiki/Keep_It_Comin%27_(song)'],
#   'titletext': '"Keep It Comin\' (song)"',
#   'url': ['/wiki/Keith_Sweat'],
#   'year': '1992'},
#  {'band_singer': ['Mr. Big'],
#   'ranking': '95\n',
#   'song': ['Just Take My Heart (song)'],
#   'songurl': ['/wiki/Just_Take_My_Heart_(song)'],
#   'titletext': '"Just Take My Heart (song)"',
#   'url': ['/wiki/Mr._Big_(band)'],
#   'year': '1992'},
#  {'band_singer': ['Amy Grant'],
#   'ranking': '96\n',
#   'song': ['I Will Remember You (Amy Grant song)'],
#   'songurl': ['/wiki/I_Will_Remember_You_(Amy_Grant_song)'],
#   'titletext': '"I Will Remember You (Amy Grant song)"',
#   'url': ['/wiki/Amy_Grant'],
#   'year': '1992'},
#  {'band_singer': ['CeCe Peniston'],
#   'ranking': '97\n',
#   'song': ['We Got a Love Thang'],
#   'songurl': ['/wiki/We_Got_a_Love_Thang'],
#   'titletext': '"We Got a Love Thang"',
#   'url': ['/wiki/CeCe_Peniston'],
#   'year': '1992'},
#  {'band_singer': ['Def Leppard'],
#   'ranking': '98\n',
#   'song': ["Let's Get Rocked"],
#   'songurl': ['/wiki/Let%27s_Get_Rocked'],
#   'titletext': '"Let\'s Get Rocked"',
#   'url': ['/wiki/Def_Leppard'],
#   'year': '1992'},
#  {'band_singer': ['Das EFX'],
#   'ranking': '99\n',
#   'song': ['They Want EFX'],
#   'songurl': ['/wiki/They_Want_EFX'],
#   'titletext': '"They Want EFX"',
#   'url': ['/wiki/Das_EFX'],
#   'year': '1992'},
#  {'band_singer': ['Bonnie Raitt'],
#   'ranking': '100\n',
#   'song': ["I Can't Make You Love Me"],
#   'songurl': ['/wiki/I_Can%27t_Make_You_Love_Me'],
#   'titletext': '"I Can\'t Make You Love Me"',
#   'url': ['/wiki/Bonnie_Raitt'],
#   'year': '1992'},
#  {'band_singer': ['Whitney Houston'],
#   'ranking': '1\n',
#   'song': ['I Will Always Love You'],
#   'songurl': ['/wiki/I_Will_Always_Love_You#Whitney_Houston_version'],
#   'titletext': '"I Will Always Love You"',
#   'url': ['/wiki/Whitney_Houston'],
#   'year': '1993'},
#  {'band_singer': ['Tag Team'],
#   'ranking': '2\n',
#   'song': ['Whoomp! (There It Is)'],
#   'songurl': ['/wiki/Whoomp!_(There_It_Is)'],
#   'titletext': '"Whoomp! (There It Is)"',
#   'url': ['/wiki/Tag_Team_(group)'],
#   'year': '1993'},
#  {'band_singer': ['UB40'],
#   'ranking': '3\n',
#   'song': ["Can't Help Falling in Love"],
#   'songurl': ['/wiki/Can%27t_Help_Falling_in_Love'],
#   'titletext': '"Can\'t Help Falling in Love"',
#   'url': ['/wiki/UB40'],
#   'year': '1993'},
#  {'band_singer': ['Janet Jackson'],
#   'ranking': '4\n',
#   'song': ["That's the Way Love Goes (Janet Jackson song)"],
#   'songurl': ['/wiki/That%27s_the_Way_Love_Goes_(Janet_Jackson_song)'],
#   'titletext': '"That\'s the Way Love Goes (Janet Jackson song)"',
#   'url': ['/wiki/Janet_Jackson'],
#   'year': '1993'},
#  {'band_singer': ['Silk'],
#   'ranking': '5\n',
#   'song': ['Freak Me'],
#   'songurl': ['/wiki/Freak_Me'],
#   'titletext': '"Freak Me"',
#   'url': ['/wiki/Silk_(group)'],
#   'year': '1993'},
#  {'band_singer': ['SWV'],
#   'ranking': '6\n',
#   'song': ['Weak (SWV song)'],
#   'songurl': ['/wiki/Weak_(SWV_song)'],
#   'titletext': '"Weak (SWV song)"',
#   'url': ['/wiki/SWV'],
#   'year': '1993'},
#  {'band_singer': ['Shai'],
#   'ranking': '7\n',
#   'song': ['If I Ever Fall in Love'],
#   'songurl': ['/wiki/If_I_Ever_Fall_in_Love'],
#   'titletext': '"If I Ever Fall in Love"',
#   'url': ['/wiki/Shai_(band)'],
#   'year': '1993'},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '8\n',
#   'song': ['Dreamlover (song)'],
#   'songurl': ['/wiki/Dreamlover_(song)'],
#   'titletext': '"Dreamlover (song)"',
#   'url': ['/wiki/Mariah_Carey'],
#   'year': '1993'},
#  {'band_singer': ['Wreckx-n-Effect'],
#   'ranking': '9\n',
#   'song': ['Rump Shaker (song)'],
#   'songurl': ['/wiki/Rump_Shaker_(song)'],
#   'titletext': '"Rump Shaker (song)"',
#   'url': ['/wiki/Wreckx-n-Effect'],
#   'year': '1993'},
#  {'band_singer': ['Snow'],
#   'ranking': '10\n',
#   'song': ['Informer (song)'],
#   'songurl': ['/wiki/Informer_(song)'],
#   'titletext': '"Informer (song)"',
#   'url': ['/wiki/Snow_(musician)'],
#   'year': '1993'},
#  {'band_singer': ['Dr. Dre'],
#   'ranking': '11\n',
#   'song': ["Nuthin' but a 'G' Thang"],
#   'songurl': ['/wiki/Nuthin%27_but_a_%27G%27_Thang'],
#   'titletext': '"Nuthin\' but a \'G\' Thang"',
#   'url': ['/wiki/Dr._Dre'],
#   'year': '1993'},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': '12\n',
#   'song': ['In the Still of the Night (1956 song)'],
#   'songurl': ['/wiki/In_the_Still_of_the_Night_(1956_song)#Boyz_II_Men_version'],
#   'titletext': '"In the Still of the Night (1956 song)"',
#   'url': ['/wiki/Boyz_II_Men'],
#   'year': '1993'},
#  {'band_singer': ['Jade'],
#   'ranking': '13\n',
#   'song': ["Don't Walk Away (Jade song)"],
#   'songurl': ['/wiki/Don%27t_Walk_Away_(Jade_song)'],
#   'titletext': '"Don\'t Walk Away (Jade song)"',
#   'url': ['/wiki/Jade_(R%26B_group)'],
#   'year': '1993'},
#  {'band_singer': ['H-Town'],
#   'ranking': '14\n',
#   'song': ["Knockin' da Boots"],
#   'songurl': ['/wiki/Knockin%27_da_Boots'],
#   'titletext': '"Knockin\' da Boots"',
#   'url': ['/wiki/H-Town_(band)'],
#   'year': '1993'},
#  {'band_singer': ['Jodeci'],
#   'ranking': '15\n',
#   'song': ['Lately (Jodeci song)'],
#   'songurl': ['/wiki/Lately_(Jodeci_song)'],
#   'titletext': '"Lately (Jodeci song)"',
#   'url': ['/wiki/Jodeci'],
#   'year': '1993'},
#  {'band_singer': ['Duice'],
#   'ranking': '16\n',
#   'song': ['Dazzey Duks'],
#   'songurl': ['/wiki/Dazzey_Duks'],
#   'titletext': '"Dazzey Duks"',
#   'url': ['/wiki/Duice'],
#   'year': '1993'},
#  {'band_singer': ['Robin S.'],
#   'ranking': '17\n',
#   'song': ['Show Me Love (Robin S. song)'],
#   'songurl': ['/wiki/Show_Me_Love_(Robin_S._song)'],
#   'titletext': '"Show Me Love (Robin S. song)"',
#   'url': ['/wiki/Robin_S.'],
#   'year': '1993'},
#  {'band_singer': ['Peabo Bryson', 'Regina Belle'],
#   'ranking': '18\n',
#   'song': ['A Whole New World'],
#   'songurl': ['/wiki/A_Whole_New_World'],
#   'titletext': '"A Whole New World"',
#   'url': ['/wiki/Peabo_Bryson', '/wiki/Regina_Belle'],
#   'year': '1993'},
#  {'band_singer': ['Janet Jackson'],
#   'ranking': '19\n',
#   'song': ['If (Janet Jackson song)'],
#   'songurl': ['/wiki/If_(Janet_Jackson_song)'],
#   'titletext': '"If (Janet Jackson song)"',
#   'url': ['/wiki/Janet_Jackson'],
#   'year': '1993'},
#  {'band_singer': ['SWV'],
#   'ranking': '20\n',
#   'song': ["I'm So Into You"],
#   'songurl': ['/wiki/I%27m_So_Into_You'],
#   'titletext': '"I\'m So Into You"',
#   'url': ['/wiki/SWV'],
#   'year': '1993'},
#  {'band_singer': ['Vanessa Williams', 'Brian McKnight'],
#   'ranking': '21\n',
#   'song': ['Love Is (Vanessa Williams song)'],
#   'songurl': ['/wiki/Love_Is_(Vanessa_Williams_song)'],
#   'titletext': '"Love Is (Vanessa Williams song)"',
#   'url': ['/wiki/Vanessa_L._Williams', '/wiki/Brian_McKnight'],
#   'year': '1993'},
#  {'band_singer': ['Soul Asylum'],
#   'ranking': '22\n',
#   'song': ['Runaway Train (Soul Asylum song)'],
#   'songurl': ['/wiki/Runaway_Train_(Soul_Asylum_song)'],
#   'titletext': '"Runaway Train (Soul Asylum song)"',
#   'url': ['/wiki/Soul_Asylum'],
#   'year': '1993'},
#  {'band_singer': ['Exposé'],
#   'ranking': '23\n',
#   'song': ["I'll Never Get Over You (Getting Over Me)"],
#   'songurl': ['/wiki/I%27ll_Never_Get_Over_You_(Getting_Over_Me)'],
#   'titletext': '"I\'ll Never Get Over You (Getting Over Me)"',
#   'url': ['/wiki/Expos%C3%A9_(group)'],
#   'year': '1993'},
#  {'band_singer': ['Paperboy'],
#   'ranking': '24\n',
#   'song': ['Ditty (Paperboy song)'],
#   'songurl': ['/wiki/Ditty_(Paperboy_song)'],
#   'titletext': '"Ditty (Paperboy song)"',
#   'url': ['/wiki/Paperboy_(rapper)'],
#   'year': '1993'},
#  {'band_singer': ['Snap!'],
#   'ranking': '25\n',
#   'song': ['Rhythm Is a Dancer'],
#   'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#   'titletext': '"Rhythm Is a Dancer"',
#   'url': ['/wiki/Snap!'],
#   'year': '1993'},
#  {'band_singer': ['Billy Joel'],
#   'ranking': '26\n',
#   'song': ['The River of Dreams'],
#   'songurl': ['/wiki/The_River_of_Dreams'],
#   'titletext': '"The River of Dreams"',
#   'url': ['/wiki/Billy_Joel'],
#   'year': '1993'},
#  {'band_singer': ['The Proclaimers'],
#   'ranking': '27\n',
#   'song': ["I'm Gonna Be (500 Miles)"],
#   'songurl': ['/wiki/I%27m_Gonna_Be_(500_Miles)'],
#   'titletext': '"I\'m Gonna Be (500 Miles)"',
#   'url': ['/wiki/The_Proclaimers'],
#   'year': '1993'},
#  {'band_singer': ['Spin Doctors'],
#   'ranking': '28\n',
#   'song': ['Two Princes'],
#   'songurl': ['/wiki/Two_Princes'],
#   'titletext': '"Two Princes"',
#   'url': ['/wiki/Spin_Doctors'],
#   'year': '1993'},
#  {'band_singer': ['SWV'],
#   'ranking': '29\n',
#   'song': ['Right Here (SWV song)'],
#   'songurl': ['/wiki/Right_Here_(SWV_song)'],
#   'titletext': '"Right Here (SWV song)"',
#   'url': ['/wiki/SWV'],
#   'year': '1993'},
#  {'band_singer': ['Whitney Houston'],
#   'ranking': '30\n',
#   'song': ['I Have Nothing'],
#   'songurl': ['/wiki/I_Have_Nothing'],
#   'titletext': '"I Have Nothing"',
#   'url': ['/wiki/Whitney_Houston'],
#   'year': '1993'},
#  {'band_singer': ['Arrested Development'],
#   'ranking': '31\n',
#   'song': ['Mr. Wendal'],
#   'songurl': ['/wiki/Mr._Wendal'],
#   'titletext': '"Mr. Wendal"',
#   'url': ['/wiki/Arrested_Development_(group)'],
#   'year': '1993'},
#  {'band_singer': ['Rod Stewart'],
#   'ranking': '32\n',
#   'song': ['Have I Told You Lately'],
#   'songurl': ['/wiki/Have_I_Told_You_Lately'],
#   'titletext': '"Have I Told You Lately"',
#   'url': ['/wiki/Rod_Stewart'],
#   'year': '1993'},
#  {'band_singer': ['Shanice'],
#   'ranking': '33\n',
#   'song': ['Saving Forever for You'],
#   'songurl': ['/wiki/Saving_Forever_for_You'],
#   'titletext': '"Saving Forever for You"',
#   'url': ['/wiki/Shanice'],
#   'year': '1993'},
#  {'band_singer': ['Duran Duran'],
#   'ranking': '34\n',
#   'song': ['Ordinary World'],
#   'songurl': ['/wiki/Ordinary_World'],
#   'titletext': '"Ordinary World"',
#   'url': ['/wiki/Duran_Duran'],
#   'year': '1993'},
#  {'band_singer': ['Tony! Toni! Toné!'],
#   'ranking': '35\n',
#   'song': ['If I Had No Loot'],
#   'songurl': ['/wiki/If_I_Had_No_Loot'],
#   'titletext': '"If I Had No Loot"',
#   'url': ['/wiki/Tony!_Toni!_Ton%C3%A9!'],
#   'year': '1993'},
#  {'band_singer': ['Meat Loaf'],
#   'ranking': '36\n',
#   'song': ["I'd Do Anything for Love (But I Won't Do That)"],
#   'songurl': ['/wiki/I%27d_Do_Anything_for_Love_(But_I_Won%27t_Do_That)'],
#   'titletext': '"I\'d Do Anything for Love (But I Won\'t Do That)"',
#   'url': ['/wiki/Meat_Loaf'],
#   'year': '1993'},
#  {'band_singer': ['Onyx'],
#   'ranking': '37\n',
#   'song': ['Slam (Onyx song)'],
#   'songurl': ['/wiki/Slam_(Onyx_song)'],
#   'titletext': '"Slam (Onyx song)"',
#   'url': ['/wiki/Onyx_(hip_hop_group)'],
#   'year': '1993'},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '38\n',
#   'song': ['Looking Through Patient Eyes'],
#   'songurl': ['/wiki/Looking_Through_Patient_Eyes'],
#   'titletext': '"Looking Through Patient Eyes"',
#   'url': ['/wiki/P.M._Dawn'],
#   'year': '1993'},
#  {'band_singer': ['Whitney Houston'],
#   'ranking': '39\n',
#   'song': ["I'm Every Woman"],
#   'songurl': ['/wiki/I%27m_Every_Woman#Whitney_Houston_version'],
#   'titletext': '"I\'m Every Woman"',
#   'url': ['/wiki/Whitney_Houston'],
#   'year': '1993'},
#  {'band_singer': ['Shai'],
#   'ranking': '40\n',
#   'song': ["I'm Every Woman"],
#   'songurl': [None],
#   'titletext': ["I'm Every Woman"],
#   'url': ['/wiki/Shai_(band)'],
#   'year': '1993'},
#  {'band_singer': ['Duran Duran'],
#   'ranking': '41\n',
#   'song': ['Come Undone (Duran Duran song)'],
#   'songurl': ['/wiki/Come_Undone_(Duran_Duran_song)'],
#   'titletext': '"Come Undone (Duran Duran song)"',
#   'url': ['/wiki/Duran_Duran'],
#   'year': '1993'},
#  {'band_singer': ['Tina Turner'],
#   'ranking': '42\n',
#   'song': ["I Don't Wanna Fight"],
#   'songurl': ['/wiki/I_Don%27t_Wanna_Fight'],
#   'titletext': '"I Don\'t Wanna Fight"',
#   'url': ['/wiki/Tina_Turner'],
#   'year': '1993'},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '43\n',
#   'song': ["I'd Die Without You"],
#   'songurl': ['/wiki/I%27d_Die_Without_You'],
#   'titletext': '"I\'d Die Without You"',
#   'url': ['/wiki/P.M._Dawn'],
#   'year': '1993'},
#  {'band_singer': ['95 South'],
#   'ranking': '44\n',
#   'song': ['Whoot, There It Is'],
#   'songurl': ['/wiki/Whoot,_There_It_Is'],
#   'titletext': '"Whoot, There It Is"',
#   'url': ['/wiki/95_South'],
#   'year': '1993'},
#  {'band_singer': ['Naughty by Nature'],
#   'ranking': '45\n',
#   'song': ['Hip Hop Hooray'],
#   'songurl': ['/wiki/Hip_Hop_Hooray'],
#   'titletext': '"Hip Hop Hooray"',
#   'url': ['/wiki/Naughty_by_Nature'],
#   'year': '1993'},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': '46\n',
#   'song': ['Another Sad Love Song'],
#   'songurl': ['/wiki/Another_Sad_Love_Song'],
#   'titletext': '"Another Sad Love Song"',
#   'url': ['/wiki/Toni_Braxton'],
#   'year': '1993'},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '47\n',
#   'song': ['Will You Be There'],
#   'songurl': ['/wiki/Will_You_Be_There'],
#   'titletext': '"Will You Be There"',
#   'url': ['/wiki/Michael_Jackson'],
#   'year': '1993'},
#  {'band_singer': ['Shai'],
#   'ranking': '48\n',
#   'song': ['Comforter (song)'],
#   'songurl': ['/wiki/Comforter_(song)'],
#   'titletext': '"Comforter (song)"',
#   'url': ['/wiki/Shai_(band)'],
#   'year': '1993'},
#  {'band_singer': ['Bobby Brown'],
#   'ranking': '49\n',
#   'song': ['Comforter (song)'],
#   'songurl': [None],
#   'titletext': ['Comforter (song)'],
#   'url': ['/wiki/Bobby_Brown'],
#   'year': '1993'},
#  {'band_singer': ['4 Non Blondes'],
#   'ranking': '50\n',
#   'song': ["What's Up? (4 Non Blondes song)"],
#   'songurl': ['/wiki/What%27s_Up%3F_(4_Non_Blondes_song)'],
#   'titletext': '"What\'s Up? (4 Non Blondes song)"',
#   'url': ['/wiki/4_Non_Blondes'],
#   'year': '1993'},
#  {'band_singer': ['Ace of Base'],
#   'ranking': '51\n',
#   'song': ['All That She Wants'],
#   'songurl': ['/wiki/All_That_She_Wants'],
#   'titletext': '"All That She Wants"',
#   'url': ['/wiki/Ace_of_Base'],
#   'year': '1993'},
#  {'band_singer': ['Prince', 'The New Power Generation'],
#   'ranking': '52\n',
#   'song': ['7 (song)'],
#   'songurl': ['/wiki/7_(song)'],
#   'titletext': '"7 (song)"',
#   'url': ['/wiki/Prince_(musician)', '/wiki/The_New_Power_Generation'],
#   'year': '1993'},
#  {'band_singer': ['Dr. Dre', 'Snoop Doggy Dogg'],
#   'ranking': '53\n',
#   'song': ["Fuck wit Dre Day (And Everybody's Celebratin')"],
#   'songurl': ['/wiki/Fuck_wit_Dre_Day_(And_Everybody%27s_Celebratin%27)'],
#   'titletext': '"Fuck wit Dre Day (And Everybody\'s Celebratin\')"',
#   'url': ['/wiki/Dr._Dre', '/wiki/Snoop_Dogg'],
#   'year': '1993'},
#  {'band_singer': ['Brian McKnight'],
#   'ranking': '54\n',
#   'song': ['One Last Cry'],
#   'songurl': ['/wiki/One_Last_Cry'],
#   'titletext': '"One Last Cry"',
#   'url': ['/wiki/Brian_McKnight'],
#   'year': '1993'},
#  {'band_singer': ['Xscape'],
#   'ranking': '55\n',
#   'song': ["Just Kickin' It"],
#   'songurl': ['/wiki/Just_Kickin%27_It'],
#   'titletext': '"Just Kickin\' It"',
#   'url': ['/wiki/Xscape_(band)'],
#   'year': '1993'},
#  {'band_singer': ['2Pac'],
#   'ranking': '56\n',
#   'song': ['I Get Around (Tupac Shakur song)'],
#   'songurl': ['/wiki/I_Get_Around_(Tupac_Shakur_song)'],
#   'titletext': '"I Get Around (Tupac Shakur song)"',
#   'url': ['/wiki/Tupac_Shakur'],
#   'year': '1993'},
#  {'band_singer': ['Bon Jovi'],
#   'ranking': '57\n',
#   'song': ['Bed of Roses (Bon Jovi song)'],
#   'songurl': ['/wiki/Bed_of_Roses_(Bon_Jovi_song)'],
#   'titletext': '"Bed of Roses (Bon Jovi song)"',
#   'url': ['/wiki/Bon_Jovi'],
#   'year': '1993'},
#  {'band_singer': ['Mary J. Blige'],
#   'ranking': '58\n',
#   'song': ['Real Love (Mary J. Blige song)'],
#   'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#   'titletext': '"Real Love (Mary J. Blige song)"',
#   'url': ['/wiki/Mary_J._Blige'],
#   'year': '1993'},
#  {'band_singer': ['Portrait'],
#   'ranking': '59\n',
#   'song': ['Real Love (Mary J. Blige song)'],
#   'songurl': [None],
#   'titletext': ['Real Love (Mary J. Blige song)'],
#   'url': ['/wiki/Portrait_(band)'],
#   'year': '1993'},
#  {'band_singer': ['Aerosmith'],
#   'ranking': '60\n',
#   'song': ["Cryin'"],
#   'songurl': ['/wiki/Cryin%27'],
#   'titletext': '"Cryin\'"',
#   'url': ['/wiki/Aerosmith'],
#   'year': '1993'},
#  {'band_singer': ['Ugly Kid Joe'],
#   'ranking': '61\n',
#   'song': ["Cat's in the Cradle"],
#   'songurl': ['/wiki/Cat%27s_in_the_Cradle'],
#   'titletext': '"Cat\'s in the Cradle"',
#   'url': ['/wiki/Ugly_Kid_Joe'],
#   'year': '1993'},
#  {'band_singer': ['TLC'],
#   'ranking': '62\n',
#   'song': ['What About Your Friends'],
#   'songurl': ['/wiki/What_About_Your_Friends'],
#   'titletext': '"What About Your Friends"',
#   'url': ['/wiki/TLC_(group)'],
#   'year': '1993'},
#  {'band_singer': ['Positive K'],
#   'ranking': '63\n',
#   'song': ['I Got a Man'],
#   'songurl': ['/wiki/I_Got_a_Man'],
#   'titletext': '"I Got a Man"',
#   'url': ['/wiki/Positive_K'],
#   'year': '1993'},
#  {'band_singer': ['Zhané'],
#   'ranking': '64\n',
#   'song': ['Hey Mr. D.J.'],
#   'songurl': ['/wiki/Hey_Mr._D.J.'],
#   'titletext': '"Hey Mr. D.J."',
#   'url': ['/wiki/Zhan%C3%A9'],
#   'year': '1993'},
#  {'band_singer': ['Cypress Hill'],
#   'ranking': '65\n',
#   'song': ['Insane in the Brain'],
#   'songurl': ['/wiki/Insane_in_the_Brain'],
#   'titletext': '"Insane in the Brain"',
#   'url': ['/wiki/Cypress_Hill'],
#   'year': '1993'},
#  {'band_singer': ['Madonna'],
#   'ranking': '66\n',
#   'song': ['Deeper and Deeper'],
#   'songurl': ['/wiki/Deeper_and_Deeper'],
#   'titletext': '"Deeper and Deeper"',
#   'url': ['/wiki/Madonna_(entertainer)'],
#   'year': '1993'},
#  {'band_singer': ['Madonna'],
#   'ranking': '67\n',
#   'song': ['Rain (Madonna song)'],
#   'songurl': ['/wiki/Rain_(Madonna_song)'],
#   'titletext': '"Rain (Madonna song)"',
#   'url': ['/wiki/Madonna_(entertainer)'],
#   'year': '1993'},
#  {'band_singer': ['Jeremy Jordan'],
#   'ranking': '68\n',
#   'song': ['The Right Kind of Love'],
#   'songurl': ['/wiki/The_Right_Kind_of_Love'],
#   'titletext': '"The Right Kind of Love"',
#   'url': ['/wiki/Jeremy_Jordan_(singer,_born_1973)'],
#   'year': '1993'},
#  {'band_singer': ['Inner Circle'],
#   'ranking': '69\n',
#   'song': ['Bad Boys (Inner Circle song)', 'Cops (TV series)'],
#   'songurl': ['/wiki/Bad_Boys_(Inner_Circle_song)', '/wiki/Cops_(TV_series)'],
#   'titletext': '"Bad Boys (Inner Circle song)" / "Cops (TV series)"',
#   'url': ['/wiki/Inner_Circle_(reggae_band)'],
#   'year': '1993'},
#  {'band_singer': ['Boy Krazy'],
#   'ranking': '70\n',
#   'song': ["That's What Love Can Do"],
#   'songurl': ['/wiki/That%27s_What_Love_Can_Do'],
#   'titletext': '"That\'s What Love Can Do"',
#   'url': ['/wiki/Boy_Krazy'],
#   'year': '1993'},
#  {'band_singer': ['Jon Secada'],
#   'ranking': '71\n',
#   'song': ['Do You Believe in Us'],
#   'songurl': ['/wiki/Do_You_Believe_in_Us'],
#   'titletext': '"Do You Believe in Us"',
#   'url': ['/wiki/Jon_Secada'],
#   'year': '1993'},
#  {'band_singer': ['Jon Secada'],
#   'ranking': '72\n',
#   'song': ['Angel (Jon Secada song)'],
#   'songurl': ['/wiki/Angel_(Jon_Secada_song)'],
#   'titletext': '"Angel (Jon Secada song)"',
#   'url': ['/wiki/Jon_Secada'],
#   'year': '1993'},
#  {'band_singer': ['Kenny G'],
#   'ranking': '73\n',
#   'song': ['Forever in Love (instrumental)'],
#   'songurl': ['/wiki/Forever_in_Love_(instrumental)'],
#   'titletext': '"Forever in Love (instrumental)"',
#   'url': ['/wiki/Kenny_G'],
#   'year': '1993'},
#  {'band_singer': ['Janet Jackson'],
#   'ranking': '74\n',
#   'song': ['Again (Janet Jackson song)'],
#   'songurl': ['/wiki/Again_(Janet_Jackson_song)'],
#   'titletext': '"Again (Janet Jackson song)"',
#   'url': ['/wiki/Janet_Jackson'],
#   'year': '1993'},
#  {'band_singer': ['DJ Jazzy Jeff & The Fresh Prince'],
#   'ranking': '75\n',
#   'song': ['Boom! Shake the Room'],
#   'songurl': ['/wiki/Boom!_Shake_the_Room'],
#   'titletext': '"Boom! Shake the Room"',
#   'url': ['/wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince'],
#   'year': '1993'},
#  {'band_singer': ['Restless Heart'],
#   'ranking': '76\n',
#   'song': ['When She Cries'],
#   'songurl': ['/wiki/When_She_Cries'],
#   'titletext': '"When She Cries"',
#   'url': ['/wiki/Restless_Heart'],
#   'year': '1993'},
#  {'band_singer': ['Inner Circle'],
#   'ranking': '77\n',
#   'song': ['Sweat (A La La La La Long)'],
#   'songurl': ['/wiki/Sweat_(A_La_La_La_La_Long)'],
#   'titletext': '"Sweat (A La La La La Long)"',
#   'url': ['/wiki/Inner_Circle_(reggae_band)'],
#   'year': '1993'},
#  {'band_singer': ['Ice Cube'],
#   'ranking': '78\n',
#   'song': ['It Was a Good Day'],
#   'songurl': ['/wiki/It_Was_a_Good_Day'],
#   'titletext': '"It Was a Good Day"',
#   'url': ['/wiki/Ice_Cube'],
#   'year': '1993'},
#  {'band_singer': ['Captain Hollywood Project'],
#   'ranking': '79\n',
#   'song': ['More and More (Captain Hollywood Project song)'],
#   'songurl': ['/wiki/More_and_More_(Captain_Hollywood_Project_song)'],
#   'titletext': '"More and More (Captain Hollywood Project song)"',
#   'url': ['/wiki/Captain_Hollywood_Project'],
#   'year': '1993'},
#  {'band_singer': ['The Heights'],
#   'ranking': '80\n',
#   'song': ['How Do You Talk to an Angel'],
#   'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#   'titletext': '"How Do You Talk to an Angel"',
#   'url': ['/wiki/The_Heights_(American_TV_series)'],
#   'year': '1993'},
#  {'band_singer': ['Digable Planets'],
#   'ranking': '81\n',
#   'song': ['Rebirth of Slick (Cool Like Dat)'],
#   'songurl': ['/wiki/Rebirth_of_Slick_(Cool_Like_Dat)'],
#   'titletext': '"Rebirth of Slick (Cool Like Dat)"',
#   'url': ['/wiki/Digable_Planets'],
#   'year': '1993'},
#  {'band_singer': ['Haddaway'],
#   'ranking': '82\n',
#   'song': ['What Is Love (Haddaway song)'],
#   'songurl': ['/wiki/What_Is_Love_(Haddaway_song)'],
#   'titletext': '"What Is Love (Haddaway song)"',
#   'url': ['/wiki/Haddaway'],
#   'year': '1993'},
#  {'band_singer': ['Michael Bolton'],
#   'ranking': '83\n',
#   'song': ['To Love Somebody (song)'],
#   'songurl': ['/wiki/To_Love_Somebody_(song)'],
#   'titletext': '"To Love Somebody (song)"',
#   'url': ['/wiki/Michael_Bolton'],
#   'year': '1993'},
#  {'band_singer': ['En Vogue'],
#   'ranking': '84\n',
#   'song': ['Give It Up, Turn It Loose'],
#   'songurl': ['/wiki/Give_It_Up,_Turn_It_Loose'],
#   'titletext': '"Give It Up, Turn It Loose"',
#   'url': ['/wiki/En_Vogue'],
#   'year': '1993'},
#  {'band_singer': ['Kris Kross'],
#   'ranking': '85\n',
#   'song': ['Alright (Kris Kross song)'],
#   'songurl': ['/wiki/Alright_(Kris_Kross_song)'],
#   'titletext': '"Alright (Kris Kross song)"',
#   'url': ['/wiki/Kris_Kross'],
#   'year': '1993'},
#  {'band_singer': ['Ice Cube', 'Das EFX'],
#   'ranking': '86\n',
#   'song': ['Check Yo Self'],
#   'songurl': ['/wiki/Check_Yo_Self'],
#   'titletext': '"Check Yo Self"',
#   'url': ['/wiki/Ice_Cube', '/wiki/Das_EFX'],
#   'year': '1993'},
#  {'band_singer': ['Sting'],
#   'ranking': '87\n',
#   'song': ['Fields of Gold'],
#   'songurl': ['/wiki/Fields_of_Gold'],
#   'titletext': '"Fields of Gold"',
#   'url': ['/wiki/Sting_(musician)'],
#   'year': '1993'},
#  {'band_singer': ['Dino'],
#   'ranking': '88\n',
#   'song': ['Ooh Child'],
#   'songurl': ['/wiki/Ooh_Child'],
#   'titletext': '"Ooh Child"',
#   'url': ['/wiki/Dino_(singer)'],
#   'year': '1993'},
#  {'band_singer': ['Go West'],
#   'ranking': '89\n',
#   'song': ['Faithful (Go West song)'],
#   'songurl': ['/wiki/Faithful_(Go_West_song)'],
#   'titletext': '"Faithful (Go West song)"',
#   'url': ['/wiki/Go_West_(band)'],
#   'year': '1993'},
#  {'band_singer': ['Rod Stewart'],
#   'ranking': '90\n',
#   'song': ['Reason to Believe'],
#   'songurl': ['/wiki/Reason_to_Believe'],
#   'titletext': '"Reason to Believe"',
#   'url': ['/wiki/Rod_Stewart'],
#   'year': '1993'},
#  {'band_singer': ['Tears for Fears'],
#   'ranking': '91\n',
#   'song': ['Break It Down Again'],
#   'songurl': ['/wiki/Break_It_Down_Again'],
#   'titletext': '"Break It Down Again"',
#   'url': ['/wiki/Tears_for_Fears'],
#   'year': '1993'},
#  {'band_singer': ['Joey Lawrence'],
#   'ranking': '92\n',
#   'song': ["Nothin' My Love Can't Fix"],
#   'songurl': ['/wiki/Nothin%27_My_Love_Can%27t_Fix'],
#   'titletext': '"Nothin\' My Love Can\'t Fix"',
#   'url': ['/wiki/Joey_Lawrence'],
#   'year': '1993'},
#  {'band_singer': ['Green Jellÿ'],
#   'ranking': '93\n',
#   'song': ['Three Little Pigs (song)'],
#   'songurl': ['/wiki/Three_Little_Pigs_(song)'],
#   'titletext': '"Three Little Pigs (song)"',
#   'url': ['/wiki/Green_Jell%C3%BF'],
#   'year': '1993'},
#  {'band_singer': ['Aerosmith'],
#   'ranking': '94\n',
#   'song': ["Livin' on the Edge"],
#   'songurl': ['/wiki/Livin%27_on_the_Edge'],
#   'titletext': '"Livin\' on the Edge"',
#   'url': ['/wiki/Aerosmith'],
#   'year': '1993'},
#  {'band_singer': ['Gin Blossoms'],
#   'ranking': '95\n',
#   'song': ['Hey Jealousy'],
#   'songurl': ['/wiki/Hey_Jealousy'],
#   'titletext': '"Hey Jealousy"',
#   'url': ['/wiki/Gin_Blossoms'],
#   'year': '1993'},
#  {'band_singer': ['Sting'],
#   'ranking': '96\n',
#   'song': ['If I Ever Lose My Faith in You'],
#   'songurl': ['/wiki/If_I_Ever_Lose_My_Faith_in_You'],
#   'titletext': '"If I Ever Lose My Faith in You"',
#   'url': ['/wiki/Sting_(musician)'],
#   'year': '1993'},
#  {'band_singer': ['Tony! Toni! Toné!'],
#   'ranking': '97\n',
#   'song': ['Anniversary (Tony! Toni! Toné! song)'],
#   'songurl': ['/wiki/Anniversary_(Tony!_Toni!_Ton%C3%A9!_song)'],
#   'titletext': '"Anniversary (Tony! Toni! Toné! song)"',
#   'url': ['/wiki/Tony!_Toni!_Ton%C3%A9!'],
#   'year': '1993'},
#  {'band_singer': ['Jade'],
#   'ranking': '98\n',
#   'song': ['One Woman'],
#   'songurl': ['/wiki/One_Woman'],
#   'titletext': '"One Woman"',
#   'url': ['/wiki/Jade_(American_band)'],
#   'year': '1993'},
#  {'band_singer': ['Taylor Dayne'],
#   'ranking': '99\n',
#   'song': ["Can't Get Enough of Your Love"],
#   'songurl': ['/wiki/Can%27t_Get_Enough_of_Your_Love#Taylor_Dayne_version'],
#   'titletext': '"Can\'t Get Enough of Your Love"',
#   'url': ['/wiki/Taylor_Dayne'],
#   'year': '1993'},
#  {'band_singer': ['Def Leppard'],
#   'ranking': '100\n',
#   'song': ['Two Steps Behind'],
#   'songurl': ['/wiki/Two_Steps_Behind'],
#   'titletext': '"Two Steps Behind"',
#   'url': ['/wiki/Def_Leppard'],
#   'year': '1993'},
#  {'band_singer': ['Ace of Base'],
#   'ranking': '1\n',
#   'song': ['The Sign (song)'],
#   'songurl': ['/wiki/The_Sign_(song)'],
#   'titletext': '"The Sign (song)"',
#   'url': ['/wiki/Ace_of_Base'],
#   'year': '1994'},
# ...
#   'song': ["Don't Tell Me (Madonna song)"],
#   'songurl': ['/wiki/Don%27t_Tell_Me_(Madonna_song)'],
#   'titletext': '"Don\'t Tell Me (Madonna song)"',
#   'url': ['/wiki/Madonna_(entertainer)'],
#   'year': '2001'},
#  {'band_singer': ['Missy Elliott'],
#   'ranking': '35\n',
#   'song': ['Get Ur Freak On'],
#   'songurl': ['/wiki/Get_Ur_Freak_On'],
#   'titletext': '"Get Ur Freak On"',
#   'url': ['/wiki/Missy_Elliott'],
#   'year': '2001'},
#  {'band_singer': ['K-Ci & JoJo'],
#   'ranking': '36\n',
#   'song': ['Crazy (K-Ci and JoJo song)'],
#   'songurl': ['/wiki/Crazy_(K-Ci_and_JoJo_song)'],
#   'titletext': '"Crazy (K-Ci and JoJo song)"',
#   'url': ['/wiki/K-Ci_%26_JoJo'],
#   'year': '2001'},
#  {'band_singer': ['Craig David'],
#   'ranking': '37\n',
#   'song': ['Fill Me In'],
#   'songurl': ['/wiki/Fill_Me_In'],
#   'titletext': '"Fill Me In"',
#   'url': ['/wiki/Craig_David'],
#   'year': '2001'},
#  {'band_singer': ['Janet Jackson'],
#   'ranking': '38\n',
#   'song': ['Someone to Call My Lover'],
#   'songurl': ['/wiki/Someone_to_Call_My_Lover'],
#   'titletext': '"Someone to Call My Lover"',
#   'url': ['/wiki/Janet_Jackson'],
#   'year': '2001'},
#  {'band_singer': ['Creed'],
#   'ranking': '39\n',
#   'song': ['With Arms Wide Open'],
#   'songurl': ['/wiki/With_Arms_Wide_Open'],
#   'titletext': '"With Arms Wide Open"',
#   'url': ['/wiki/Creed_(band)'],
#   'year': '2001'},
#  {'band_singer': ['Mýa'],
#   'ranking': '40\n',
#   'song': ['Case of the Ex'],
#   'songurl': ['/wiki/Case_of_the_Ex'],
#   'titletext': '"Case of the Ex"',
#   'url': ['/wiki/M%C3%BDa'],
#   'year': '2001'},
#  {'band_singer': ['O-Town'],
#   'ranking': '41\n',
#   'song': ['All or Nothing (O-Town song)'],
#   'songurl': ['/wiki/All_or_Nothing_(O-Town_song)'],
#   'titletext': '"All or Nothing (O-Town song)"',
#   'url': ['/wiki/O-Town'],
#   'year': '2001'},
#  {'band_singer': ["Destiny's Child"],
#   'ranking': '42\n',
#   'song': ['Bootylicious'],
#   'songurl': ['/wiki/Bootylicious'],
#   'titletext': '"Bootylicious"',
#   'url': ['/wiki/Destiny%27s_Child'],
#   'year': '2001'},
#  {'band_singer': ['Nelly Furtado'],
#   'ranking': '43\n',
#   'song': ["I'm Like a Bird"],
#   'songurl': ['/wiki/I%27m_Like_a_Bird'],
#   'titletext': '"I\'m Like a Bird"',
#   'url': ['/wiki/Nelly_Furtado'],
#   'year': '2001'},
#  {'band_singer': ['3 Doors Down'],
#   'ranking': '44\n',
#   'song': ['Kryptonite (3 Doors Down song)'],
#   'songurl': ['/wiki/Kryptonite_(3_Doors_Down_song)'],
#   'titletext': '"Kryptonite (3 Doors Down song)"',
#   'url': ['/wiki/3_Doors_Down'],
#   'year': '2001'},
#  {'band_singer': ['R. Kelly', 'Jay-Z'],
#   'ranking': '45\n',
#   'song': ['Fiesta (R. Kelly song)'],
#   'songurl': ['/wiki/Fiesta_(R._Kelly_song)'],
#   'titletext': '"Fiesta (R. Kelly song)"',
#   'url': ['/wiki/R._Kelly', '/wiki/Jay-Z'],
#   'year': '2001'},
#  {'band_singer': ['Sugar Ray'],
#   'ranking': '46\n',
#   'song': ["When It's Over (Sugar Ray song)"],
#   'songurl': ['/wiki/When_It%27s_Over_(Sugar_Ray_song)'],
#   'titletext': '"When It\'s Over (Sugar Ray song)"',
#   'url': ['/wiki/Sugar_Ray'],
#   'year': '2001'},
#  {'band_singer': ['Aerosmith'],
#   'ranking': '47\n',
#   'song': ['Jaded (Aerosmith song)'],
#   'songurl': ['/wiki/Jaded_(Aerosmith_song)'],
#   'titletext': '"Jaded (Aerosmith song)"',
#   'url': ['/wiki/Aerosmith'],
#   'year': '2001'},
#  {'band_singer': ['Jagged Edge'],
#   'ranking': '48\n',
#   'song': ['Promise (Jagged Edge song)'],
#   'songurl': ['/wiki/Promise_(Jagged_Edge_song)'],
#   'titletext': '"Promise (Jagged Edge song)"',
#   'url': ['/wiki/Jagged_Edge_(band)'],
#   'year': '2001'},
#  {'band_singer': ['Case'],
#   'ranking': '49\n',
#   'song': ['Missing You (Case song)'],
#   'songurl': ['/wiki/Missing_You_(Case_song)'],
#   'titletext': '"Missing You (Case song)"',
#   'url': ['/wiki/Case_(singer)'],
#   'year': '2001'},
#  {'band_singer': ['Ginuwine'],
#   'ranking': '50\n',
#   'song': ['Differences (song)'],
#   'songurl': ['/wiki/Differences_(song)'],
#   'titletext': '"Differences (song)"',
#   'url': ['/wiki/Ginuwine'],
#   'year': '2001'},
#  {'band_singer': ["'N Sync"],
#   'ranking': '51\n',
#   'song': ['This I Promise You'],
#   'songurl': ['/wiki/This_I_Promise_You'],
#   'titletext': '"This I Promise You"',
#   'url': ['/wiki/%27N_Sync'],
#   'year': '2001'},
#  {'band_singer': ['Jay-Z'],
#   'ranking': '52\n',
#   'song': ['Izzo (H.O.V.A.)'],
#   'songurl': ['/wiki/Izzo_(H.O.V.A.)'],
#   'titletext': '"Izzo (H.O.V.A.)"',
#   'url': ['/wiki/Jay-Z'],
#   'year': '2001'},
#  {'band_singer': ["Lil' Mo", 'Fabolous'],
#   'ranking': '53\n',
#   'song': ['Superwoman Pt. II'],
#   'songurl': ['/wiki/Superwoman_Pt._II'],
#   'titletext': '"Superwoman Pt. II"',
#   'url': ['/wiki/Lil%27_Mo', '/wiki/Fabolous'],
#   'year': '2001'},
#  {'band_singer': ['Evan and Jaron'],
#   'ranking': '54\n',
#   'song': ['Crazy for This Girl'],
#   'songurl': ['/wiki/Crazy_for_This_Girl'],
#   'titletext': '"Crazy for This Girl"',
#   'url': ['/wiki/Evan_and_Jaron'],
#   'year': '2001'},
#  {'band_singer': ['Ricky Martin', 'Christina Aguilera'],
#   'ranking': '55\n',
#   'song': ['Nobody Wants to Be Lonely'],
#   'songurl': ['/wiki/Nobody_Wants_to_Be_Lonely'],
#   'titletext': '"Nobody Wants to Be Lonely"',
#   'url': ['/wiki/Ricky_Martin', '/wiki/Christina_Aguilera'],
#   'year': '2001'},
#  {'band_singer': ['Jay-Z'],
#   'ranking': '56\n',
#   'song': ['I Just Wanna Love U (Give It 2 Me)'],
#   'songurl': ['/wiki/I_Just_Wanna_Love_U_(Give_It_2_Me)'],
#   'titletext': '"I Just Wanna Love U (Give It 2 Me)"',
#   'url': ['/wiki/Jay-Z'],
#   'year': '2001'},
#  {'band_singer': ['Missy Elliott', 'Ludacris'],
#   'ranking': '57\n',
#   'song': ['One Minute Man'],
#   'songurl': ['/wiki/One_Minute_Man'],
#   'titletext': '"One Minute Man"',
#   'url': ['/wiki/Missy_Elliott', '/wiki/Ludacris'],
#   'year': '2001'},
#  {'band_singer': ['Mystikal', 'Nivea'],
#   'ranking': '58\n',
#   'song': ['Danger (Been So Long)'],
#   'songurl': ['/wiki/Danger_(Been_So_Long)'],
#   'titletext': '"Danger (Been So Long)"',
#   'url': ['/wiki/Mystikal', '/wiki/Nivea_(singer)'],
#   'year': '2001'},
#  {'band_singer': ['Enya'],
#   'ranking': '59\n',
#   'song': ['Only Time'],
#   'songurl': ['/wiki/Only_Time'],
#   'titletext': '"Only Time"',
#   'url': ['/wiki/Enya'],
#   'year': '2001'},
#  {'band_singer': ['Toya'],
#   'ranking': '60\n',
#   'song': ['I Do!!'],
#   'songurl': ['/wiki/I_Do!!'],
#   'titletext': '"I Do!!"',
#   'url': ['/wiki/Toya_(singer)'],
#   'year': '2001'},
#  {'band_singer': ['S Club 7'],
#   'ranking': '61\n',
#   'song': ['Never Had a Dream Come True'],
#   'songurl': ['/wiki/Never_Had_a_Dream_Come_True'],
#   'titletext': '"Never Had a Dream Come True"',
#   'url': ['/wiki/S_Club_7'],
#   'year': '2001'},
#  {'band_singer': ['Tamia'],
#   'ranking': '62\n',
#   'song': ['Stranger in My House (Tamia song)'],
#   'songurl': ['/wiki/Stranger_in_My_House_(Tamia_song)'],
#   'titletext': '"Stranger in My House (Tamia song)"',
#   'url': ['/wiki/Tamia'],
#   'year': '2001'},
#  {'band_singer': ['Jessica Simpson'],
#   'ranking': '63\n',
#   'song': ['Irresistible (Jessica Simpson song)'],
#   'songurl': ['/wiki/Irresistible_(Jessica_Simpson_song)'],
#   'titletext': '"Irresistible (Jessica Simpson song)"',
#   'url': ['/wiki/Jessica_Simpson'],
#   'year': '2001'},
#  {'band_singer': ['Sunshine Anderson'],
#   'ranking': '64\n',
#   'song': ['Heard It All Before (song)'],
#   'songurl': ['/wiki/Heard_It_All_Before_(song)'],
#   'titletext': '"Heard It All Before (song)"',
#   'url': ['/wiki/Sunshine_Anderson'],
#   'year': '2001'},
#  {'band_singer': ['Dave Matthews Band'],
#   'ranking': '65\n',
#   'song': ['The Space Between'],
#   'songurl': ['/wiki/The_Space_Between'],
#   'titletext': '"The Space Between"',
#   'url': ['/wiki/Dave_Matthews_Band'],
#   'year': '2001'},
#  {'band_singer': ['Faith Hill'],
#   'ranking': '66\n',
#   'song': ["There You'll Be"],
#   'songurl': ['/wiki/There_You%27ll_Be'],
#   'titletext': '"There You\'ll Be"',
#   'url': ['/wiki/Faith_Hill'],
#   'year': '2001'},
#  {'band_singer': ['Musiq Soulchild'],
#   'ranking': '67\n',
#   'song': ['Love (Musiq Soulchild song)'],
#   'songurl': ['/wiki/Love_(Musiq_Soulchild_song)'],
#   'titletext': '"Love (Musiq Soulchild song)"',
#   'url': ['/wiki/Musiq_Soulchild'],
#   'year': '2001'},
#  {'band_singer': ['112'],
#   'ranking': '68\n',
#   'song': ["It's Over Now (112 song)"],
#   'songurl': ['/wiki/It%27s_Over_Now_(112_song)'],
#   'titletext': '"It\'s Over Now (112 song)"',
#   'url': ['/wiki/112_(band)'],
#   'year': '2001'},
#  {'band_singer': ['3LW'],
#   'ranking': '69\n',
#   'song': ["No More (Baby I'ma Do Right)"],
#   'songurl': ['/wiki/No_More_(Baby_I%27ma_Do_Right)'],
#   'titletext': '"No More (Baby I\'ma Do Right)"',
#   'url': ['/wiki/3LW'],
#   'year': '2001'},
#  {'band_singer': ['Nelly Furtado'],
#   'ranking': '70\n',
#   'song': ['Turn Off the Light'],
#   'songurl': ['/wiki/Turn_Off_the_Light'],
#   'titletext': '"Turn Off the Light"',
#   'url': ['/wiki/Nelly_Furtado'],
#   'year': '2001'},
#  {'band_singer': ['Brooks & Dunn'],
#   'ranking': '71\n',
#   'song': ["Ain't Nothing 'bout You"],
#   'songurl': ['/wiki/Ain%27t_Nothing_%27bout_You'],
#   'titletext': '"Ain\'t Nothing \'bout You"',
#   'url': ['/wiki/Brooks_%26_Dunn'],
#   'year': '2001'},
#  {'band_singer': ['Jennifer Lopez'],
#   'ranking': '72\n',
#   'song': ['Play (Jennifer Lopez song)'],
#   'songurl': ['/wiki/Play_(Jennifer_Lopez_song)'],
#   'titletext': '"Play (Jennifer Lopez song)"',
#   'url': ['/wiki/Jennifer_Lopez'],
#   'year': '2001'},
#  {'band_singer': ['Lonestar'],
#   'ranking': '73\n',
#   'song': ["I'm Already There (song)"],
#   'songurl': ['/wiki/I%27m_Already_There_(song)'],
#   'titletext': '"I\'m Already There (song)"',
#   'url': ['/wiki/Lonestar'],
#   'year': '2001'},
#  {'band_singer': ["Lil' Romeo"],
#   'ranking': '74\n',
#   'song': ["My Baby (Lil' Romeo song)"],
#   'songurl': ['/wiki/My_Baby_(Lil%27_Romeo_song)'],
#   'titletext': '"My Baby (Lil\' Romeo song)"',
#   'url': ['/wiki/Romeo_Miller'],
#   'year': '2001'},
#  {'band_singer': ['U2'],
#   'ranking': '75\n',
#   'song': ['Beautiful Day'],
#   'songurl': ['/wiki/Beautiful_Day'],
#   'titletext': '"Beautiful Day"',
#   'url': ['/wiki/U2'],
#   'year': '2001'},
#  {'band_singer': ['Blake Shelton'],
#   'ranking': '76\n',
#   'song': ['Austin (song)'],
#   'songurl': ['/wiki/Austin_(song)'],
#   'titletext': '"Austin (song)"',
#   'url': ['/wiki/Blake_Shelton'],
#   'year': '2001'},
#  {'band_singer': ['Ludacris'],
#   'ranking': '77\n',
#   'song': ['Southern Hospitality (song)'],
#   'songurl': ['/wiki/Southern_Hospitality_(song)'],
#   'titletext': '"Southern Hospitality (song)"',
#   'url': ['/wiki/Ludacris'],
#   'year': '2001'},
#  {'band_singer': ['Tim McGraw'],
#   'ranking': '78\n',
#   'song': ["Grown Men Don't Cry"],
#   'songurl': ['/wiki/Grown_Men_Don%27t_Cry'],
#   'titletext': '"Grown Men Don\'t Cry"',
#   'url': ['/wiki/Tim_McGraw'],
#   'year': '2001'},
#  {'band_singer': ['Ja Rule', 'Case'],
#   'ranking': '79\n',
#   'song': ["Livin' It Up (Ja Rule song)"],
#   'songurl': ['/wiki/Livin%27_It_Up_(Ja_Rule_song)'],
#   'titletext': '"Livin\' It Up (Ja Rule song)"',
#   'url': ['/wiki/Ja_Rule', '/wiki/Case_(singer)'],
#   'year': '2001'},
#  {'band_singer': ['Mariah Carey', 'Cameo'],
#   'ranking': '80\n',
#   'song': ['Loverboy (Mariah Carey song)'],
#   'songurl': ['/wiki/Loverboy_(Mariah_Carey_song)'],
#   'titletext': '"Loverboy (Mariah Carey song)"',
#   'url': ['/wiki/Mariah_Carey', '/wiki/Cameo_(band)'],
#   'year': '2001'},
#  {'band_singer': ['The Isley Brothers', 'R. Kelly', 'Chanté Moore'],
#   'ranking': '81\n',
#   'song': ['Contagious (song)'],
#   'songurl': ['/wiki/Contagious_(song)'],
#   'titletext': '"Contagious (song)"',
#   'url': ['/wiki/The_Isley_Brothers',
#    '/wiki/R._Kelly',
#    '/wiki/Chant%C3%A9_Moore'],
#   'year': '2001'},
#  {'band_singer': ['Jessica Andrews'],
#   'ranking': '82\n',
#   'song': ['Who I Am (Jessica Andrews song)'],
#   'songurl': ['/wiki/Who_I_Am_(Jessica_Andrews_song)'],
#   'titletext': '"Who I Am (Jessica Andrews song)"',
#   'url': ['/wiki/Jessica_Andrews'],
#   'year': '2001'},
#  {'band_singer': ['Erick Sermon', 'Marvin Gaye'],
#   'ranking': '83\n',
#   'song': ['Music (Erick Sermon and Marvin Gaye song)'],
#   'songurl': ['/wiki/Music_(Erick_Sermon_and_Marvin_Gaye_song)'],
#   'titletext': '"Music (Erick Sermon and Marvin Gaye song)"',
#   'url': ['/wiki/Erick_Sermon', '/wiki/Marvin_Gaye'],
#   'year': '2001'},
#  {'band_singer': ['Willa Ford'],
#   'ranking': '84\n',
#   'song': ['I Wanna Be Bad'],
#   'songurl': ['/wiki/I_Wanna_Be_Bad'],
#   'titletext': '"I Wanna Be Bad"',
#   'url': ['/wiki/Willa_Ford'],
#   'year': '2001'},
#  {'band_singer': ['Kenny Chesney'],
#   'ranking': '85\n',
#   'song': ["Don't Happen Twice"],
#   'songurl': ['/wiki/Don%27t_Happen_Twice'],
#   'titletext': '"Don\'t Happen Twice"',
#   'url': ['/wiki/Kenny_Chesney'],
#   'year': '2001'},
#  {'band_singer': ['Diamond Rio'],
#   'ranking': '86\n',
#   'song': ['One More Day (Diamond Rio song)'],
#   'songurl': ['/wiki/One_More_Day_(Diamond_Rio_song)'],
#   'titletext': '"One More Day (Diamond Rio song)"',
#   'url': ['/wiki/Diamond_Rio'],
#   'year': '2001'},
#  {'band_singer': ['R. Kelly'],
#   'ranking': '87\n',
#   'song': ['I Wish (R. Kelly song)'],
#   'songurl': ['/wiki/I_Wish_(R._Kelly_song)'],
#   'titletext': '"I Wish (R. Kelly song)"',
#   'url': ['/wiki/R._Kelly'],
#   'year': '2001'},
#  {'band_singer': ['Travis Tritt'],
#   'ranking': '88\n',
#   'song': ["It's a Great Day to Be Alive"],
#   'songurl': ['/wiki/It%27s_a_Great_Day_to_Be_Alive'],
#   'titletext': '"It\'s a Great Day to Be Alive"',
#   'url': ['/wiki/Travis_Tritt'],
#   'year': '2001'},
#  {'band_singer': ['Trick Daddy'],
#   'ranking': '89\n',
#   'song': ["It's a Great Day to Be Alive"],
#   'songurl': [None],
#   'titletext': ["It's a Great Day to Be Alive"],
#   'url': ['/wiki/Trick_Daddy'],
#   'year': '2001'},
#  {'band_singer': ['Eve 6'],
#   'ranking': '90\n',
#   'song': ["Here's to the Night"],
#   'songurl': ['/wiki/Here%27s_to_the_Night'],
#   'titletext': '"Here\'s to the Night"',
#   'url': ['/wiki/Eve_6'],
#   'year': '2001'},
#  {'band_singer': ['Toby Keith'],
#   'ranking': '91\n',
#   'song': ["You Shouldn't Kiss Me Like This"],
#   'songurl': ['/wiki/You_Shouldn%27t_Kiss_Me_Like_This'],
#   'titletext': '"You Shouldn\'t Kiss Me Like This"',
#   'url': ['/wiki/Toby_Keith'],
#   'year': '2001'},
#  {'band_singer': ["Eden's Crush"],
#   'ranking': '92\n',
#   'song': ["Get Over Yourself (Eden's Crush song)"],
#   'songurl': ['/wiki/Get_Over_Yourself_(Eden%27s_Crush_song)'],
#   'titletext': '"Get Over Yourself (Eden\'s Crush song)"',
#   'url': ['/wiki/Eden%27s_Crush'],
#   'year': '2001'},
#  {'band_singer': ['Debelah Morgan'],
#   'ranking': '93\n',
#   'song': ['Dance with Me (Debelah Morgan song)'],
#   'songurl': ['/wiki/Dance_with_Me_(Debelah_Morgan_song)'],
#   'titletext': '"Dance with Me (Debelah Morgan song)"',
#   'url': ['/wiki/Debelah_Morgan'],
#   'year': '2001'},
#  {'band_singer': ['Outkast'],
#   'ranking': '94\n',
#   'song': ['So Fresh So Clean'],
#   'songurl': ['/wiki/So_Fresh_So_Clean'],
#   'titletext': '"So Fresh So Clean"',
#   'url': ['/wiki/Outkast'],
#   'year': '2001'},
#  {'band_singer': ['Nelly'],
#   'ranking': '95\n',
#   'song': ['E.I. (song)'],
#   'songurl': ['/wiki/E.I._(song)'],
#   'titletext': '"E.I. (song)"',
#   'url': ['/wiki/Nelly'],
#   'year': '2001'},
#  {'band_singer': ['3 Doors Down'],
#   'ranking': '96\n',
#   'song': ['Be Like That'],
#   'songurl': ['/wiki/Be_Like_That'],
#   'titletext': '"Be Like That"',
#   'url': ['/wiki/3_Doors_Down'],
#   'year': '2001'},
#  {'band_singer': ['Pink'],
#   'ranking': '97\n',
#   'song': ['Most Girls (Pink song)'],
#   'songurl': ['/wiki/Most_Girls_(Pink_song)'],
#   'titletext': '"Most Girls (Pink song)"',
#   'url': ['/wiki/Pink_(singer)'],
#   'year': '2001'},
#  {'band_singer': ['Nas', 'Bravehearts'],
#   'ranking': '98\n',
#   'song': ['Oochie Wally'],
#   'songurl': ['/wiki/Oochie_Wally'],
#   'titletext': '"Oochie Wally"',
#   'url': ['/wiki/Nas', '/wiki/Bravehearts'],
#   'year': '2001'},
#  {'band_singer': ['Enrique Iglesias'],
#   'ranking': '99\n',
#   'song': ['Hero (Enrique Iglesias song)'],
#   'songurl': ['/wiki/Hero_(Enrique_Iglesias_song)'],
#   'titletext': '"Hero (Enrique Iglesias song)"',
#   'url': ['/wiki/Enrique_Iglesias'],
#   'year': '2001'},
#  {'band_singer': ['Fuel'],
#   'ranking': '100\n',
#   'song': ['Hemorrhage (In My Hands)'],
#   'songurl': ['/wiki/Hemorrhage_(In_My_Hands)'],
#   'titletext': '"Hemorrhage (In My Hands)"',
#   'url': ['/wiki/Fuel_(band)'],
#   'year': '2001'},
#  ...]

# %%
# TO RERUN THIS CELL, you must restart and clear all output!!!

# the following code removes lists from inside of our dictionaries inside of our list. It then creates new dictionary entries
# for each individual list item
band_singer = []
songurl = ''
title_text = ''
singer_url = []
starting_length = len(rows)
for dics in rows: 
    if starting_length == 0:
        break
    dict_add = {}   
    # checks if our dictionary contains lists longer than one element
    if len(dics['band_singer']) > 1:
        i = 0
        j = len(dics['band_singer'])
        
        for value in dics['band_singer']:
            # new dictionary entry to append to our list
            dict_add = {'band_singer' : dics['band_singer'][i],
            'ranking' : dics['ranking'],
            'song' : dics['song'], 'songurl': dics['songurl'], 'titletext' : dics['titletext'],
            'url' : dics['url'][i], 'year' : dics['year']}
            rows.append(dict_add)
            i = 1 + i
            j = j - 1
    starting_length = starting_length - 1

rows2 = []
band_singer = []

# loops through our list again, removing duplicate entries
for dics in rows:
    if len(dics['band_singer']) == 1 or len(dics['band_singer']) > 5:
        rows2.append(dics)

# turns all remaining one element lists into strings
for row in rows2:
    for key in row:
        row[key] = str(row[key])
        row[key] = row[key].strip("[]")
        row[key] = row[key].strip("''")

# %%
rows2
# Out:
# [{'band_singer': 'Boyz II Men',
#   'ranking': '1\n',
#   'song': 'End of the Road',
#   'songurl': '/wiki/End_of_the_Road',
#   'titletext': '"End of the Road"',
#   'url': '/wiki/Boyz_II_Men',
#   'year': '1992'},
#  {'band_singer': 'Sir Mix-a-Lot',
#   'ranking': '2\n',
#   'song': 'Baby Got Back',
#   'songurl': '/wiki/Baby_Got_Back',
#   'titletext': '"Baby Got Back"',
#   'url': '/wiki/Sir_Mix-a-Lot',
#   'year': '1992'},
#  {'band_singer': 'Kris Kross',
#   'ranking': '3\n',
#   'song': 'Jump (Kris Kross song)',
#   'songurl': '/wiki/Jump_(Kris_Kross_song)',
#   'titletext': '"Jump (Kris Kross song)"',
#   'url': '/wiki/Kris_Kross',
#   'year': '1992'},
#  {'band_singer': 'Vanessa Williams',
#   'ranking': '4\n',
#   'song': 'Save the Best for Last',
#   'songurl': '/wiki/Save_the_Best_for_Last',
#   'titletext': '"Save the Best for Last"',
#   'url': '/wiki/Vanessa_L._Williams',
#   'year': '1992'},
#  {'band_singer': 'TLC',
#   'ranking': '5\n',
#   'song': 'Baby-Baby-Baby',
#   'songurl': '/wiki/Baby-Baby-Baby',
#   'titletext': '"Baby-Baby-Baby"',
#   'url': '/wiki/TLC_(band)',
#   'year': '1992'},
#  {'band_singer': 'Eric Clapton',
#   'ranking': '6\n',
#   'song': 'Tears in Heaven',
#   'songurl': '/wiki/Tears_in_Heaven',
#   'titletext': '"Tears in Heaven"',
#   'url': '/wiki/Eric_Clapton',
#   'year': '1992'},
#  {'band_singer': 'En Vogue',
#   'ranking': '7\n',
#   'song': '"My Lovin\' (You\'re Never Gonna Get It)"',
#   'songurl': '/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)',
#   'titletext': '"My Lovin\' (You\'re Never Gonna Get It)"',
#   'url': '/wiki/En_Vogue',
#   'year': '1992'},
#  {'band_singer': 'Red Hot Chili Peppers',
#   'ranking': '8\n',
#   'song': 'Under the Bridge',
#   'songurl': '/wiki/Under_the_Bridge',
#   'titletext': '"Under the Bridge"',
#   'url': '/wiki/Red_Hot_Chili_Peppers',
#   'year': '1992'},
#  {'band_singer': 'Color Me Badd',
#   'ranking': '9\n',
#   'song': 'All 4 Love',
#   'songurl': '/wiki/All_4_Love',
#   'titletext': '"All 4 Love"',
#   'url': '/wiki/Color_Me_Badd',
#   'year': '1992'},
#  {'band_singer': 'Jon Secada',
#   'ranking': '10\n',
#   'song': 'Just Another Day (Jon Secada song)',
#   'songurl': '/wiki/Just_Another_Day_(Jon_Secada_song)',
#   'titletext': '"Just Another Day (Jon Secada song)"',
#   'url': '/wiki/Jon_Secada',
#   'year': '1992'},
#  {'band_singer': 'Shanice',
#   'ranking': '11\n',
#   'song': 'I Love Your Smile',
#   'songurl': '/wiki/I_Love_Your_Smile',
#   'titletext': '"I Love Your Smile"',
#   'url': '/wiki/Shanice',
#   'year': '1992'},
#  {'band_singer': 'Mr. Big',
#   'ranking': '12\n',
#   'song': 'To Be with You',
#   'songurl': '/wiki/To_Be_with_You',
#   'titletext': '"To Be with You"',
#   'url': '/wiki/Mr._Big_(band)',
#   'year': '1992'},
#  {'band_singer': 'Right Said Fred',
#   'ranking': '13\n',
#   'song': '"I\'m Too Sexy"',
#   'songurl': '/wiki/I%27m_Too_Sexy',
#   'titletext': '"I\'m Too Sexy"',
#   'url': '/wiki/Right_Said_Fred',
#   'year': '1992'},
#  {'band_singer': 'Michael Jackson',
#   'ranking': '14\n',
#   'song': 'Black or White',
#   'songurl': '/wiki/Black_or_White',
#   'titletext': '"Black or White"',
#   'url': '/wiki/Michael_Jackson',
#   'year': '1992'},
#  {'band_singer': 'Billy Ray Cyrus',
#   'ranking': '15\n',
#   'song': 'Achy Breaky Heart',
#   'songurl': '/wiki/Achy_Breaky_Heart',
#   'titletext': '"Achy Breaky Heart"',
#   'url': '/wiki/Billy_Ray_Cyrus',
#   'year': '1992'},
#  {'band_singer': 'Mariah Carey',
#   'ranking': '16\n',
#   'song': '"I\'ll Be There (The Jackson 5 song)"',
#   'songurl': '/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mariah_Carey_version',
#   'titletext': '"I\'ll Be There (The Jackson 5 song)"',
#   'url': '/wiki/Mariah_Carey',
#   'year': '1992'},
#  {'band_singer': '"Guns N\' Roses"',
#   'ranking': '17\n',
#   'song': 'November Rain',
#   'songurl': '/wiki/November_Rain',
#   'titletext': '"November Rain"',
#   'url': '/wiki/Guns_N%27_Roses',
#   'year': '1992'},
#  {'band_singer': 'Tom Cochrane',
#   'ranking': '18\n',
#   'song': 'Life Is a Highway',
#   'songurl': '/wiki/Life_Is_a_Highway',
#   'titletext': '"Life Is a Highway"',
#   'url': '/wiki/Tom_Cochrane',
#   'year': '1992'},
#  {'band_singer': 'Michael Jackson',
#   'ranking': '19\n',
#   'song': 'Remember the Time',
#   'songurl': '/wiki/Remember_the_Time',
#   'titletext': '"Remember the Time"',
#   'url': '/wiki/Michael_Jackson',
#   'year': '1992'},
#  {'band_singer': 'CeCe Peniston',
#   'ranking': '20\n',
#   'song': 'Finally (CeCe Peniston song)',
#   'songurl': '/wiki/Finally_(CeCe_Peniston_song)',
#   'titletext': '"Finally (CeCe Peniston song)"',
#   'url': '/wiki/CeCe_Peniston',
#   'year': '1992'},
#  {'band_singer': 'Madonna',
#   'ranking': '21\n',
#   'song': 'This Used to Be My Playground',
#   'songurl': '/wiki/This_Used_to_Be_My_Playground',
#   'titletext': '"This Used to Be My Playground"',
#   'url': '/wiki/Madonna_(entertainer)',
#   'year': '1992'},
#  {'band_singer': 'Mariah Carey',
#   'ranking': '23\n',
#   'song': '"Can\'t Let Go (Mariah Carey song)"',
#   'songurl': '/wiki/Can%27t_Let_Go_(Mariah_Carey_song)',
#   'titletext': '"Can\'t Let Go (Mariah Carey song)"',
#   'url': '/wiki/Mariah_Carey',
#   'year': '1992'},
#  {'band_singer': 'House of Pain',
#   'ranking': '24\n',
#   'song': 'Jump Around',
#   'songurl': '/wiki/Jump_Around',
#   'titletext': '"Jump Around"',
#   'url': '/wiki/House_of_Pain',
#   'year': '1992'},
#  {'band_singer': 'Atlantic Starr',
#   'ranking': '27\n',
#   'song': 'Masterpiece (Atlantic Starr song)',
#   'songurl': '/wiki/Masterpiece_(Atlantic_Starr_song)',
#   'titletext': '"Masterpiece (Atlantic Starr song)"',
#   'url': '/wiki/Atlantic_Starr',
#   'year': '1992'},
#  {'band_singer': 'Celine Dion',
#   'ranking': '28\n',
#   'song': 'If You Asked Me To',
#   'songurl': '/wiki/If_You_Asked_Me_To',
#   'titletext': '"If You Asked Me To"',
#   'url': '/wiki/Celine_Dion',
#   'year': '1992'},
#  {'band_singer': 'En Vogue',
#   'ranking': '29\n',
#   'song': 'Something He Can Feel',
#   'songurl': '/wiki/Something_He_Can_Feel',
#   'titletext': '"Something He Can Feel"',
#   'url': '/wiki/En_Vogue',
#   'year': '1992'},
#  {'band_singer': 'Joe Public',
#   'ranking': '30\n',
#   'song': 'Live and Learn (Joe Public song)',
#   'songurl': '/wiki/Live_and_Learn_(Joe_Public_song)',
#   'titletext': '"Live and Learn (Joe Public song)"',
#   'url': '/wiki/Joe_Public_(band)',
#   'year': '1992'},
#  {'band_singer': 'Jodeci',
#   'ranking': '31\n',
#   'song': 'Come and Talk to Me',
#   'songurl': '/wiki/Come_and_Talk_to_Me',
#   'titletext': '"Come and Talk to Me"',
#   'url': '/wiki/Jodeci',
#   'year': '1992'},
#  {'band_singer': 'Nirvana',
#   'ranking': '32\n',
#   'song': 'Smells Like Teen Spirit',
#   'songurl': '/wiki/Smells_Like_Teen_Spirit',
#   'titletext': '"Smells Like Teen Spirit"',
#   'url': '/wiki/Nirvana_(band)',
#   'year': '1992'},
#  {'band_singer': 'Bobby Brown',
#   'ranking': '33\n',
#   'song': '"Humpin\' Around"',
#   'songurl': '/wiki/Humpin%27_Around',
#   'titletext': '"Humpin\' Around"',
#   'url': '/wiki/Bobby_Brown',
#   'year': '1992'},
#  {'band_singer': 'Sophie B. Hawkins',
#   'ranking': '34\n',
#   'song': 'Damn I Wish I Was Your Lover',
#   'songurl': '/wiki/Damn_I_Wish_I_Was_Your_Lover',
#   'titletext': '"Damn I Wish I Was Your Lover"',
#   'url': '/wiki/Sophie_B._Hawkins',
#   'year': '1992'},
#  {'band_singer': 'Tevin Campbell',
#   'ranking': '35\n',
#   'song': 'Tell Me What You Want Me to Do',
#   'songurl': '/wiki/Tell_Me_What_You_Want_Me_to_Do',
#   'titletext': '"Tell Me What You Want Me to Do"',
#   'url': '/wiki/Tevin_Campbell',
#   'year': '1992'},
#  {'band_singer': 'TLC',
#   'ranking': '36\n',
#   'song': '"Ain\'t 2 Proud 2 Beg"',
#   'songurl': '/wiki/Ain%27t_2_Proud_2_Beg',
#   'titletext': '"Ain\'t 2 Proud 2 Beg"',
#   'url': '/wiki/TLC_(band)',
#   'year': '1992'},
#  {'band_singer': 'Boyz II Men',
#   'ranking': '37\n',
#   'song': '"It\'s So Hard to Say Goodbye to Yesterday"',
#   'songurl': '/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday',
#   'titletext': '"It\'s So Hard to Say Goodbye to Yesterday"',
#   'url': '/wiki/Boyz_II_Men',
#   'year': '1992'},
#  {'band_singer': 'Queen',
#   'ranking': '39\n',
#   'song': 'Bohemian Rhapsody',
#   'songurl': '/wiki/Bohemian_Rhapsody',
#   'titletext': '"Bohemian Rhapsody"',
#   'url': '/wiki/Queen_(band)',
#   'year': '1992'},
#  {'band_singer': 'Arrested Development',
#   'ranking': '40\n',
#   'song': 'Tennessee (Arrested Development song)',
#   'songurl': '/wiki/Tennessee_(Arrested_Development_song)',
#   'titletext': '"Tennessee (Arrested Development song)"',
#   'url': '/wiki/Arrested_Development_(group)',
#   'year': '1992'},
#  {'band_singer': 'Mariah Carey',
#   'ranking': '42\n',
#   'song': 'Make It Happen (Mariah Carey song)',
#   'songurl': '/wiki/Make_It_Happen_(Mariah_Carey_song)',
#   'titletext': '"Make It Happen (Mariah Carey song)"',
#   'url': '/wiki/Mariah_Carey',
#   'year': '1992'},
#  {'band_singer': 'Elton John',
#   'ranking': '43\n',
#   'song': 'The One (Elton John song)',
#   'songurl': '/wiki/The_One_(Elton_John_song)',
#   'titletext': '"The One (Elton John song)"',
#   'url': '/wiki/Elton_John',
#   'year': '1992'},
#  {'band_singer': 'P.M. Dawn',
#   'ranking': '44\n',
#   'song': 'Set Adrift on Memory Bliss',
#   'songurl': '/wiki/Set_Adrift_on_Memory_Bliss',
#   'titletext': '"Set Adrift on Memory Bliss"',
#   'url': '/wiki/P.M._Dawn',
#   'year': '1992'},
#  {'band_singer': 'Shakespears Sister',
#   'ranking': '45\n',
#   'song': 'Stay (Shakespears Sister song)',
#   'songurl': '/wiki/Stay_(Shakespears_Sister_song)',
#   'titletext': '"Stay (Shakespears Sister song)"',
#   'url': '/wiki/Shakespears_Sister',
#   'year': '1992'},
#  {'band_singer': 'Hammer',
#   'ranking': '46\n',
#   'song': 'Too Legit to Quit (song)',
#   'songurl': '/wiki/Too_Legit_to_Quit_(song)',
#   'titletext': '"Too Legit to Quit (song)"',
#   'url': '/wiki/MC_Hammer',
#   'year': '1992'},
#  {'band_singer': 'KWS',
#   'ranking': '47\n',
#   'song': '"Please Don\'t Go (KC and the Sunshine Band song)"',
#   'songurl': '/wiki/Please_Don%27t_Go_(KC_and_the_Sunshine_Band_song)#KWS_version',
#   'titletext': '"Please Don\'t Go (KC and the Sunshine Band song)"',
#   'url': '/wiki/KWS_(band)',
#   'year': '1992'},
#  {'band_singer': 'Mint Condition',
#   'ranking': '48\n',
#   'song': '"Breakin\' My Heart (Pretty Brown Eyes)"',
#   'songurl': '/wiki/Breakin%27_My_Heart_(Pretty_Brown_Eyes)',
#   'titletext': '"Breakin\' My Heart (Pretty Brown Eyes)"',
#   'url': '/wiki/Mint_Condition',
#   'year': '1992'},
#  {'band_singer': 'The Cover Girls',
#   'ranking': '49\n',
#   'song': 'Wishing on a Star',
#   'songurl': '/wiki/Wishing_on_a_Star',
#   'titletext': '"Wishing on a Star"',
#   'url': '/wiki/The_Cover_Girls',
#   'year': '1992'},
#  {'band_singer': 'Hi-Five',
#   'ranking': '50\n',
#   'song': 'Wishing on a Star',
#   'songurl': 'None',
#   'titletext': 'Wishing on a Star',
#   'url': '/wiki/Hi-Five',
#   'year': '1992'},
#  {'band_singer': 'P.M. Dawn',
#   'ranking': '51\n',
#   'song': '"I\'d Die Without You"',
#   'songurl': '/wiki/I%27d_Die_Without_You',
#   'titletext': '"I\'d Die Without You"',
#   'url': '/wiki/P.M._Dawn',
#   'year': '1992'},
#  {'band_singer': 'Amy Grant',
#   'ranking': '52\n',
#   'song': 'Good for Me (song)',
#   'songurl': '/wiki/Good_for_Me_(song)',
#   'titletext': '"Good for Me (song)"',
#   'url': '/wiki/Amy_Grant',
#   'year': '1992'},
#  {'band_singer': 'Toad the Wet Sprocket',
#   'ranking': '53\n',
#   'song': 'All I Want (Toad the Wet Sprocket song)',
#   'songurl': '/wiki/All_I_Want_(Toad_the_Wet_Sprocket_song)',
#   'titletext': '"All I Want (Toad the Wet Sprocket song)"',
#   'url': '/wiki/Toad_the_Wet_Sprocket',
#   'year': '1992'},
#  {'band_singer': 'Michael Bolton',
#   'ranking': '54\n',
#   'song': 'When a Man Loves a Woman (song)',
#   'songurl': '/wiki/When_a_Man_Loves_a_Woman_(song)',
#   'titletext': '"When a Man Loves a Woman (song)"',
#   'url': '/wiki/Michael_Bolton',
#   'year': '1992'},
#  {'band_singer': 'Genesis',
#   'ranking': '55\n',
#   'song': '"I Can\'t Dance"',
#   'songurl': '/wiki/I_Can%27t_Dance',
#   'titletext': '"I Can\'t Dance"',
#   'url': '/wiki/Genesis_(band)',
#   'year': '1992'},
#  {'band_singer': 'Richard Marx',
#   'ranking': '56\n',
#   'song': 'Hazard (song)',
#   'songurl': '/wiki/Hazard_(song)',
#   'titletext': '"Hazard (song)"',
#   'url': '/wiki/Richard_Marx',
#   'year': '1992'},
#  {'band_singer': 'U2',
#   'ranking': '57\n',
#   'song': 'Mysterious Ways (song)',
#   'songurl': '/wiki/Mysterious_Ways_(song)',
#   'titletext': '"Mysterious Ways (song)"',
#   'url': '/wiki/U2',
#   'year': '1992'},
#  {'band_singer': 'George Michael',
#   'ranking': '58\n',
#   'song': 'Too Funky',
#   'songurl': '/wiki/Too_Funky',
#   'titletext': '"Too Funky"',
#   'url': '/wiki/George_Michael',
#   'year': '1992'},
#  {'band_singer': 'The Heights',
#   'ranking': '59\n',
#   'song': 'How Do You Talk to an Angel',
#   'songurl': '/wiki/How_Do_You_Talk_to_an_Angel',
#   'titletext': '"How Do You Talk to an Angel"',
#   'url': '/wiki/The_Heights_(American_TV_series)',
#   'year': '1992'},
#  {'band_singer': 'U2',
#   'ranking': '60\n',
#   'song': 'One (U2 song)',
#   'songurl': '/wiki/One_(U2_song)',
#   'titletext': '"One (U2 song)"',
#   'url': '/wiki/U2',
#   'year': '1992'},
#  {'band_singer': 'CeCe Peniston',
#   'ranking': '61\n',
#   'song': '"Keep on Walkin\' (song)"',
#   'songurl': '/wiki/Keep_on_Walkin%27_(song)',
#   'titletext': '"Keep on Walkin\' (song)"',
#   'url': '/wiki/CeCe_Peniston',
#   'year': '1992'},
#  {'band_singer': 'Genesis',
#   'ranking': '62\n',
#   'song': 'Hold on My Heart',
#   'songurl': '/wiki/Hold_on_My_Heart',
#   'titletext': '"Hold on My Heart"',
#   'url': '/wiki/Genesis_(band)',
#   'year': '1992'},
#  {'band_singer': 'Karyn White',
#   'ranking': '63\n',
#   'song': 'Hold on My Heart',
#   'songurl': 'None',
#   'titletext': 'Hold on My Heart',
#   'url': '/wiki/Karyn_White',
#   'year': '1992'},
#  {'band_singer': 'Kris Kross',
#   'ranking': '65\n',
#   'song': 'Warm It Up',
#   'songurl': '/wiki/Warm_It_Up',
#   'titletext': '"Warm It Up"',
#   'url': '/wiki/Kris_Kross',
#   'year': '1992'},
#  {'band_singer': 'Michael Jackson',
#   'ranking': '66\n',
#   'song': 'In the Closet',
#   'songurl': '/wiki/In_the_Closet',
#   'titletext': '"In the Closet"',
#   'url': '/wiki/Michael_Jackson',
#   'year': '1992'},
#  {'band_singer': 'Arrested Development',
#   'ranking': '67\n',
#   'song': 'People Everyday',
#   'songurl': '/wiki/People_Everyday',
#   'titletext': '"People Everyday"',
#   'url': '/wiki/Arrested_Development_(group)',
#   'year': '1992'},
#  {'band_singer': 'Genesis',
#   'ranking': '68\n',
#   'song': 'No Son of Mine',
#   'songurl': '/wiki/No_Son_of_Mine',
#   'titletext': '"No Son of Mine"',
#   'url': '/wiki/Genesis_(band)',
#   'year': '1992'},
#  {'band_singer': 'Marky Mark and the Funky Bunch',
#   'ranking': '69\n',
#   'song': 'Wildside (Marky Mark and the Funky Bunch song)',
#   'songurl': '/wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch_song)',
#   'titletext': '"Wildside (Marky Mark and the Funky Bunch song)"',
#   'url': '/wiki/Marky_Mark_and_the_Funky_Bunch',
#   'year': '1992'},
#  {'band_singer': 'Bryan Adams',
#   'ranking': '70\n',
#   'song': 'Do I Have to Say the Words?',
#   'songurl': '/wiki/Do_I_Have_to_Say_the_Words%3F',
#   'titletext': '"Do I Have to Say the Words?"',
#   'url': '/wiki/Bryan_Adams',
#   'year': '1992'},
#  {'band_singer': 'The Cure',
#   'ranking': '71\n',
#   'song': '"Friday I\'m in Love"',
#   'songurl': '/wiki/Friday_I%27m_in_Love',
#   'titletext': '"Friday I\'m in Love"',
#   'url': '/wiki/The_Cure',
#   'year': '1992'},
#  {'band_singer': 'Ugly Kid Joe',
#   'ranking': '72\n',
#   'song': 'Everything About You (Ugly Kid Joe song)',
#   'songurl': '/wiki/Everything_About_You_(Ugly_Kid_Joe_song)',
#   'titletext': '"Everything About You (Ugly Kid Joe song)"',
#   'url': '/wiki/Ugly_Kid_Joe',
#   'year': '1992'},
#  {'band_singer': 'Paula Abdul',
#   'ranking': '73\n',
#   'song': 'Blowing Kisses in the Wind',
#   'songurl': '/wiki/Blowing_Kisses_in_the_Wind',
#   'titletext': '"Blowing Kisses in the Wind"',
#   'url': '/wiki/Paula_Abdul',
#   'year': '1992'},
#  {'band_singer': 'Bryan Adams',
#   'ranking': '74\n',
#   'song': '"Thought I\'d Died and Gone to Heaven"',
#   'songurl': '/wiki/Thought_I%27d_Died_and_Gone_to_Heaven',
#   'titletext': '"Thought I\'d Died and Gone to Heaven"',
#   'url': '/wiki/Bryan_Adams',
#   'year': '1992'},
#  {'band_singer': 'Snap!',
#   'ranking': '75\n',
#   'song': 'Rhythm Is a Dancer',
#   'songurl': '/wiki/Rhythm_Is_a_Dancer',
#   'titletext': '"Rhythm Is a Dancer"',
#   'url': '/wiki/Snap!',
#   'year': '1992'},
#  {'band_singer': 'Hammer',
#   'ranking': '76\n',
#   'song': 'Addams Groove',
#   'songurl': '/wiki/Addams_Groove',
#   'titletext': '"Addams Groove"',
#   'url': '/wiki/MC_Hammer',
#   'year': '1992'},
#  {'band_singer': 'Michael Bolton',
#   'ranking': '77\n',
#   'song': 'Missing You Now',
#   'songurl': '/wiki/Missing_You_Now',
#   'titletext': '"Missing You Now"',
#   'url': '/wiki/Michael_Bolton',
#   'year': '1992'},
#  {'band_singer': 'N2Deep',
#   'ranking': '78\n',
#   'song': 'Missing You Now',
#   'songurl': 'None',
#   'titletext': 'Missing You Now',
#   'url': '/wiki/N2Deep',
#   'year': '1992'},
#  {'band_singer': 'Kathy Troccoli',
#   'ranking': '79\n',
#   'song': 'Missing You Now',
#   'songurl': 'None',
#   'titletext': 'Missing You Now',
#   'url': '/wiki/Kathy_Troccoli',
#   'year': '1992'},
#  {'band_singer': 'Def Leppard',
#   'ranking': '80\n',
#   'song': 'Have You Ever Needed Someone So Bad',
#   'songurl': '/wiki/Have_You_Ever_Needed_Someone_So_Bad',
#   'titletext': '"Have You Ever Needed Someone So Bad"',
#   'url': '/wiki/Def_Leppard',
#   'year': '1992'},
#  {'band_singer': 'Richard Marx',
#   'ranking': '81\n',
#   'song': 'Take This Heart',
#   'songurl': '/wiki/Take_This_Heart',
#   'titletext': '"Take This Heart"',
#   'url': '/wiki/Richard_Marx',
#   'year': '1992'},
#  {'band_singer': 'FireHouse',
#   'ranking': '82\n',
#   'song': 'When I Look Into Your Eyes',
#   'songurl': '/wiki/When_I_Look_Into_Your_Eyes',
#   'titletext': '"When I Look Into Your Eyes"',
#   'url': '/wiki/FireHouse_(band)',
#   'year': '1992'},
#  {'band_singer': 'Jade',
#   'ranking': '83\n',
#   'song': 'I Wanna Love You (Jade song)',
#   'songurl': '/wiki/I_Wanna_Love_You_(Jade_song)',
#   'titletext': '"I Wanna Love You (Jade song)"',
#   'url': '/wiki/Jade_(American_band)',
#   'year': '1992'},
#  {'band_singer': 'Boyz II Men',
#   'ranking': '84\n',
#   'song': 'Uhh Ahh',
#   'songurl': '/wiki/Uhh_Ahh',
#   'titletext': '"Uhh Ahh"',
#   'url': '/wiki/Boyz_II_Men',
#   'year': '1992'},
#  {'band_singer': 'Mary J. Blige',
#   'ranking': '85\n',
#   'song': 'Real Love (Mary J. Blige song)',
#   'songurl': '/wiki/Real_Love_(Mary_J._Blige_song)',
#   'titletext': '"Real Love (Mary J. Blige song)"',
#   'url': '/wiki/Mary_J._Blige',
#   'year': '1992'},
#  {'band_singer': 'The KLF',
#   'ranking': '86\n',
#   'song': 'Justified and Ancient',
#   'songurl': '/wiki/Justified_and_Ancient',
#   'titletext': '"Justified and Ancient"',
#   'url': '/wiki/The_KLF',
#   'year': '1992'},
#  {'band_singer': 'Color Me Badd',
#   'ranking': '87\n',
#   'song': 'Justified and Ancient',
#   'songurl': 'None',
#   'titletext': 'Justified and Ancient',
#   'url': '/wiki/Color_Me_Badd',
#   'year': '1992'},
#  {'band_singer': 'TLC',
#   'ranking': '88\n',
#   'song': 'What About Your Friends',
#   'songurl': '/wiki/What_About_Your_Friends',
#   'titletext': '"What About Your Friends"',
#   'url': '/wiki/TLC_(band)',
#   'year': '1992'},
#  {'band_singer': 'Color Me Badd',
#   'ranking': '89\n',
#   'song': 'What About Your Friends',
#   'songurl': 'None',
#   'titletext': 'What About Your Friends',
#   'url': '/wiki/Color_Me_Badd',
#   'year': '1992'},
#  {'band_singer': 'Charles & Eddie',
#   'ranking': '90\n',
#   'song': 'Would I Lie to You? (Charles & Eddie song)',
#   'songurl': '/wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie_song)',
#   'titletext': '"Would I Lie to You? (Charles & Eddie song)"',
#   'url': '/wiki/Charles_%26_Eddie',
#   'year': '1992'},
#  {'band_singer': 'Amy Grant',
#   'ranking': '91\n',
#   'song': '"That\'s What Love Is For"',
#   'songurl': '/wiki/That%27s_What_Love_Is_For',
#   'titletext': '"That\'s What Love Is For"',
#   'url': '/wiki/Amy_Grant',
#   'year': '1992'},
#  {'band_singer': 'Richard Marx',
#   'ranking': '92\n',
#   'song': 'Keep Coming Back (song)',
#   'songurl': '/wiki/Keep_Coming_Back_(song)',
#   'titletext': '"Keep Coming Back (song)"',
#   'url': '/wiki/Richard_Marx',
#   'year': '1992'},
#  {'band_singer': 'En Vogue',
#   'ranking': '93\n',
#   'song': 'Free Your Mind (song)',
#   'songurl': '/wiki/Free_Your_Mind_(song)',
#   'titletext': '"Free Your Mind (song)"',
#   'url': '/wiki/En_Vogue',
#   'year': '1992'},
#  {'band_singer': 'Keith Sweat',
#   'ranking': '94\n',
#   'song': '"Keep It Comin\' (song)"',
#   'songurl': '/wiki/Keep_It_Comin%27_(song)',
#   'titletext': '"Keep It Comin\' (song)"',
#   'url': '/wiki/Keith_Sweat',
#   'year': '1992'},
#  {'band_singer': 'Mr. Big',
#   'ranking': '95\n',
#   'song': 'Just Take My Heart (song)',
#   'songurl': '/wiki/Just_Take_My_Heart_(song)',
#   'titletext': '"Just Take My Heart (song)"',
#   'url': '/wiki/Mr._Big_(band)',
#   'year': '1992'},
#  {'band_singer': 'Amy Grant',
#   'ranking': '96\n',
#   'song': 'I Will Remember You (Amy Grant song)',
#   'songurl': '/wiki/I_Will_Remember_You_(Amy_Grant_song)',
#   'titletext': '"I Will Remember You (Amy Grant song)"',
#   'url': '/wiki/Amy_Grant',
#   'year': '1992'},
#  {'band_singer': 'CeCe Peniston',
#   'ranking': '97\n',
#   'song': 'We Got a Love Thang',
#   'songurl': '/wiki/We_Got_a_Love_Thang',
#   'titletext': '"We Got a Love Thang"',
#   'url': '/wiki/CeCe_Peniston',
#   'year': '1992'},
#  {'band_singer': 'Def Leppard',
#   'ranking': '98\n',
#   'song': '"Let\'s Get Rocked"',
#   'songurl': '/wiki/Let%27s_Get_Rocked',
#   'titletext': '"Let\'s Get Rocked"',
#   'url': '/wiki/Def_Leppard',
#   'year': '1992'},
#  {'band_singer': 'Das EFX',
#   'ranking': '99\n',
#   'song': 'They Want EFX',
#   'songurl': '/wiki/They_Want_EFX',
#   'titletext': '"They Want EFX"',
#   'url': '/wiki/Das_EFX',
#   'year': '1992'},
#  {'band_singer': 'Bonnie Raitt',
#   'ranking': '100\n',
#   'song': '"I Can\'t Make You Love Me"',
#   'songurl': '/wiki/I_Can%27t_Make_You_Love_Me',
#   'titletext': '"I Can\'t Make You Love Me"',
#   'url': '/wiki/Bonnie_Raitt',
#   'year': '1992'},
#  {'band_singer': 'Whitney Houston',
#   'ranking': '1\n',
#   'song': 'I Will Always Love You',
#   'songurl': '/wiki/I_Will_Always_Love_You#Whitney_Houston_version',
#   'titletext': '"I Will Always Love You"',
#   'url': '/wiki/Whitney_Houston',
#   'year': '1993'},
#  {'band_singer': 'Tag Team',
#   'ranking': '2\n',
#   'song': 'Whoomp! (There It Is)',
#   'songurl': '/wiki/Whoomp!_(There_It_Is)',
#   'titletext': '"Whoomp! (There It Is)"',
#   'url': '/wiki/Tag_Team_(group)',
#   'year': '1993'},
#  {'band_singer': 'UB40',
#   'ranking': '3\n',
#   'song': '"Can\'t Help Falling in Love"',
#   'songurl': '/wiki/Can%27t_Help_Falling_in_Love',
#   'titletext': '"Can\'t Help Falling in Love"',
#   'url': '/wiki/UB40',
#   'year': '1993'},
#  {'band_singer': 'Janet Jackson',
#   'ranking': '4\n',
#   'song': '"That\'s the Way Love Goes (Janet Jackson song)"',
#   'songurl': '/wiki/That%27s_the_Way_Love_Goes_(Janet_Jackson_song)',
#   'titletext': '"That\'s the Way Love Goes (Janet Jackson song)"',
#   'url': '/wiki/Janet_Jackson',
#   'year': '1993'},
#  {'band_singer': 'Silk',
#   'ranking': '5\n',
#   'song': 'Freak Me',
#   'songurl': '/wiki/Freak_Me',
#   'titletext': '"Freak Me"',
#   'url': '/wiki/Silk_(group)',
#   'year': '1993'},
#  {'band_singer': 'SWV',
#   'ranking': '6\n',
#   'song': 'Weak (SWV song)',
#   'songurl': '/wiki/Weak_(SWV_song)',
#   'titletext': '"Weak (SWV song)"',
#   'url': '/wiki/SWV',
#   'year': '1993'},
#  {'band_singer': 'Shai',
#   'ranking': '7\n',
#   'song': 'If I Ever Fall in Love',
#   'songurl': '/wiki/If_I_Ever_Fall_in_Love',
#   'titletext': '"If I Ever Fall in Love"',
#   'url': '/wiki/Shai_(band)',
#   'year': '1993'},
#  {'band_singer': 'Mariah Carey',
#   'ranking': '8\n',
#   'song': 'Dreamlover (song)',
#   'songurl': '/wiki/Dreamlover_(song)',
#   'titletext': '"Dreamlover (song)"',
#   'url': '/wiki/Mariah_Carey',
#   'year': '1993'},
#  {'band_singer': 'Wreckx-n-Effect',
#   'ranking': '9\n',
#   'song': 'Rump Shaker (song)',
#   'songurl': '/wiki/Rump_Shaker_(song)',
#   'titletext': '"Rump Shaker (song)"',
#   'url': '/wiki/Wreckx-n-Effect',
#   'year': '1993'},
#  {'band_singer': 'Snow',
#   'ranking': '10\n',
#   'song': 'Informer (song)',
#   'songurl': '/wiki/Informer_(song)',
#   'titletext': '"Informer (song)"',
#   'url': '/wiki/Snow_(musician)',
#   'year': '1993'},
#  {'band_singer': 'Dr. Dre',
#   'ranking': '11\n',
#   'song': '"Nuthin\' but a \'G\' Thang"',
#   'songurl': '/wiki/Nuthin%27_but_a_%27G%27_Thang',
#   'titletext': '"Nuthin\' but a \'G\' Thang"',
#   'url': '/wiki/Dr._Dre',
#   'year': '1993'},
#  {'band_singer': 'Boyz II Men',
#   'ranking': '12\n',
#   'song': 'In the Still of the Night (1956 song)',
#   'songurl': '/wiki/In_the_Still_of_the_Night_(1956_song)#Boyz_II_Men_version',
#   'titletext': '"In the Still of the Night (1956 song)"',
#   'url': '/wiki/Boyz_II_Men',
#   'year': '1993'},
#  {'band_singer': 'Jade',
#   'ranking': '13\n',
#   'song': '"Don\'t Walk Away (Jade song)"',
#   'songurl': '/wiki/Don%27t_Walk_Away_(Jade_song)',
#   'titletext': '"Don\'t Walk Away (Jade song)"',
#   'url': '/wiki/Jade_(R%26B_group)',
#   'year': '1993'},
#  {'band_singer': 'H-Town',
#   'ranking': '14\n',
#   'song': '"Knockin\' da Boots"',
#   'songurl': '/wiki/Knockin%27_da_Boots',
#   'titletext': '"Knockin\' da Boots"',
#   'url': '/wiki/H-Town_(band)',
#   'year': '1993'},
#  {'band_singer': 'Jodeci',
#   'ranking': '15\n',
#   'song': 'Lately (Jodeci song)',
#   'songurl': '/wiki/Lately_(Jodeci_song)',
#   'titletext': '"Lately (Jodeci song)"',
#   'url': '/wiki/Jodeci',
#   'year': '1993'},
#  {'band_singer': 'Duice',
#   'ranking': '16\n',
#   'song': 'Dazzey Duks',
#   'songurl': '/wiki/Dazzey_Duks',
#   'titletext': '"Dazzey Duks"',
#   'url': '/wiki/Duice',
#   'year': '1993'},
#  {'band_singer': 'Robin S.',
#   'ranking': '17\n',
#   'song': 'Show Me Love (Robin S. song)',
#   'songurl': '/wiki/Show_Me_Love_(Robin_S._song)',
#   'titletext': '"Show Me Love (Robin S. song)"',
#   'url': '/wiki/Robin_S.',
#   'year': '1993'},
#  {'band_singer': 'Janet Jackson',
#   'ranking': '19\n',
#   'song': 'If (Janet Jackson song)',
#   'songurl': '/wiki/If_(Janet_Jackson_song)',
#   'titletext': '"If (Janet Jackson song)"',
#   'url': '/wiki/Janet_Jackson',
#   'year': '1993'},
#  {'band_singer': 'SWV',
#   'ranking': '20\n',
#   'song': '"I\'m So Into You"',
#   'songurl': '/wiki/I%27m_So_Into_You',
#   'titletext': '"I\'m So Into You"',
#   'url': '/wiki/SWV',
#   'year': '1993'},
#  {'band_singer': 'Soul Asylum',
#   'ranking': '22\n',
#   'song': 'Runaway Train (Soul Asylum song)',
#   'songurl': '/wiki/Runaway_Train_(Soul_Asylum_song)',
#   'titletext': '"Runaway Train (Soul Asylum song)"',
#   'url': '/wiki/Soul_Asylum',
#   'year': '1993'},
#  {'band_singer': 'Exposé',
#   'ranking': '23\n',
#   'song': '"I\'ll Never Get Over You (Getting Over Me)"',
#   'songurl': '/wiki/I%27ll_Never_Get_Over_You_(Getting_Over_Me)',
#   'titletext': '"I\'ll Never Get Over You (Getting Over Me)"',
#   'url': '/wiki/Expos%C3%A9_(group)',
#   'year': '1993'},
#  {'band_singer': 'Paperboy',
#   'ranking': '24\n',
#   'song': 'Ditty (Paperboy song)',
#   'songurl': '/wiki/Ditty_(Paperboy_song)',
#   'titletext': '"Ditty (Paperboy song)"',
#   'url': '/wiki/Paperboy_(rapper)',
#   'year': '1993'},
#  {'band_singer': 'Snap!',
#   'ranking': '25\n',
#   'song': 'Rhythm Is a Dancer',
#   'songurl': '/wiki/Rhythm_Is_a_Dancer',
#   'titletext': '"Rhythm Is a Dancer"',
#   'url': '/wiki/Snap!',
#   'year': '1993'},
#  {'band_singer': 'Billy Joel',
#   'ranking': '26\n',
#   'song': 'The River of Dreams',
#   'songurl': '/wiki/The_River_of_Dreams',
#   'titletext': '"The River of Dreams"',
#   'url': '/wiki/Billy_Joel',
#   'year': '1993'},
#  {'band_singer': 'The Proclaimers',
#   'ranking': '27\n',
#   'song': '"I\'m Gonna Be (500 Miles)"',
#   'songurl': '/wiki/I%27m_Gonna_Be_(500_Miles)',
#   'titletext': '"I\'m Gonna Be (500 Miles)"',
#   'url': '/wiki/The_Proclaimers',
#   'year': '1993'},
#  {'band_singer': 'Spin Doctors',
#   'ranking': '28\n',
#   'song': 'Two Princes',
#   'songurl': '/wiki/Two_Princes',
#   'titletext': '"Two Princes"',
#   'url': '/wiki/Spin_Doctors',
#   'year': '1993'},
#  {'band_singer': 'SWV',
#   'ranking': '29\n',
#   'song': 'Right Here (SWV song)',
#   'songurl': '/wiki/Right_Here_(SWV_song)',
#   'titletext': '"Right Here (SWV song)"',
#   'url': '/wiki/SWV',
#   'year': '1993'},
#  {'band_singer': 'Whitney Houston',
#   'ranking': '30\n',
#   'song': 'I Have Nothing',
#   'songurl': '/wiki/I_Have_Nothing',
#   'titletext': '"I Have Nothing"',
#   'url': '/wiki/Whitney_Houston',
#   'year': '1993'},
#  {'band_singer': 'Arrested Development',
#   'ranking': '31\n',
#   'song': 'Mr. Wendal',
#   'songurl': '/wiki/Mr._Wendal',
#   'titletext': '"Mr. Wendal"',
#   'url': '/wiki/Arrested_Development_(group)',
#   'year': '1993'},
#  {'band_singer': 'Rod Stewart',
#   'ranking': '32\n',
#   'song': 'Have I Told You Lately',
#   'songurl': '/wiki/Have_I_Told_You_Lately',
#   'titletext': '"Have I Told You Lately"',
#   'url': '/wiki/Rod_Stewart',
#   'year': '1993'},
#  {'band_singer': 'Shanice',
#   'ranking': '33\n',
#   'song': 'Saving Forever for You',
#   'songurl': '/wiki/Saving_Forever_for_You',
#   'titletext': '"Saving Forever for You"',
#   'url': '/wiki/Shanice',
#   'year': '1993'},
#  {'band_singer': 'Duran Duran',
#   'ranking': '34\n',
#   'song': 'Ordinary World',
#   'songurl': '/wiki/Ordinary_World',
#   'titletext': '"Ordinary World"',
#   'url': '/wiki/Duran_Duran',
#   'year': '1993'},
#  {'band_singer': 'Tony! Toni! Toné!',
#   'ranking': '35\n',
#   'song': 'If I Had No Loot',
#   'songurl': '/wiki/If_I_Had_No_Loot',
#   'titletext': '"If I Had No Loot"',
#   'url': '/wiki/Tony!_Toni!_Ton%C3%A9!',
#   'year': '1993'},
#  {'band_singer': 'Meat Loaf',
#   'ranking': '36\n',
#   'song': '"I\'d Do Anything for Love (But I Won\'t Do That)"',
#   'songurl': '/wiki/I%27d_Do_Anything_for_Love_(But_I_Won%27t_Do_That)',
#   'titletext': '"I\'d Do Anything for Love (But I Won\'t Do That)"',
#   'url': '/wiki/Meat_Loaf',
#   'year': '1993'},
#  {'band_singer': 'Onyx',
#   'ranking': '37\n',
#   'song': 'Slam (Onyx song)',
#   'songurl': '/wiki/Slam_(Onyx_song)',
#   'titletext': '"Slam (Onyx song)"',
#   'url': '/wiki/Onyx_(hip_hop_group)',
#   'year': '1993'},
#  {'band_singer': 'P.M. Dawn',
#   'ranking': '38\n',
#   'song': 'Looking Through Patient Eyes',
#   'songurl': '/wiki/Looking_Through_Patient_Eyes',
#   'titletext': '"Looking Through Patient Eyes"',
#   'url': '/wiki/P.M._Dawn',
#   'year': '1993'},
#  {'band_singer': 'Whitney Houston',
#   'ranking': '39\n',
#   'song': '"I\'m Every Woman"',
#   'songurl': '/wiki/I%27m_Every_Woman#Whitney_Houston_version',
#   'titletext': '"I\'m Every Woman"',
#   'url': '/wiki/Whitney_Houston',
#   'year': '1993'},
#  {'band_singer': 'Shai',
#   'ranking': '40\n',
#   'song': '"I\'m Every Woman"',
#   'songurl': 'None',
#   'titletext': '"I\'m Every Woman"',
#   'url': '/wiki/Shai_(band)',
#   'year': '1993'},
#  {'band_singer': 'Duran Duran',
#   'ranking': '41\n',
#   'song': 'Come Undone (Duran Duran song)',
#   'songurl': '/wiki/Come_Undone_(Duran_Duran_song)',
#   'titletext': '"Come Undone (Duran Duran song)"',
#   'url': '/wiki/Duran_Duran',
#   'year': '1993'},
#  {'band_singer': 'Tina Turner',
#   'ranking': '42\n',
#   'song': '"I Don\'t Wanna Fight"',
#   'songurl': '/wiki/I_Don%27t_Wanna_Fight',
#   'titletext': '"I Don\'t Wanna Fight"',
#   'url': '/wiki/Tina_Turner',
#   'year': '1993'},
#  {'band_singer': 'P.M. Dawn',
#   'ranking': '43\n',
#   'song': '"I\'d Die Without You"',
#   'songurl': '/wiki/I%27d_Die_Without_You',
#   'titletext': '"I\'d Die Without You"',
#   'url': '/wiki/P.M._Dawn',
#   'year': '1993'},
#  {'band_singer': '95 South',
#   'ranking': '44\n',
#   'song': 'Whoot, There It Is',
#   'songurl': '/wiki/Whoot,_There_It_Is',
#   'titletext': '"Whoot, There It Is"',
#   'url': '/wiki/95_South',
#   'year': '1993'},
#  {'band_singer': 'Naughty by Nature',
#   'ranking': '45\n',
#   'song': 'Hip Hop Hooray',
#   'songurl': '/wiki/Hip_Hop_Hooray',
#   'titletext': '"Hip Hop Hooray"',
#   'url': '/wiki/Naughty_by_Nature',
#   'year': '1993'},
#  {'band_singer': 'Toni Braxton',
#   'ranking': '46\n',
#   'song': 'Another Sad Love Song',
#   'songurl': '/wiki/Another_Sad_Love_Song',
#   'titletext': '"Another Sad Love Song"',
#   'url': '/wiki/Toni_Braxton',
#   'year': '1993'},
#  {'band_singer': 'Michael Jackson',
#   'ranking': '47\n',
#   'song': 'Will You Be There',
#   'songurl': '/wiki/Will_You_Be_There',
#   'titletext': '"Will You Be There"',
#   'url': '/wiki/Michael_Jackson',
#   'year': '1993'},
#  {'band_singer': 'Shai',
#   'ranking': '48\n',
#   'song': 'Comforter (song)',
#   'songurl': '/wiki/Comforter_(song)',
#   'titletext': '"Comforter (song)"',
#   'url': '/wiki/Shai_(band)',
#   'year': '1993'},
#  {'band_singer': 'Bobby Brown',
#   'ranking': '49\n',
#   'song': 'Comforter (song)',
#   'songurl': 'None',
#   'titletext': 'Comforter (song)',
#   'url': '/wiki/Bobby_Brown',
#   'year': '1993'},
#  {'band_singer': '4 Non Blondes',
#   'ranking': '50\n',
#   'song': '"What\'s Up? (4 Non Blondes song)"',
#   'songurl': '/wiki/What%27s_Up%3F_(4_Non_Blondes_song)',
#   'titletext': '"What\'s Up? (4 Non Blondes song)"',
#   'url': '/wiki/4_Non_Blondes',
#   'year': '1993'},
#  {'band_singer': 'Ace of Base',
#   'ranking': '51\n',
#   'song': 'All That She Wants',
#   'songurl': '/wiki/All_That_She_Wants',
#   'titletext': '"All That She Wants"',
#   'url': '/wiki/Ace_of_Base',
#   'year': '1993'},
#  {'band_singer': 'Brian McKnight',
#   'ranking': '54\n',
#   'song': 'One Last Cry',
#   'songurl': '/wiki/One_Last_Cry',
#   'titletext': '"One Last Cry"',
#   'url': '/wiki/Brian_McKnight',
#   'year': '1993'},
#  {'band_singer': 'Xscape',
#   'ranking': '55\n',
#   'song': '"Just Kickin\' It"',
#   'songurl': '/wiki/Just_Kickin%27_It',
#   'titletext': '"Just Kickin\' It"',
#   'url': '/wiki/Xscape_(band)',
#   'year': '1993'},
#  {'band_singer': '2Pac',
#   'ranking': '56\n',
#   'song': 'I Get Around (Tupac Shakur song)',
#   'songurl': '/wiki/I_Get_Around_(Tupac_Shakur_song)',
#   'titletext': '"I Get Around (Tupac Shakur song)"',
#   'url': '/wiki/Tupac_Shakur',
#   'year': '1993'},
#  {'band_singer': 'Bon Jovi',
#   'ranking': '57\n',
#   'song': 'Bed of Roses (Bon Jovi song)',
#   'songurl': '/wiki/Bed_of_Roses_(Bon_Jovi_song)',
#   'titletext': '"Bed of Roses (Bon Jovi song)"',
#   'url': '/wiki/Bon_Jovi',
#   'year': '1993'},
#  {'band_singer': 'Mary J. Blige',
#   'ranking': '58\n',
#   'song': 'Real Love (Mary J. Blige song)',
#   'songurl': '/wiki/Real_Love_(Mary_J._Blige_song)',
#   'titletext': '"Real Love (Mary J. Blige song)"',
#   'url': '/wiki/Mary_J._Blige',
#   'year': '1993'},
#  {'band_singer': 'Portrait',
#   'ranking': '59\n',
#   'song': 'Real Love (Mary J. Blige song)',
#   'songurl': 'None',
#   'titletext': 'Real Love (Mary J. Blige song)',
#   'url': '/wiki/Portrait_(band)',
#   'year': '1993'},
#  {'band_singer': 'Aerosmith',
#   'ranking': '60\n',
#   'song': '"Cryin\'"',
#   'songurl': '/wiki/Cryin%27',
#   'titletext': '"Cryin\'"',
#   'url': '/wiki/Aerosmith',
#   'year': '1993'},
#  {'band_singer': 'Ugly Kid Joe',
#   'ranking': '61\n',
#   'song': '"Cat\'s in the Cradle"',
#   'songurl': '/wiki/Cat%27s_in_the_Cradle',
#   'titletext': '"Cat\'s in the Cradle"',
#   'url': '/wiki/Ugly_Kid_Joe',
#   'year': '1993'},
#  {'band_singer': 'TLC',
#   'ranking': '62\n',
#   'song': 'What About Your Friends',
#   'songurl': '/wiki/What_About_Your_Friends',
#   'titletext': '"What About Your Friends"',
#   'url': '/wiki/TLC_(group)',
#   'year': '1993'},
#  {'band_singer': 'Positive K',
#   'ranking': '63\n',
#   'song': 'I Got a Man',
#   'songurl': '/wiki/I_Got_a_Man',
#   'titletext': '"I Got a Man"',
#   'url': '/wiki/Positive_K',
#   'year': '1993'},
#  {'band_singer': 'Zhané',
#   'ranking': '64\n',
#   'song': 'Hey Mr. D.J.',
#   'songurl': '/wiki/Hey_Mr._D.J.',
#   'titletext': '"Hey Mr. D.J."',
#   'url': '/wiki/Zhan%C3%A9',
#   'year': '1993'},
#  {'band_singer': 'Cypress Hill',
#   'ranking': '65\n',
#   'song': 'Insane in the Brain',
#   'songurl': '/wiki/Insane_in_the_Brain',
#   'titletext': '"Insane in the Brain"',
#   'url': '/wiki/Cypress_Hill',
#   'year': '1993'},
#  {'band_singer': 'Madonna',
#   'ranking': '66\n',
#   'song': 'Deeper and Deeper',
#   'songurl': '/wiki/Deeper_and_Deeper',
#   'titletext': '"Deeper and Deeper"',
#   'url': '/wiki/Madonna_(entertainer)',
#   'year': '1993'},
#  {'band_singer': 'Madonna',
#   'ranking': '67\n',
#   'song': 'Rain (Madonna song)',
#   'songurl': '/wiki/Rain_(Madonna_song)',
#   'titletext': '"Rain (Madonna song)"',
#   'url': '/wiki/Madonna_(entertainer)',
#   'year': '1993'},
#  {'band_singer': 'Jeremy Jordan',
#   'ranking': '68\n',
#   'song': 'The Right Kind of Love',
#   'songurl': '/wiki/The_Right_Kind_of_Love',
#   'titletext': '"The Right Kind of Love"',
#   'url': '/wiki/Jeremy_Jordan_(singer,_born_1973)',
#   'year': '1993'},
#  {'band_singer': 'Inner Circle',
#   'ranking': '69\n',
#   'song': "Bad Boys (Inner Circle song)', 'Cops (TV series)",
#   'songurl': "/wiki/Bad_Boys_(Inner_Circle_song)', '/wiki/Cops_(TV_series)",
#   'titletext': '"Bad Boys (Inner Circle song)" / "Cops (TV series)"',
#   'url': '/wiki/Inner_Circle_(reggae_band)',
#   'year': '1993'},
#  {'band_singer': 'Boy Krazy',
#   'ranking': '70\n',
#   'song': '"That\'s What Love Can Do"',
#   'songurl': '/wiki/That%27s_What_Love_Can_Do',
#   'titletext': '"That\'s What Love Can Do"',
#   'url': '/wiki/Boy_Krazy',
#   'year': '1993'},
#  {'band_singer': 'Jon Secada',
#   'ranking': '71\n',
#   'song': 'Do You Believe in Us',
#   'songurl': '/wiki/Do_You_Believe_in_Us',
#   'titletext': '"Do You Believe in Us"',
#   'url': '/wiki/Jon_Secada',
#   'year': '1993'},
#  {'band_singer': 'Jon Secada',
#   'ranking': '72\n',
#   'song': 'Angel (Jon Secada song)',
#   'songurl': '/wiki/Angel_(Jon_Secada_song)',
#   'titletext': '"Angel (Jon Secada song)"',
#   'url': '/wiki/Jon_Secada',
#   'year': '1993'},
#  {'band_singer': 'Kenny G',
#   'ranking': '73\n',
#   'song': 'Forever in Love (instrumental)',
#   'songurl': '/wiki/Forever_in_Love_(instrumental)',
#   'titletext': '"Forever in Love (instrumental)"',
#   'url': '/wiki/Kenny_G',
#   'year': '1993'},
#  {'band_singer': 'Janet Jackson',
#   'ranking': '74\n',
#   'song': 'Again (Janet Jackson song)',
#   'songurl': '/wiki/Again_(Janet_Jackson_song)',
#   'titletext': '"Again (Janet Jackson song)"',
#   'url': '/wiki/Janet_Jackson',
#   'year': '1993'},
#  {'band_singer': 'DJ Jazzy Jeff & The Fresh Prince',
#   'ranking': '75\n',
#   'song': 'Boom! Shake the Room',
#   'songurl': '/wiki/Boom!_Shake_the_Room',
#   'titletext': '"Boom! Shake the Room"',
#   'url': '/wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince',
#   'year': '1993'},
#  {'band_singer': 'Restless Heart',
#   'ranking': '76\n',
#   'song': 'When She Cries',
#   'songurl': '/wiki/When_She_Cries',
#   'titletext': '"When She Cries"',
#   'url': '/wiki/Restless_Heart',
#   'year': '1993'},
#  {'band_singer': 'Inner Circle',
#   'ranking': '77\n',
#   'song': 'Sweat (A La La La La Long)',
#   'songurl': '/wiki/Sweat_(A_La_La_La_La_Long)',
#   'titletext': '"Sweat (A La La La La Long)"',
#   'url': '/wiki/Inner_Circle_(reggae_band)',
#   'year': '1993'},
#  {'band_singer': 'Ice Cube',
#   'ranking': '78\n',
#   'song': 'It Was a Good Day',
#   'songurl': '/wiki/It_Was_a_Good_Day',
#   'titletext': '"It Was a Good Day"',
#   'url': '/wiki/Ice_Cube',
#   'year': '1993'},
#  {'band_singer': 'Captain Hollywood Project',
#   'ranking': '79\n',
#   'song': 'More and More (Captain Hollywood Project song)',
#   'songurl': '/wiki/More_and_More_(Captain_Hollywood_Project_song)',
#   'titletext': '"More and More (Captain Hollywood Project song)"',
#   'url': '/wiki/Captain_Hollywood_Project',
#   'year': '1993'},
#  {'band_singer': 'The Heights',
#   'ranking': '80\n',
#   'song': 'How Do You Talk to an Angel',
#   'songurl': '/wiki/How_Do_You_Talk_to_an_Angel',
#   'titletext': '"How Do You Talk to an Angel"',
#   'url': '/wiki/The_Heights_(American_TV_series)',
#   'year': '1993'},
#  {'band_singer': 'Digable Planets',
#   'ranking': '81\n',
#   'song': 'Rebirth of Slick (Cool Like Dat)',
#   'songurl': '/wiki/Rebirth_of_Slick_(Cool_Like_Dat)',
#   'titletext': '"Rebirth of Slick (Cool Like Dat)"',
#   'url': '/wiki/Digable_Planets',
#   'year': '1993'},
#  {'band_singer': 'Haddaway',
#   'ranking': '82\n',
#   'song': 'What Is Love (Haddaway song)',
#   'songurl': '/wiki/What_Is_Love_(Haddaway_song)',
#   'titletext': '"What Is Love (Haddaway song)"',
#   'url': '/wiki/Haddaway',
#   'year': '1993'},
#  {'band_singer': 'Michael Bolton',
#   'ranking': '83\n',
#   'song': 'To Love Somebody (song)',
#   'songurl': '/wiki/To_Love_Somebody_(song)',
#   'titletext': '"To Love Somebody (song)"',
#   'url': '/wiki/Michael_Bolton',
#   'year': '1993'},
#  {'band_singer': 'En Vogue',
#   'ranking': '84\n',
#   'song': 'Give It Up, Turn It Loose',
#   'songurl': '/wiki/Give_It_Up,_Turn_It_Loose',
#   'titletext': '"Give It Up, Turn It Loose"',
#   'url': '/wiki/En_Vogue',
#   'year': '1993'},
#  {'band_singer': 'Kris Kross',
#   'ranking': '85\n',
#   'song': 'Alright (Kris Kross song)',
#   'songurl': '/wiki/Alright_(Kris_Kross_song)',
#   'titletext': '"Alright (Kris Kross song)"',
#   'url': '/wiki/Kris_Kross',
#   'year': '1993'},
#  {'band_singer': 'Sting',
#   'ranking': '87\n',
#   'song': 'Fields of Gold',
#   'songurl': '/wiki/Fields_of_Gold',
#   'titletext': '"Fields of Gold"',
#   'url': '/wiki/Sting_(musician)',
#   'year': '1993'},
#  {'band_singer': 'Dino',
#   'ranking': '88\n',
#   'song': 'Ooh Child',
#   'songurl': '/wiki/Ooh_Child',
#   'titletext': '"Ooh Child"',
#   'url': '/wiki/Dino_(singer)',
#   'year': '1993'},
#  {'band_singer': 'Go West',
#   'ranking': '89\n',
#   'song': 'Faithful (Go West song)',
#   'songurl': '/wiki/Faithful_(Go_West_song)',
#   'titletext': '"Faithful (Go West song)"',
#   'url': '/wiki/Go_West_(band)',
#   'year': '1993'},
#  {'band_singer': 'Rod Stewart',
#   'ranking': '90\n',
#   'song': 'Reason to Believe',
#   'songurl': '/wiki/Reason_to_Believe',
#   'titletext': '"Reason to Believe"',
#   'url': '/wiki/Rod_Stewart',
#   'year': '1993'},
#  {'band_singer': 'Tears for Fears',
#   'ranking': '91\n',
#   'song': 'Break It Down Again',
#   'songurl': '/wiki/Break_It_Down_Again',
#   'titletext': '"Break It Down Again"',
#   'url': '/wiki/Tears_for_Fears',
#   'year': '1993'},
#  {'band_singer': 'Joey Lawrence',
#   'ranking': '92\n',
#   'song': '"Nothin\' My Love Can\'t Fix"',
#   'songurl': '/wiki/Nothin%27_My_Love_Can%27t_Fix',
#   'titletext': '"Nothin\' My Love Can\'t Fix"',
#   'url': '/wiki/Joey_Lawrence',
#   'year': '1993'},
#  {'band_singer': 'Green Jellÿ',
#   'ranking': '93\n',
#   'song': 'Three Little Pigs (song)',
#   'songurl': '/wiki/Three_Little_Pigs_(song)',
#   'titletext': '"Three Little Pigs (song)"',
#   'url': '/wiki/Green_Jell%C3%BF',
#   'year': '1993'},
#  {'band_singer': 'Aerosmith',
#   'ranking': '94\n',
#   'song': '"Livin\' on the Edge"',
#   'songurl': '/wiki/Livin%27_on_the_Edge',
#   'titletext': '"Livin\' on the Edge"',
#   'url': '/wiki/Aerosmith',
#   'year': '1993'},
#  {'band_singer': 'Gin Blossoms',
#   'ranking': '95\n',
#   'song': 'Hey Jealousy',
#   'songurl': '/wiki/Hey_Jealousy',
#   'titletext': '"Hey Jealousy"',
#   'url': '/wiki/Gin_Blossoms',
#   'year': '1993'},
#  {'band_singer': 'Sting',
#   'ranking': '96\n',
#   'song': 'If I Ever Lose My Faith in You',
#   'songurl': '/wiki/If_I_Ever_Lose_My_Faith_in_You',
#   'titletext': '"If I Ever Lose My Faith in You"',
#   'url': '/wiki/Sting_(musician)',
#   'year': '1993'},
#  {'band_singer': 'Tony! Toni! Toné!',
#   'ranking': '97\n',
#   'song': 'Anniversary (Tony! Toni! Toné! song)',
#   'songurl': '/wiki/Anniversary_(Tony!_Toni!_Ton%C3%A9!_song)',
#   'titletext': '"Anniversary (Tony! Toni! Toné! song)"',
#   'url': '/wiki/Tony!_Toni!_Ton%C3%A9!',
#   'year': '1993'},
#  {'band_singer': 'Jade',
#   'ranking': '98\n',
#   'song': 'One Woman',
#   'songurl': '/wiki/One_Woman',
#   'titletext': '"One Woman"',
#   'url': '/wiki/Jade_(American_band)',
#   'year': '1993'},
#  {'band_singer': 'Taylor Dayne',
#   'ranking': '99\n',
#   'song': '"Can\'t Get Enough of Your Love"',
#   'songurl': '/wiki/Can%27t_Get_Enough_of_Your_Love#Taylor_Dayne_version',
#   'titletext': '"Can\'t Get Enough of Your Love"',
#   'url': '/wiki/Taylor_Dayne',
#   'year': '1993'},
#  {'band_singer': 'Def Leppard',
#   'ranking': '100\n',
#   'song': 'Two Steps Behind',
#   'songurl': '/wiki/Two_Steps_Behind',
#   'titletext': '"Two Steps Behind"',
#   'url': '/wiki/Def_Leppard',
#   'year': '1993'},
#  {'band_singer': 'Ace of Base',
#   'ranking': '1\n',
#   'song': 'The Sign (song)',
#   'songurl': '/wiki/The_Sign_(song)',
#   'titletext': '"The Sign (song)"',
#   'url': '/wiki/Ace_of_Base',
#   'year': '1994'},
#  {'band_singer': 'All-4-One',
#   'ranking': '2\n',
#   'song': 'I Swear',
#   'songurl': '/wiki/I_Swear#All-4-One_version',
#   'titletext': '"I Swear"',
#   'url': '/wiki/All-4-One',
#   'year': '1994'},
#  {'band_singer': 'Boyz II Men',
#   'ranking': '3\n',
#   'song': '"I\'ll Make Love to You"',
#   'songurl': '/wiki/I%27ll_Make_Love_to_You',
#   'titletext': '"I\'ll Make Love to You"',
#   'url': '/wiki/Boyz_II_Men',
#   'year': '1994'},
#  {'band_singer': 'Céline Dion',
#   'ranking': '4\n',
#   'song': 'The Power of Love (Jennifer Rush song)',
#   'songurl': '/wiki/The_Power_of_Love_(Jennifer_Rush_song)#Céline_Dion_version',
#   'titletext': '"The Power of Love (Jennifer Rush song)"',
#   'url': '/wiki/C%C3%A9line_Dion',
#   'year': '1994'},
#  {'band_singer': 'Mariah Carey',
#   'ranking': '5\n',
#   'song': 'Hero (Mariah Carey song)',
#   'songurl': '/wiki/Hero_(Mariah_Carey_song)',
#   'titletext': '"Hero (Mariah Carey song)"',
#   'url': '/wiki/Mariah_Carey',
#   'year': '1994'},
#  {'band_singer': 'Lisa Loeb and Nine Stories',
#   'ranking': '6\n',
#   'song': 'Stay (I Missed You)',
#   'songurl': '/wiki/Stay_(I_Missed_You)',
#   'titletext': '"Stay (I Missed You)"',
#   'url': '/wiki/Lisa_Loeb',
#   'year': '1994'},
#  {'band_singer': 'Toni Braxton',
#   'ranking': '7\n',
#   'song': 'Breathe Again',
#   'songurl': '/wiki/Breathe_Again',
#   'titletext': '"Breathe Again"',
#   'url': '/wiki/Toni_Braxton',
#   'year': '1994'},
#  {'band_singer': 'Ace of Base',
#   'ranking': '9\n',
#   'song': 'All That She Wants',
#   'songurl': '/wiki/All_That_She_Wants',
#   'titletext': '"All That She Wants"',
#   'url': '/wiki/Ace_of_Base',
#   'year': '1994'},
#  {'band_singer': 'Ace of Base',
#   'ranking': '10\n',
#   'song': '"Don\'t Turn Around"',
#   'songurl': '/wiki/Don%27t_Turn_Around',
#   'titletext': '"Don\'t Turn Around"',
#   'url': '/wiki/Ace_of_Base',
#   'year': '1994'},
#  {'band_singer': 'R. Kelly',
#   'ranking': '11\n',
#   'song': '"Bump n\' Grind (R. Kelly song)"',
#   'songurl': '/wiki/Bump_n%27_Grind_(R._Kelly_song)',
#   'titletext': '"Bump n\' Grind (R. Kelly song)"',
#   'url': '/wiki/R._Kelly',
#   'year': '1994'},
#  {'band_singer': 'Janet Jackson',
#   'ranking': '12\n',
#   'song': 'Again (Janet Jackson song)',
#   'songurl': '/wiki/Again_(Janet_Jackson_song)',
#   'titletext': '"Again (Janet Jackson song)"',
#   'url': '/wiki/Janet_Jackson',
#   'year': '1994'},
#  {'band_singer': 'Madonna',
#   'ranking': '13\n',
#   'song': '"I\'ll Remember"',
#   'songurl': '/wiki/I%27ll_Remember',
#   'titletext': '"I\'ll Remember"',
#   'url': '/wiki/Madonna_(entertainer)',
#   'year': '1994'},
#  {'band_singer': 'Mariah Carey',
#   'ranking': '16\n',
#   'song': "Without You (Badfinger song)', 'Never Forget You (Mariah Carey song)",
#   'songurl': "/wiki/Without_You_(Badfinger_song)#Mariah_Carey_version', '/wiki/Never_Forget_You_(Mariah_Carey_song)",
#   'titletext': '"Without You (Badfinger song)" / "Never Forget You (Mariah Carey song)"',
#   'url': '/wiki/Mariah_Carey',
#   'year': '1994'},
#  {'band_singer': 'Toni Braxton',
#   'ranking': '17\n',
#   'song': 'You Mean the World to Me (Toni Braxton song)',
#   'songurl': '/wiki/You_Mean_the_World_to_Me_(Toni_Braxton_song)',
#   'titletext': '"You Mean the World to Me (Toni Braxton song)"',
#   'url': '/wiki/Toni_Braxton',
#   'year': '1994'},
#  {'band_singer': 'Elton John',
#   'ranking': '18\n',
#   'song': 'Can You Feel the Love Tonight',
#   'songurl': '/wiki/Can_You_Feel_the_Love_Tonight',
#   'titletext': '"Can You Feel the Love Tonight"',
#   'url': '/wiki/Elton_John',
#   'year': '1994'},
#  {'band_singer': 'Prince',
#   'ranking': '19\n',
#   'song': 'The Most Beautiful Girl in the World (Prince song)',
#   'songurl': '/wiki/The_Most_Beautiful_Girl_in_the_World_(Prince_song)',
#   'titletext': '"The Most Beautiful Girl in the World (Prince song)"',
#   'url': '/wiki/Prince_(musician)',
#   'year': '1994'},
#  {'band_singer': 'Coolio',
#   'ranking': '20\n',
#   'song': 'Fantastic Voyage (Coolio song)',
#   'songurl': '/wiki/Fantastic_Voyage_(Coolio_song)',
#   'titletext': '"Fantastic Voyage (Coolio song)"',
#   'url': '/wiki/Coolio',
#   'year': '1994'},
#  {'band_singer': 'Big Mountain',
#   'ranking': '21\n',
#   'song': 'Baby, I Love Your Way',
#   'songurl': '/wiki/Baby,_I_Love_Your_Way',
#   'titletext': '"Baby, I Love Your Way"',
#   'url': '/wiki/Big_Mountain_(band)',
#   'year': '1994'},
#  {'band_singer': 'Jon Secada',
#   'ranking': '23\n',
#   'song': 'If You Go (song)',
#   'songurl': '/wiki/If_You_Go_(song)',
#   'titletext': '"If You Go (song)"',
#   'url': '/wiki/Jon_Secada',
#   'year': '1994'},
#  {'band_singer': 'Aaliyah',
#   'ranking': '24\n',
#   'song': 'Back & Forth (Aaliyah song)',
#   'songurl': '/wiki/Back_%26_Forth_(Aaliyah_song)',
# ...
#   'url': '/wiki/Kenny_Chesney',
#   'year': '2002'},
#  {'band_singer': 'Steve Holy',
#   'ranking': '84\n',
#   'song': 'Good Morning Beautiful (song)',
#   'songurl': '/wiki/Good_Morning_Beautiful_(song)',
#   'titletext': '"Good Morning Beautiful (song)"',
#   'url': '/wiki/Steve_Holy',
#   'year': '2002'},
#  {'band_singer': 'Aaliyah',
#   'ranking': '85\n',
#   'song': 'Rock the Boat (Aaliyah song)',
#   'songurl': '/wiki/Rock_the_Boat_(Aaliyah_song)',
#   'titletext': '"Rock the Boat (Aaliyah song)"',
#   'url': '/wiki/Aaliyah',
#   'year': '2002'},
#  {'band_singer': 'Alan Jackson',
#   'ranking': '86\n',
#   'song': 'Drive (For Daddy Gene)',
#   'songurl': '/wiki/Drive_(For_Daddy_Gene)',
#   'titletext': '"Drive (For Daddy Gene)"',
#   'url': '/wiki/Alan_Jackson',
#   'year': '2002'},
#  {'band_singer': 'Jewel',
#   'ranking': '87\n',
#   'song': 'Standing Still (Jewel song)',
#   'songurl': '/wiki/Standing_Still_(Jewel_song)',
#   'titletext': '"Standing Still (Jewel song)"',
#   'url': '/wiki/Jewel_(singer)',
#   'year': '2002'},
#  {'band_singer': 'Brandy',
#   'ranking': '89\n',
#   'song': 'Full Moon (Brandy Norwood song)',
#   'songurl': '/wiki/Full_Moon_(Brandy_Norwood_song)',
#   'titletext': '"Full Moon (Brandy Norwood song)"',
#   'url': '/wiki/Brandy_Norwood',
#   'year': '2002'},
#  {'band_singer': 'B2K',
#   'ranking': '90\n',
#   'song': 'Uh Huh (B2K song)',
#   'songurl': '/wiki/Uh_Huh_(B2K_song)',
#   'titletext': '"Uh Huh (B2K song)"',
#   'url': '/wiki/B2K',
#   'year': '2002'},
#  {'band_singer': 'Celine Dion',
#   'ranking': '91\n',
#   'song': 'A New Day Has Come (song)',
#   'songurl': '/wiki/A_New_Day_Has_Come_(song)',
#   'titletext': '"A New Day Has Come (song)"',
#   'url': '/wiki/Celine_Dion',
#   'year': '2002'},
#  {'band_singer': 'Nelly Furtado',
#   'ranking': '92\n',
#   'song': 'Turn Off the Light',
#   'songurl': '/wiki/Turn_Off_the_Light',
#   'titletext': '"Turn Off the Light"',
#   'url': '/wiki/Nelly_Furtado',
#   'year': '2002'},
#  {'band_singer': 'George Strait',
#   'ranking': '93\n',
#   'song': 'Living and Living Well',
#   'songurl': '/wiki/Living_and_Living_Well',
#   'titletext': '"Living and Living Well"',
#   'url': '/wiki/George_Strait',
#   'year': '2002'},
#  {'band_singer': 'Toby Keith',
#   'ranking': '94\n',
#   'song': 'My List',
#   'songurl': '/wiki/My_List',
#   'titletext': '"My List"',
#   'url': '/wiki/Toby_Keith',
#   'year': '2002'},
#  {'band_singer': 'Alanis Morissette',
#   'ranking': '95\n',
#   'song': 'Hands Clean',
#   'songurl': '/wiki/Hands_Clean',
#   'titletext': '"Hands Clean"',
#   'url': '/wiki/Alanis_Morissette',
#   'year': '2002'},
#  {'band_singer': 'Avril Lavigne',
#   'ranking': '96\n',
#   'song': 'Sk8er Boi',
#   'songurl': '/wiki/Sk8er_Boi',
#   'titletext': '"Sk8er Boi"',
#   'url': '/wiki/Avril_Lavigne',
#   'year': '2002'},
#  {'band_singer': 'Dixie Chicks',
#   'ranking': '97\n',
#   'song': 'Long Time Gone',
#   'songurl': '/wiki/Long_Time_Gone',
#   'titletext': '"Long Time Gone"',
#   'url': '/wiki/Dixie_Chicks',
#   'year': '2002'},
#  {'band_singer': 'Alan Jackson',
#   'ranking': '98\n',
#   'song': 'Where Were You (When the World Stopped Turning)',
#   'songurl': '/wiki/Where_Were_You_(When_the_World_Stopped_Turning)',
#   'titletext': '"Where Were You (When the World Stopped Turning)"',
#   'url': '/wiki/Alan_Jackson',
#   'year': '2002'},
#  {'band_singer': 'Justin Timberlake',
#   'ranking': '99\n',
#   'song': 'Like I Love You',
#   'songurl': '/wiki/Like_I_Love_You',
#   'titletext': '"Like I Love You"',
#   'url': '/wiki/Justin_Timberlake',
#   'year': '2002'},
#  {'band_singer': 'Toya',
#   'ranking': '100\n',
#   'song': 'I Do!!',
#   'songurl': '/wiki/I_Do!!',
#   'titletext': '"I Do!!"',
#   'url': '/wiki/Toya_(singer)',
#   'year': '2002'},
#  {'band_singer': '50 Cent',
#   'ranking': '1\n',
#   'song': 'In Da Club',
#   'songurl': '/wiki/In_Da_Club',
#   'titletext': '"In Da Club"',
#   'url': '/wiki/50_Cent',
#   'year': '2003'},
#  {'band_singer': 'R. Kelly',
#   'ranking': '2\n',
#   'song': 'Ignition (Remix)',
#   'songurl': '/wiki/Ignition_(Remix)',
#   'titletext': '"Ignition (Remix)"',
#   'url': '/wiki/R._Kelly',
#   'year': '2003'},
#  {'band_singer': 'Sean Paul',
#   'ranking': '3\n',
#   'song': 'Get Busy',
#   'songurl': '/wiki/Get_Busy',
#   'titletext': '"Get Busy"',
#   'url': '/wiki/Sean_Paul',
#   'year': '2003'},
#  {'band_singer': '3 Doors Down',
#   'ranking': '5\n',
#   'song': '"When I\'m Gone (3 Doors Down song)"',
#   'songurl': '/wiki/When_I%27m_Gone_(3_Doors_Down_song)',
#   'titletext': '"When I\'m Gone (3 Doors Down song)"',
#   'url': '/wiki/3_Doors_Down',
#   'year': '2003'},
#  {'band_singer': 'Matchbox Twenty',
#   'ranking': '6\n',
#   'song': 'Unwell',
#   'songurl': '/wiki/Unwell',
#   'titletext': '"Unwell"',
#   'url': '/wiki/Matchbox_Twenty',
#   'year': '2003'},
#  {'band_singer': 'Chingy',
#   'ranking': '7\n',
#   'song': 'Right Thurr',
#   'songurl': '/wiki/Right_Thurr',
#   'titletext': '"Right Thurr"',
#   'url': '/wiki/Chingy',
#   'year': '2003'},
#  {'band_singer': 'Aaliyah',
#   'ranking': '8\n',
#   'song': 'Miss You (Aaliyah song)',
#   'songurl': '/wiki/Miss_You_(Aaliyah_song)',
#   'titletext': '"Miss You (Aaliyah song)"',
#   'url': '/wiki/Aaliyah',
#   'year': '2003'},
#  {'band_singer': 'Christina Aguilera',
#   'ranking': '16\n',
#   'song': 'Beautiful (Christina Aguilera song)',
#   'songurl': '/wiki/Beautiful_(Christina_Aguilera_song)',
#   'titletext': '"Beautiful (Christina Aguilera song)"',
#   'url': '/wiki/Christina_Aguilera',
#   'year': '2003'},
#  {'band_singer': 'Avril Lavigne',
#   'ranking': '18\n',
#   'song': '"I\'m with You (song)"',
#   'songurl': '/wiki/I%27m_with_You_(song)',
#   'titletext': '"I\'m with You (song)"',
#   'url': '/wiki/Avril_Lavigne',
#   'year': '2003'},
#  {'band_singer': '50 Cent',
#   'ranking': '21\n',
#   'song': 'P.I.M.P.',
#   'songurl': '/wiki/P.I.M.P.',
#   'titletext': '"P.I.M.P."',
#   'url': '/wiki/50_Cent',
#   'year': '2003'},
#  {'band_singer': 'The Black Eyed Peas',
#   'ranking': '26\n',
#   'song': 'Where Is the Love?',
#   'songurl': '/wiki/Where_Is_the_Love%3F',
#   'titletext': '"Where Is the Love?"',
#   'url': '/wiki/The_Black_Eyed_Peas',
#   'year': '2003'},
#  {'band_singer': 'Eminem',
#   'ranking': '28\n',
#   'song': 'Lose Yourself',
#   'songurl': '/wiki/Lose_Yourself',
#   'titletext': '"Lose Yourself"',
#   'url': '/wiki/Eminem',
#   'year': '2003'},
#  {'band_singer': 'Ashanti',
#   'ranking': '29\n',
#   'song': 'Rock wit U (Awww Baby)',
#   'songurl': '/wiki/Rock_wit_U_(Awww_Baby)',
#   'titletext': '"Rock wit U (Awww Baby)"',
#   'url': '/wiki/Ashanti_(entertainer)',
#   'year': '2003'},
#  {'band_singer': 'Justin Timberlake',
#   'ranking': '30\n',
#   'song': 'Cry Me a River (Justin Timberlake song)',
#   'songurl': '/wiki/Cry_Me_a_River_(Justin_Timberlake_song)',
#   'titletext': '"Cry Me a River (Justin Timberlake song)"',
#   'url': '/wiki/Justin_Timberlake',
#   'year': '2003'},
#  {'band_singer': 'Tyrese',
#   'ranking': '31\n',
#   'song': 'How You Gonna Act Like That',
#   'songurl': '/wiki/How_You_Gonna_Act_Like_That',
#   'titletext': '"How You Gonna Act Like That"',
#   'url': '/wiki/Tyrese_Gibson',
#   'year': '2003'},
#  {'band_singer': 'Justin Timberlake',
#   'ranking': '32\n',
#   'song': 'Rock Your Body',
#   'songurl': '/wiki/Rock_Your_Body',
#   'titletext': '"Rock Your Body"',
#   'url': '/wiki/Justin_Timberlake',
#   'year': '2003'},
#  {'band_singer': 'Wayne Wonder',
#   'ranking': '33\n',
#   'song': 'No Letting Go (song)',
#   'songurl': '/wiki/No_Letting_Go_(song)',
#   'titletext': '"No Letting Go (song)"',
#   'url': '/wiki/Wayne_Wonder',
#   'year': '2003'},
#  {'band_singer': 'Dixie Chicks',
#   'ranking': '35\n',
#   'song': 'Landslide (Fleetwood Mac song)',
#   'songurl': '/wiki/Landslide_(Fleetwood_Mac_song)',
#   'titletext': '"Landslide (Fleetwood Mac song)"',
#   'url': '/wiki/Dixie_Chicks',
#   'year': '2003'},
#  {'band_singer': 'Missy Elliott',
#   'ranking': '36\n',
#   'song': 'Work It (Missy Elliott song)',
#   'songurl': '/wiki/Work_It_(Missy_Elliott_song)',
#   'titletext': '"Work It (Missy Elliott song)"',
#   'url': '/wiki/Missy_Elliott',
#   'year': '2003'},
#  {'band_singer': 'Monica',
#   'ranking': '39\n',
#   'song': 'So Gone',
#   'songurl': '/wiki/So_Gone',
#   'titletext': '"So Gone"',
#   'url': '/wiki/Monica_(entertainer)',
#   'year': '2003'},
#  {'band_singer': 'Lumidee',
#   'ranking': '41\n',
#   'song': 'Never Leave You (Uh Oooh, Uh Oooh)',
#   'songurl': '/wiki/Never_Leave_You_(Uh_Oooh,_Uh_Oooh)',
#   'titletext': '"Never Leave You (Uh Oooh, Uh Oooh)"',
#   'url': '/wiki/Lumidee',
#   'year': '2003'},
#  {'band_singer': 'Kelly Clarkson',
#   'ranking': '44\n',
#   'song': 'Miss Independent (Kelly Clarkson song)',
#   'songurl': '/wiki/Miss_Independent_(Kelly_Clarkson_song)',
#   'titletext': '"Miss Independent (Kelly Clarkson song)"',
#   'url': '/wiki/Kelly_Clarkson',
#   'year': '2003'},
#  {'band_singer': 'Train',
#   'ranking': '45\n',
#   'song': 'Calling All Angels',
#   'songurl': '/wiki/Calling_All_Angels',
#   'titletext': '"Calling All Angels"',
#   'url': '/wiki/Train_(band)',
#   'year': '2003'},
#  {'band_singer': 'Clay Aiken',
#   'ranking': '47\n',
#   'song': 'This Is the Night (Clay Aiken song)',
#   'songurl': '/wiki/This_Is_the_Night_(Clay_Aiken_song)',
#   'titletext': '"This Is the Night (Clay Aiken song)"',
#   'url': '/wiki/Clay_Aiken',
#   'year': '2003'},
#  {'band_singer': 'John Mayer',
#   'ranking': '48\n',
#   'song': 'Your Body Is a Wonderland',
#   'songurl': '/wiki/Your_Body_Is_a_Wonderland',
#   'titletext': '"Your Body Is a Wonderland"',
#   'url': '/wiki/John_Mayer',
#   'year': '2003'},
#  {'band_singer': 'Trapt',
#   'ranking': '49\n',
#   'song': 'Headstrong (Trapt song)',
#   'songurl': '/wiki/Headstrong_(Trapt_song)',
#   'titletext': '"Headstrong (Trapt song)"',
#   'url': '/wiki/Trapt',
#   'year': '2003'},
#  {'band_singer': 'Ginuwine',
#   'ranking': '50\n',
#   'song': 'In Those Jeans',
#   'songurl': '/wiki/In_Those_Jeans',
#   'titletext': '"In Those Jeans"',
#   'url': '/wiki/Ginuwine',
#   'year': '2003'},
#  {'band_singer': 'Jason Mraz',
#   'ranking': '52\n',
#   'song': '"The Remedy (I Won\'t Worry)"',
#   'songurl': '/wiki/The_Remedy_(I_Won%27t_Worry)',
#   'titletext': '"The Remedy (I Won\'t Worry)"',
#   'url': '/wiki/Jason_Mraz',
#   'year': '2003'},
#  {'band_singer': 'Jay-Z',
#   'ranking': '54\n',
#   'song': 'Excuse Me Miss',
#   'songurl': '/wiki/Excuse_Me_Miss',
#   'titletext': '"Excuse Me Miss"',
#   'url': '/wiki/Jay-Z',
#   'year': '2003'},
#  {'band_singer': 'Michelle Branch',
#   'ranking': '56\n',
#   'song': 'Are You Happy Now?',
#   'songurl': '/wiki/Are_You_Happy_Now%3F',
#   'titletext': '"Are You Happy Now?"',
#   'url': '/wiki/Michelle_Branch',
#   'year': '2003'},
#  {'band_singer': 'Shania Twain',
#   'ranking': '57\n',
#   'song': 'Forever and for Always',
#   'songurl': '/wiki/Forever_and_for_Always',
#   'titletext': '"Forever and for Always"',
#   'url': '/wiki/Shania_Twain',
#   'year': '2003'},
#  {'band_singer': 'Nas',
#   'ranking': '58\n',
#   'song': 'I Can (Nas song)',
#   'songurl': '/wiki/I_Can_(Nas_song)',
#   'titletext': '"I Can (Nas song)"',
#   'url': '/wiki/Nas',
#   'year': '2003'},
#  {'band_singer': 'Daniel Bedingfield',
#   'ranking': '60\n',
#   'song': '"If You\'re Not the One"',
#   'songurl': '/wiki/If_You%27re_Not_the_One',
#   'titletext': '"If You\'re Not the One"',
#   'url': '/wiki/Daniel_Bedingfield',
#   'year': '2003'},
#  {'band_singer': 'R. Kelly',
#   'ranking': '61\n',
#   'song': 'Thoia Thoing',
#   'songurl': '/wiki/Thoia_Thoing',
#   'titletext': '"Thoia Thoing"',
#   'url': '/wiki/R._Kelly',
#   'year': '2003'},
#  {'band_singer': '3 Doors Down',
#   'ranking': '62\n',
#   'song': 'Here Without You',
#   'songurl': '/wiki/Here_Without_You',
#   'titletext': '"Here Without You"',
#   'url': '/wiki/3_Doors_Down',
#   'year': '2003'},
#  {'band_singer': '50 Cent',
#   'ranking': '63\n',
#   'song': 'Wanksta',
#   'songurl': '/wiki/Wanksta',
#   'titletext': '"Wanksta"',
#   'url': '/wiki/50_Cent',
#   'year': '2003'},
#  {'band_singer': 'Mýa',
#   'ranking': '64\n',
#   'song': 'My Love Is Like...Wo',
#   'songurl': '/wiki/My_Love_Is_Like...Wo',
#   'titletext': '"My Love Is Like...Wo"',
#   'url': '/wiki/M%C3%BDa',
#   'year': '2003'},
#  {'band_singer': 'Sean Paul',
#   'ranking': '66\n',
#   'song': 'Like Glue',
#   'songurl': '/wiki/Like_Glue',
#   'titletext': '"Like Glue"',
#   'url': '/wiki/Sean_Paul',
#   'year': '2003'},
#  {'band_singer': 'Lonestar',
#   'ranking': '68\n',
#   'song': 'My Front Porch Looking In',
#   'songurl': '/wiki/My_Front_Porch_Looking_In',
#   'titletext': '"My Front Porch Looking In"',
#   'url': '/wiki/Lonestar',
#   'year': '2003'},
#  {'band_singer': 'Amanda Perez',
#   'ranking': '69\n',
#   'song': 'Angel (Amanda Perez song)',
#   'songurl': '/wiki/Angel_(Amanda_Perez_song)',
#   'titletext': '"Angel (Amanda Perez song)"',
#   'url': '/wiki/Amanda_Perez',
#   'year': '2003'},
#  {'band_singer': 'Puddle of Mudd',
#   'ranking': '70\n',
#   'song': 'She Hates Me',
#   'songurl': '/wiki/She_Hates_Me',
#   'titletext': '"She Hates Me"',
#   'url': '/wiki/Puddle_of_Mudd',
#   'year': '2003'},
#  {'band_singer': 'Frankie J',
#   'ranking': '71\n',
#   'song': '"Don\'t Wanna Try"',
#   'songurl': '/wiki/Don%27t_Wanna_Try',
#   'titletext': '"Don\'t Wanna Try"',
#   'url': '/wiki/Frankie_J',
#   'year': '2003'},
#  {'band_singer': 'Jewel',
#   'ranking': '73\n',
#   'song': 'Intuition (Jewel song)',
#   'songurl': '/wiki/Intuition_(Jewel_song)',
#   'titletext': '"Intuition (Jewel song)"',
#   'url': '/wiki/Jewel_(singer)',
#   'year': '2003'},
#  {'band_singer': 'Christina Aguilera',
#   'ranking': '79\n',
#   'song': 'Fighter (Christina Aguilera song)',
#   'songurl': '/wiki/Fighter_(Christina_Aguilera_song)',
#   'titletext': '"Fighter (Christina Aguilera song)"',
#   'url': '/wiki/Christina_Aguilera',
#   'year': '2003'},
#  {'band_singer': '2Pac',
#   'ranking': '80\n',
#   'song': 'Thugz Mansion',
#   'songurl': '/wiki/Thugz_Mansion',
#   'titletext': '"Thugz Mansion"',
#   'url': '/wiki/Tupac_Shakur',
#   'year': '2003'},
#  {'band_singer': 'Coldplay',
#   'ranking': '81\n',
#   'song': 'Clocks (song)',
#   'songurl': '/wiki/Clocks_(song)',
#   'titletext': '"Clocks (song)"',
#   'url': '/wiki/Coldplay',
#   'year': '2003'},
#  {'band_singer': 'Jaheim',
#   'ranking': '82\n',
#   'song': 'Clocks (song)',
#   'songurl': 'None',
#   'titletext': 'Clocks (song)',
#   'url': '/wiki/Jaheim',
#   'year': '2003'},
#  {'band_singer': 'Ashanti',
#   'ranking': '83\n',
#   'song': 'Rain on Me',
#   'songurl': '/wiki/Rain_on_Me',
#   'titletext': '"Rain on Me"',
#   'url': '/wiki/Ashanti_(entertainer)',
#   'year': '2003'},
#  {'band_singer': 'Mark Wills',
#   'ranking': '84\n',
#   'song': '"19 Somethin\'"',
#   'songurl': '/wiki/19_Somethin%27',
#   'titletext': '"19 Somethin\'"',
#   'url': '/wiki/Mark_Wills',
#   'year': '2003'},
#  {'band_singer': 'Young Gunz',
#   'ranking': '85\n',
#   'song': '"Can\'t Stop, Won\'t Stop (Young Gunz song)"',
#   'songurl': '/wiki/Can%27t_Stop,_Won%27t_Stop_(Young_Gunz_song)',
#   'titletext': '"Can\'t Stop, Won\'t Stop (Young Gunz song)"',
#   'url': '/wiki/Young_Gunz',
#   'year': '2003'},
#  {'band_singer': 'Brooks & Dunn',
#   'ranking': '86\n',
#   'song': 'Red Dirt Road (song)',
#   'songurl': '/wiki/Red_Dirt_Road_(song)',
#   'titletext': '"Red Dirt Road (song)"',
#   'url': '/wiki/Brooks_%26_Dunn',
#   'year': '2003'},
#  {'band_singer': 'Dierks Bentley',
#   'ranking': '87\n',
#   'song': '"What Was I Thinkin\'"',
#   'songurl': '/wiki/What_Was_I_Thinkin%27',
#   'titletext': '"What Was I Thinkin\'"',
#   'url': '/wiki/Dierks_Bentley',
#   'year': '2003'},
#  {'band_singer': 'Ruben Studdard',
#   'ranking': '88\n',
#   'song': 'Flying Without Wings',
#   'songurl': '/wiki/Flying_Without_Wings#Ruben_Studdard_version',
#   'titletext': '"Flying Without Wings"',
#   'url': '/wiki/Ruben_Studdard',
#   'year': '2003'},
#  {'band_singer': 'Eminem',
#   'ranking': '89\n',
#   'song': 'Sing for the Moment',
#   'songurl': '/wiki/Sing_for_the_Moment',
#   'titletext': '"Sing for the Moment"',
#   'url': '/wiki/Eminem',
#   'year': '2003'},
#  {'band_singer': 'Darryl Worley',
#   'ranking': '90\n',
#   'song': 'Have You Forgotten? (song)',
#   'songurl': '/wiki/Have_You_Forgotten%3F_(song)',
#   'titletext': '"Have You Forgotten? (song)"',
#   'url': '/wiki/Darryl_Worley',
#   'year': '2003'},
#  {'band_singer': 'Kenny Chesney',
#   'ranking': '91\n',
#   'song': 'No Shoes, No Shirt, No Problems (song)',
#   'songurl': '/wiki/No_Shoes,_No_Shirt,_No_Problems_(song)',
#   'titletext': '"No Shoes, No Shirt, No Problems (song)"',
#   'url': '/wiki/Kenny_Chesney',
#   'year': '2003'},
#  ...]

# %% [markdown]
# To construct the dataframe, we'll need to iterate over the years and the singles per year. Notice how, above, the dataframe is ordered by ranking and then year. While the exact order is up to you, note that you will have to come up with a scheme to order the information.
#
# Check that the dataframe has sensible data types. You will also likely find that the year field has become an "object" (Pandas treats strings as generic objects): this is due to the conversion to and back from JSON. Such conversions need special care. Fix any data type issues with `flatframe`. (See Pandas [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function.)
# We will use this `flatframe` in the next question.
#
# (As an aside, we used the name `flatframe` to indicate that this dataframe is flattened from a hierarchical dictionary structure with the keys being the years.)

# %%
# create dataframe
flatframe = pd.DataFrame(rows2)


# check datatypes of dataframe columns
flatframe['year'].dtype
# Out:
# dtype('O')

# %%
# sanity check
flatframe
# Out:
#              band_singer ranking                        song                           songurl                     titletext                        url  year
# 0            Boyz II Men     1\n             End of the Road             /wiki/End_of_the_Road             "End of the Road"          /wiki/Boyz_II_Men  1992
# 1          Sir Mix-a-Lot     2\n               Baby Got Back               /wiki/Baby_Got_Back               "Baby Got Back"        /wiki/Sir_Mix-a-Lot  1992
# 2             Kris Kross     3\n      Jump (Kris Kross song)      /wiki/Jump_(Kris_Kross_song)      "Jump (Kris Kross song)"           /wiki/Kris_Kross  1992
# 3       Vanessa Williams     4\n      Save the Best for Last      /wiki/Save_the_Best_for_Last      "Save the Best for Last"  /wiki/Vanessa_L._Williams  1992
# 4                    TLC     5\n              Baby-Baby-Baby              /wiki/Baby-Baby-Baby              "Baby-Baby-Baby"           /wiki/TLC_(band)  1992
# ...                  ...     ...                         ...                               ...                           ...                        ...   ...
# 2745     Hayley Williams    94\n  Stay the Night (Zedd song)  /wiki/Stay_the_Night_(Zedd_song)  "Stay the Night (Zedd song)"      /wiki/Hayley_Williams  2014
# 2746         ScHoolboy Q    96\n               Studio (song)               /wiki/Studio_(song)               "Studio (song)"          /wiki/ScHoolboy_Q  2014
# 2747  BJ the Chicago Kid    96\n               Studio (song)               /wiki/Studio_(song)               "Studio (song)"   /wiki/BJ_the_Chicago_Kid  2014
# 2748     Miranda Lambert    99\n             "Somethin' Bad"             /wiki/Somethin%27_Bad               "Somethin' Bad"      /wiki/Miranda_Lambert  2014
# 2749    Carrie Underwood    99\n             "Somethin' Bad"             /wiki/Somethin%27_Bad               "Somethin' Bad"     /wiki/Carrie_Underwood  2014
#
# [2750 rows x 7 columns]

# %%
# convert year column to int
flatframe['year'] = flatframe['year'].astype(np.uint16)

# %% [markdown]
# ### Who are the highest quality singers?

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# #### 1.5 Find highest quality singers according to how prolific they are
#
# What do we mean by highest quality? This is of course open to interpretation, but let's define "highest quality" here as the number of times a singer appears in the top 100 over this time period. If a singer appears twice in a year (for different songs), this is counted as two appearances, not one.
#
# Make a bar-plot of the most prolific singers. Singers on this chart should have appeared at-least more than 15 times. (HINT: look at the docs for the pandas method `value_counts`.)

# %%
# count artist appearences in top 100



artist_count = flatframe["band_singer"].value_counts()

# %%
# plot top artists
artist_count[:8].plot.barh()

# %% [markdown]
# #### 1.6 What if we used a different metric?

# %%
scored_df = pd.DataFrame(np.array(flatframe[['band_singer', 'song', 'ranking']]))
scored_df.columns = ['band_singer', 'song', 'ranking']
# scored_df.groupby(['band_singer', 'song'])['ranking']

scored_df['ranking'] = scored_df['ranking'].apply(lambda x: 101 - int(x))

#display(scored_df)

scored_df.groupby('band_singer')['ranking'].aggregate(np.sum).sort_values(ascending=False).head(20).plot.barh()

# %% [markdown]
# What we would like to capture is this: a singer should to be scored higher if the singer appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %% [markdown]
# #### 1.7 Do you notice any major differences when you change the metric?
#
# How have the singers at the top shifted places? Why do you think this happens?

# %% [markdown]
# """
# While Rihanna keeps her place at the head of the pack (by a sizeable margin, it should be noted),
# Mariah Carey gains materially over R. Kelly, Ludacris and Lil Wayne. The reason for this is that while
# Mariah's songs appear in the top 100 less frequently than those other three, the latter chart weighs
# the relative rank of her songs while the former disregards this and looks at only frequency. Including
# relative rank also gives Katy Perry a place near the top, too.
# """

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those band/singer urls we collected under `flatframe.url` and get information about singers and/or bands.

# %% [markdown]
# ### Scrape information about artists from wikipedia

# %% [markdown]
# We wish to fetch information about the singers or groups for all the winning songs in a list of years.
#
# Here we show a function that fetches information about a singer or group from their url on wikipedia. We create a cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Once we have fetched information about an artist, we don't need to do it again. The caching also helps if the network goes down, or the target website is having some problems. You simply need to run the `get_page` function below again, and the `urlcache` dictionary will continue to be filled.
#
# If the request gets an HTTP return code different from 200, (such as a 404 not found or 500 Internal Server Error) the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.
#
# Notice that we have wrapped the call in whats called _an exception block_. We try to make the request. If it fails entirely, or returns a HTTP code thats not 200, we set the status to 2 and 1 respectively.

# %%
urlcache={}

# %%
def get_page(url):
    # Check if URL has already been visited.
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        # try/except blocks are used whenever the code could generate an exception (e.g. division by zero).
        # In this case we don't know if the page really exists, or even if it does, if we'll be able to reach it.
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)

            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# We sort the `flatframe` by year, ascending, first. Think why.

# %%
# sort the flatframe by year
flatframe = flatframe.sort_values('year')

# %% [markdown]
# #### Pulling and saving the data

# %% [markdown]
# You may have to run this function again and again, in case there were network problems. Note that, because there is a "global" cache, it will take less time each time you run it. Also note that this function is designed to be run again and again: it attempts to make sure that there are no unresolved pages remaining. Let us make sure of this: *the sum below should be 0, and the boolean True.*

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
# Here we are populating the url cache
# subsequent calls to this cell should be very fast, since Python won't
# need to fetch the page from the web server.
# NOTE this function will take quite some time to run (about 30 mins for me), since we sleep 1 second before
# making a request. If you run it again it will be almost instantaneous, save requests that might have failed
# (you will need to run it again if requests fail..see cell below for how to test this)
flatframe["url"].apply(get_page)
# Out:
# 0       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 78      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 77      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 76      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 74      <!DOCTYPE html>\n<html class="client-nojs" lan...
#                               ...
# 1698    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 1697    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 1696    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 1702    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2749    <!DOCTYPE html>\n<html class="client-nojs" lan...
# Name: url, Length: 2750, dtype: object

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
print("Number of bad requests:",np.sum([(urlcache[k]==1) or (urlcache[k]==2) for k in urlcache])) # no one or 0's)
print("Did we get all urls?", len(flatframe.url.unique())==len(urlcache)) # we got all of the urls
# Out:
# Number of bad requests: 1
# Did we get all urls? True

# %% [markdown]
# Let's save the `urlcache` to disk, just in case we need it again.

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
with open("artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %%
# RERUN WHEN SUBMITTING
with open("artistinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# #### 2.1 Extract information about singers and bands

# %% [markdown]
# From each page we collected about a singer or a band, extract the following information:
#
# 1. If the page has the text "Born" in the sidebar on the right, extract the element with the class `.bday`. If the page doesn't contain "Born", store `False`.  Store either of these into the variable `born`. We want to analyze the artist's age.
#
# 2. If the text "Years active" is found, but no "born", assume a band. Store into the variable `ya` the value of the next table cell corresponding to this, or `False` if the text is not found.
#
# Put this all into a function `singer_band_info` which takes the singer/band url as argument and returns a dictionary `dict(url=url, born=born, ya=ya)`.
#
# The information can be found on the sidebar on each such wikipedia page, as the example here shows:
#
# ![sandg](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/sandg.png).

# %% [markdown]
# Write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""


def singer_band_info(url, page_text):
    bday_dict = {}
    bday = ''
    ya = ''
    # soupify our webpage
    soup = BeautifulSoup(page_text[url], "lxml")
    tables = soup.find('table', attrs={'class':'infobox vcard plainlist'})
    if (tables == None):
        tables = soup.find('table', attrs={'class':'infobox biography vcard'})
    bday = tables.find('span', {'class': 'bday'})
    if bday: 
        bday = bday.get_text()[:4]
        bday_dict = {'url' : url, 'born' : bday, 'ya' : ya}
    else:
        ya = False
        for tr in tables.find_all('tr'):
            if hasattr(tr.th, 'span'):
                if hasattr(tr.th.span, 'string'):
                    if tr.th.span.string == 'Years active':                
                        if hasattr(tr.th, 'span'):
                            #ya = tr.td.string
                            ya = tr.td.text   #DK add
                            bday = 'False'
                            bday_dict = {'url' : url, 'born' : 'False', 'ya' : ya}
    return(bday_dict)

# %%
url = '/wiki/Iggy_Azalea'
singer_band_info(url, urlcache)
# Out:
# {'url': '/wiki/Iggy_Azalea', 'born': '1990', 'ya': ''}

# %%
# create additional dictionary with all artists additional information with their url as a key
list_of_addit_dicts = []
bday_dict = {}
for url in urlcache.keys():   
    try:
        bday_dict = singer_band_info(url, urlcache)
        list_of_addit_dicts.append(bday_dict)
    except:
        break

# %%
list_of_addit_dicts
# Out:
# [{'url': '/wiki/Boyz_II_Men', 'born': 'False', 'ya': '1985–present'},
#  {'url': '/wiki/Mary_J._Blige', 'born': '1971', 'ya': ''},
#  {'url': '/wiki/Jade_(American_band)', 'born': 'False', 'ya': '1991–present'},
#  {'url': '/wiki/Richard_Marx', 'born': '1963', 'ya': ''},
#  {'url': '/wiki/Def_Leppard', 'born': 'False', 'ya': '1977–present'},
#  {'url': '/wiki/Kathy_Troccoli', 'born': '1958', 'ya': ''},
#  {'url': '/wiki/N2Deep', 'born': 'False', 'ya': '1990–present'},
#  {'url': '/wiki/Michael_Bolton', 'born': '1953', 'ya': ''},
#  {'url': '/wiki/MC_Hammer', 'born': '1962', 'ya': ''},
#  {'url': '/wiki/Snap!', 'born': 'False', 'ya': '1989–1996; 2000–present'},
#  {'url': '/wiki/Bryan_Adams', 'born': '1959', 'ya': ''},
#  {'url': '/wiki/Paula_Abdul', 'born': '1962', 'ya': ''},
#  {'url': '/wiki/Ugly_Kid_Joe',
#   'born': 'False',
#   'ya': '\n1987–1997\n2010–present\n'},
#  {'url': '/wiki/The_Cure', 'born': 'False', 'ya': '1978–present'},
#  {'url': '/wiki/Marky_Mark_and_the_Funky_Bunch',
#   'born': 'False',
#   'ya': '1989–1993'},
#  {'url': '/wiki/Genesis_(band)',
#   'born': 'False',
#   'ya': '1967–1998[5][6]2006–2007[7]'},
#  {'url': '/wiki/Arrested_Development_(group)',
#   'born': 'False',
#   'ya': '1988–1996, 2000–present'},
#  {'url': '/wiki/Michael_Jackson', 'born': '1958', 'ya': ''},
#  {'url': '/wiki/Kris_Kross', 'born': 'False', 'ya': '1991–1996, 2006–2013'},
#  {'url': '/wiki/Karyn_White', 'born': '1965', 'ya': ''},
#  {'url': '/wiki/CeCe_Peniston', 'born': '1969', 'ya': ''},
#  {'url': '/wiki/The_KLF',
#   'born': 'False',
#   'ya': '1987–199219951997(reunion performance in 2017)'},
#  {'url': '/wiki/U2', 'born': 'False', 'ya': '1976–present'},
#  {'url': '/wiki/Color_Me_Badd', 'born': '1985', 'ya': ''},
#  {'url': '/wiki/Patty_Smyth', 'born': '1957', 'ya': ''},
#  {'url': '/wiki/Don_Henley', 'born': '1947', 'ya': ''},
#  {'url': '/wiki/Prince_(entertainer)', 'born': '1958', 'ya': ''},
#  {'url': '/wiki/The_New_Power_Generation',
#   'born': 'False',
#   'ya': '1990–2013, 2015, 2017'},
#  {'url': '/wiki/George_Michael', 'born': '1963', 'ya': ''},
#  {'url': '/wiki/Elton_John', 'born': '1947', 'ya': ''},
#  {'url': '/wiki/Technotronic', 'born': 'False', 'ya': '1988–2000'},
#  {'url': '/wiki/Ya_Kid_K', 'born': '1973', 'ya': ''},
#  {'url': '/wiki/Luther_Vandross', 'born': '1951', 'ya': ''},
#  {'url': '/wiki/Janet_Jackson', 'born': '1966', 'ya': ''},
#  {'url': '/wiki/Celine_Dion', 'born': '1968', 'ya': ''},
#  {'url': '/wiki/Peabo_Bryson', 'born': '1951', 'ya': ''},
#  {'url': '/wiki/Bonnie_Raitt', 'born': '1949', 'ya': ''},
#  {'url': '/wiki/Das_EFX', 'born': 'False', 'ya': '1988–present'},
#  {'url': '/wiki/Amy_Grant', 'born': '1960', 'ya': ''},
#  {'url': '/wiki/Mr._Big_(band)',
#   'born': 'False',
#   'ya': '1988–20022009–present'},
#  {'url': '/wiki/Keith_Sweat', 'born': '1961', 'ya': ''},
#  {'url': '/wiki/En_Vogue', 'born': 'False', 'ya': '1989–present'},
#  {'url': '/wiki/Charles_%26_Eddie', 'born': 'False', 'ya': '1990–1995'},
#  {'url': '/wiki/TLC_(band)', 'born': 'False', 'ya': '1990–present'}]

# %%
#use the additional dictionary to create additional dataframe

additional_df = pd.DataFrame(list_of_addit_dicts)

# %%
#merge the two dataframes

largedf = pd.merge(flatframe, additional_df, left_on='url', right_on='url', how="outer")

# %%
largedf
# Out:
#            band_singer ranking                                        song                                            songurl                                   titletext                     url  year   born            ya
# 0          Boyz II Men     1\n                             End of the Road                              /wiki/End_of_the_Road                           "End of the Road"       /wiki/Boyz_II_Men  1992  False  1985–present
# 1          Boyz II Men    84\n                                     Uhh Ahh                                      /wiki/Uhh_Ahh                                   "Uhh Ahh"       /wiki/Boyz_II_Men  1992  False  1985–present
# 2          Boyz II Men    37\n  "It's So Hard to Say Goodbye to Yesterday"   /wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday  "It's So Hard to Say Goodbye to Yesterday"       /wiki/Boyz_II_Men  1992  False  1985–present
# 3          Boyz II Men    12\n       In the Still of the Night (1956 song)  /wiki/In_the_Still_of_the_Night_(1956_song)#Bo...     "In the Still of the Night (1956 song)"       /wiki/Boyz_II_Men  1993  False  1985–present
# 4          Boyz II Men     3\n                     "I'll Make Love to You"                      /wiki/I%27ll_Make_Love_to_You                     "I'll Make Love to You"       /wiki/Boyz_II_Men  1994  False  1985–present
# ...                ...     ...                                         ...                                                ...                                         ...                     ...   ...    ...           ...
# 2745       Nico & Vinz    14\n                           Am I Wrong (song)                            /wiki/Am_I_Wrong_(song)                         "Am I Wrong (song)"     /wiki/Nico_%26_Vinz  2014    NaN           NaN
# 2746      Idina Menzel    21\n                     Let It Go (Disney song)                      /wiki/Let_It_Go_(Disney_song)                   "Let It Go (Disney song)"      /wiki/Idina_Menzel  2014    NaN           NaN
# 2747  American Authors    31\n                         Best Day of My Life                          /wiki/Best_Day_of_My_Life                       "Best Day of My Life"  /wiki/American_Authors  2014    NaN           NaN
# 2748               Sia    25\n                       Chandelier (Sia song)                        /wiki/Chandelier_(Sia_song)                     "Chandelier (Sia song)"        /wiki/Sia_Furler  2014    NaN           NaN
# 2749           Tove Lo    32\n                          Habits (Stay High)                           /wiki/Habits_(Stay_High)                        "Habits (Stay High)"           /wiki/Tove_Lo  2014    NaN           NaN
#
# [2750 rows x 9 columns]

# %% [markdown]
# #### 2.2  Merging this information in

# %% [markdown]
# Iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a dataframe from there with columns `url`, `born`, and `ya`. Merge this dataframe on the `url` key with `flatframe`, creating a rather wide dataframe that we shall call `largedf`. It should look something like this:
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC3.png)
#
# Notice how the `born` and `ya` and `url` are repeated every time a different song from a given band is represented in a row.

# %% [markdown]
# #### 2.3 What is the age at which singers achieve their top ranking?

# %% [markdown]
# Plot a histogram of the age at which singers achieve their top ranking. What conclusions can you draw from this distribution of ages?
#
# *HINT: You will need to do some manipulation of the `born` column, and find the song for which a band or an artist achieves their top ranking. You will then need to put these rows together into another dataframe or array to make the plot.*

# %%
new_df = pd.DataFrame(np.array(largedf[['year', 'band_singer', 'ranking', 'born']]))
new_df.columns = ['year', 'band_singer', 'ranking', 'born']
new_df['born'] = pd.to_numeric(new_df['born'], errors='coerce').fillna(0).astype(np.int64)                     #convert to int
new_df['year_minus_born'] = new_df['year'] - new_df['born']
sorted_df = new_df.sort_values(['band_singer', 'ranking']);
filtered_df = sorted_df.drop_duplicates(subset='band_singer', keep='first')
filtered_df = filtered_df.query('born > 0')
print(filtered_df)
filtered_df.groupby('band_singer')['year_minus_born'].aggregate(np.sum).sort_values(ascending=False).plot.hist(bins=10)
# Out:
#      year      band_singer ranking  born year_minus_born
# 138  1992        Amy Grant    52\n  1960              32
# 132  1992     Bonnie Raitt   100\n  1949              43
# 48   1995      Bryan Adams    16\n  1959              36
# 76   1992    CeCe Peniston    20\n  1969              23
# 126  1998      Celine Dion    13\n  1968              30
# 85   1996    Color Me Badd    54\n  1985              11
# 87   1992       Don Henley    22\n  1947              45
# 98   1997       Elton John     1\n  1947              50
# 91   1992   George Michael    26\n  1963              29
# 41   1992           Hammer    46\n  1962              30
# 116  1998            Janet     6\n  1966              32
# 108  1994    Janet Jackson    12\n  1966              28
# 73   1992      Karyn White    63\n  1965              27
# 33   1992   Kathy Troccoli    79\n  1958              34
# 143  1996      Keith Sweat    10\n  1961              35
# 102  1992  Luther Vandross    41\n  1951              41
# 21   2006    Mary J. Blige    11\n  1971              35
# 38   1994   Michael Bolton    32\n  1953              41
# 63   1992  Michael Jackson    14\n  1958              34
# 86   1992      Patty Smyth    22\n  1957              35
# 50   1992      Paula Abdul    73\n  1962              30
# 131  1993     Peabo Bryson    18\n  1951              42
# 29   1994     Richard Marx    25\n  1963              31
# 101  1992         Ya Kid K    38\n  1973              19

# %% [markdown]
# #### 2.4 At what year since inception do bands reach their top rankings?

# %% [markdown]
# Make a similar calculation to plot a histogram of the years since inception at which bands reach their top ranking. What conclusions can you draw?

# %%
new_df_2 = pd.DataFrame(np.array(largedf[['year', 'band_singer', 'ranking', 'ya']]))
new_df_2.columns = ['year', 'band_singer', 'ranking', 'ya']
new_df_2['ya'] = new_df_2['ya'].str[:4]
new_df_2['ya'] = pd.to_numeric(new_df_2['ya'], errors='coerce').fillna(0).astype(np.int64)                     #convert to int
new_df_2['year_minus_ya'] = new_df_2['year'] - new_df_2['ya']
sorted_df_2 = new_df_2.sort_values(['band_singer', 'ranking']);
filtered_df_2 = sorted_df_2.drop_duplicates(subset='band_singer', keep='first')
filtered_df_2 = filtered_df_2.query('ya > 0')
filtered_df_2 = filtered_df_2.query('year_minus_ya < 40')
print(filtered_df_2)
filtered_df_2.groupby('band_singer')['year_minus_ya'].aggregate(np.sum).sort_values(ascending=False).plot.hist(bins=10)
# Out:
#      year                     band_singer ranking    ya year_minus_ya
# 60   1993            Arrested Development    31\n  1988             5
# 0    1992                     Boyz II Men     1\n  1985             7
# 152  1992                 Charles & Eddie    90\n  1990             2
# 135  1993                         Das EFX    86\n  1988             5
# 32   1993                     Def Leppard   100\n  1977            16
# 150  1994                        En Vogue    14\n  1989             5
# 57   1992                         Genesis    55\n  1967            25
# 70   1992                      Kris Kross     3\n  1991             1
# 54   1992  Marky Mark and the Funky Bunch    69\n  1989             3
# 140  1992                         Mr. Big    12\n  1988             4
# 34   1992                          N2Deep    78\n  1990             2
# 43   1993                           Snap!    25\n  1989             4
# 157  1995                             TLC     2\n  1990             5
# 100  1992                    Technotronic    38\n  1988             4
# 53   1992                        The Cure    71\n  1978            14
# 77   1992                         The KLF    86\n  1987             5
# 89   1992        The New Power Generation    25\n  1990             2
# 79   1992                              U2    57\n  1976            16
